# %%
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.preprocessing import StandardScaler
from xgboost import plot_importance
import matplotlib.pyplot as plt
import xgboost as xgb
import pandas as pd
import numpy as np
import itertools

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
identifier_name = 'flight_id'

most_important_features_names = [
    'wtc', 
    'flown_distance', 
    'aircraft_type', 
    'groundspeed_max', 
    'airline', 
    'altitude_max', 
    'flight_duration', 
    'latitude_max', 
    'ades', 
    'adep', 
    'altitude_75percentile', 
    'altitude_median', 
]

target_name = 'tow'

global_random_state = 123

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def evaluate_model(model, data_df, features_columns, target_column):
    features = data_df[features_columns]
    target = data_df[target_column]
    X_array = features.values
    y_array = target.values
    rmse_scores = []
    kf = KFold(n_splits=3, shuffle=True, random_state=global_random_state)
    for train_index, test_index in kf.split(X_array):
        X_train, X_test = features.iloc[train_index], features.iloc[test_index]
        y_train, y_test = target.iloc[train_index], target.iloc[test_index]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        rmse_scores.append(rmse(y_test, y_pred))
    return np.mean(rmse_scores)

# %%
encoded_challenge_set = pd.read_csv('data/encoded_challenge_set.csv')
encoded_challenge_set = encoded_challenge_set.fillna(0)

# %%
num_top_important_features = len(most_important_features_names)
print(f"We need to build {2**num_top_important_features} Trying all combinations of the top {num_top_important_features} important features")

all_combinations = list(itertools.chain.from_iterable(
    itertools.combinations(most_important_features_names, r) for r in range(len(most_important_features_names) + 1)
))
print(f"Total number of generated combinations: {len(all_combinations)}")

tried_combination = []
combinations_rmse_scores = []
for index, combination in enumerate(all_combinations[1:]):
    current_features = list(combination)
    
    print(f"Trying the combination number {index+1}...")
    print(current_features)
    
    xgb_model = xgb.XGBRegressor(
        n_estimators=91,
        max_depth=10,
        learning_rate=0.1,
        subsample=1.0,
        colsample_bytree=1.0,
        objective='reg:squarederror', 
        eval_metric='rmse',
        random_state=global_random_state
    )
    
    rmse_score = evaluate_model(
        model=xgb_model, 
        data_df=encoded_challenge_set, 
        features_columns=current_features, 
        target_column=target_name
    )
    print("Evaluation RMSE:", rmse_score)

    tried_combination.append(current_features)
    combinations_rmse_scores.append(rmse_score)
# Out:
# We need to build 4096 Trying all combinations of the top 12 important features
# Total number of generated combinations: 4096
# Trying the combination number 1...
# ['wtc']
# Evaluation RMSE: 20350.17311080975
# Trying the combination number 2...
# ['flown_distance']
# Evaluation RMSE: 27477.065008386544
# Trying the combination number 3...
# ['aircraft_type']
# Evaluation RMSE: 10827.753782628288
# Trying the combination number 4...
# ['groundspeed_max']
# Evaluation RMSE: 45819.71034871987
# Trying the combination number 5...
# ['airline']
# Evaluation RMSE: 43931.55855543888
# Trying the combination number 6...
# ['altitude_max']
# Evaluation RMSE: 47272.32769928831
# Trying the combination number 7...
# ['flight_duration']
# Evaluation RMSE: 28424.577113701594
# Trying the combination number 8...
# ['latitude_max']
# Evaluation RMSE: 46904.50174785484
# Trying the combination number 9...
# ['ades']
# Evaluation RMSE: 40828.276413857
# Trying the combination number 10...
# ['adep']
# Evaluation RMSE: 41102.97042689838
# Trying the combination number 11...
# ['altitude_75percentile']
# Evaluation RMSE: 48931.27588103849
# Trying the combination number 12...
# ['altitude_median']
# Evaluation RMSE: 47380.31073261142
# Trying the combination number 13...
# ['wtc', 'flown_distance']
# Evaluation RMSE: 15521.667890609824
# Trying the combination number 14...
# ['wtc', 'aircraft_type']
# Evaluation RMSE: 10830.147034063946
# Trying the combination number 15...
# ['wtc', 'groundspeed_max']
# Evaluation RMSE: 19635.869077269483
# Trying the combination number 16...
# ['wtc', 'airline']
# Evaluation RMSE: 17348.920974564604
# Trying the combination number 17...
# ['wtc', 'altitude_max']
# Evaluation RMSE: 17484.59461763784
# Trying the combination number 18...
# ['wtc', 'flight_duration']
# Evaluation RMSE: 15939.55890628444
# Trying the combination number 19...
# ['wtc', 'latitude_max']
# Evaluation RMSE: 18086.444114589867
# Trying the combination number 20...
# ['wtc', 'ades']
# Evaluation RMSE: 17184.227893568004
# Trying the combination number 21...
# ['wtc', 'adep']
# Evaluation RMSE: 17062.49154074454
# Trying the combination number 22...
# ['wtc', 'altitude_75percentile']
# Evaluation RMSE: 17968.337761890718
# Trying the combination number 23...
# ['wtc', 'altitude_median']
# Evaluation RMSE: 17879.07465925698
# Trying the combination number 24...
# ['flown_distance', 'aircraft_type']
# Evaluation RMSE: 6503.059692245734
# Trying the combination number 25...
# ['flown_distance', 'groundspeed_max']
# Evaluation RMSE: 27167.66814236043
# Trying the combination number 26...
# ['flown_distance', 'airline']
# Evaluation RMSE: 23162.04230152392
# Trying the combination number 27...
# ['flown_distance', 'altitude_max']
# Evaluation RMSE: 23784.67723042289
# Trying the combination number 28...
# ['flown_distance', 'flight_duration']
# Evaluation RMSE: 26971.12916550147
# Trying the combination number 29...
# ['flown_distance', 'latitude_max']
# Evaluation RMSE: 22672.495629147063
# Trying the combination number 30...
# ['flown_distance', 'ades']
# Evaluation RMSE: 21444.074346837966
# Trying the combination number 31...
# ['flown_distance', 'adep']
# Evaluation RMSE: 21530.859141815497
# Trying the combination number 32...
# ['flown_distance', 'altitude_75percentile']
# Evaluation RMSE: 24691.366332832855
# Trying the combination number 33...
# ['flown_distance', 'altitude_median']
# Evaluation RMSE: 25179.31949816017
# Trying the combination number 34...
# ['aircraft_type', 'groundspeed_max']
# Evaluation RMSE: 10714.235672707975
# Trying the combination number 35...
# ['aircraft_type', 'airline']
# Evaluation RMSE: 8117.089391402267
# Trying the combination number 36...
# ['aircraft_type', 'altitude_max']
# Evaluation RMSE: 10270.274487071169
# Trying the combination number 37...
# ['aircraft_type', 'flight_duration']
# Evaluation RMSE: 7185.765089283096
# Trying the combination number 38...
# ['aircraft_type', 'latitude_max']
# Evaluation RMSE: 9129.587929490923
# Trying the combination number 39...
# ['aircraft_type', 'ades']
# Evaluation RMSE: 7848.791316126623
# Trying the combination number 40...
# ['aircraft_type', 'adep']
# Evaluation RMSE: 7721.553074247091
# Trying the combination number 41...
# ['aircraft_type', 'altitude_75percentile']
# Evaluation RMSE: 10144.185751099909
# Trying the combination number 42...
# ['aircraft_type', 'altitude_median']
# Evaluation RMSE: 10023.755655063273
# Trying the combination number 43...
# ['groundspeed_max', 'airline']
# Evaluation RMSE: 39076.95667692413
# Trying the combination number 44...
# ['groundspeed_max', 'altitude_max']
# Evaluation RMSE: 39866.49753106273
# Trying the combination number 45...
# ['groundspeed_max', 'flight_duration']
# Evaluation RMSE: 27844.944322996424
# Trying the combination number 46...
# ['groundspeed_max', 'latitude_max']
# Evaluation RMSE: 39770.74956859043
# Trying the combination number 47...
# ['groundspeed_max', 'ades']
# Evaluation RMSE: 33143.74929914837
# Trying the combination number 48...
# ['groundspeed_max', 'adep']
# Evaluation RMSE: 38043.6007652724
# Trying the combination number 49...
# ['groundspeed_max', 'altitude_75percentile']
# Evaluation RMSE: 42094.9288615171
# Trying the combination number 50...
# ['groundspeed_max', 'altitude_median']
# Evaluation RMSE: 41147.88625279342
# Trying the combination number 51...
# ['airline', 'altitude_max']
# Evaluation RMSE: 37811.43482370052
# Trying the combination number 52...
# ['airline', 'flight_duration']
# Evaluation RMSE: 24762.79108442046
# Trying the combination number 53...
# ['airline', 'latitude_max']
# Evaluation RMSE: 36129.215770901596
# Trying the combination number 54...
# ['airline', 'ades']
# Evaluation RMSE: 33858.559876569976
# Trying the combination number 55...
# ['airline', 'adep']
# Evaluation RMSE: 34187.94120799412
# Trying the combination number 56...
# ['airline', 'altitude_75percentile']
# Evaluation RMSE: 38999.41954879789
# Trying the combination number 57...
# ['airline', 'altitude_median']
# Evaluation RMSE: 38512.84687300413
# Trying the combination number 58...
# ['altitude_max', 'flight_duration']
# Evaluation RMSE: 25120.42060296184
# Trying the combination number 59...
# ['altitude_max', 'latitude_max']
# Evaluation RMSE: 39183.8899231035
# Trying the combination number 60...
# ['altitude_max', 'ades']
# Evaluation RMSE: 31971.738929515122
# Trying the combination number 61...
# ['altitude_max', 'adep']
# Evaluation RMSE: 32537.47542794024
# Trying the combination number 62...
# ['altitude_max', 'altitude_75percentile']
# Evaluation RMSE: 45672.31260073084
# Trying the combination number 63...
# ['altitude_max', 'altitude_median']
# Evaluation RMSE: 42550.76187022513
# Trying the combination number 64...
# ['flight_duration', 'latitude_max']
# Evaluation RMSE: 24356.674005238503
# Trying the combination number 65...
# ['flight_duration', 'ades']
# Evaluation RMSE: 22996.07285236396
# Trying the combination number 66...
# ['flight_duration', 'adep']
# Evaluation RMSE: 23074.627157311275
# Trying the combination number 67...
# ['flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 26069.84145139188
# Trying the combination number 68...
# ['flight_duration', 'altitude_median']
# Evaluation RMSE: 26579.38085874176
# Trying the combination number 69...
# ['latitude_max', 'ades']
# Evaluation RMSE: 31353.153547883925
# Trying the combination number 70...
# ['latitude_max', 'adep']
# Evaluation RMSE: 33172.997315162116
# Trying the combination number 71...
# ['latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 40280.461425950976
# Trying the combination number 72...
# ['latitude_max', 'altitude_median']
# Evaluation RMSE: 38623.698374562555
# Trying the combination number 73...
# ['ades', 'adep']
# Evaluation RMSE: 20139.66149872003
# Trying the combination number 74...
# ['ades', 'altitude_75percentile']
# Evaluation RMSE: 32730.870663343532
# Trying the combination number 75...
# ['ades', 'altitude_median']
# Evaluation RMSE: 31441.87136153869
# Trying the combination number 76...
# ['adep', 'altitude_75percentile']
# Evaluation RMSE: 33630.37066146767
# Trying the combination number 77...
# ['adep', 'altitude_median']
# Evaluation RMSE: 33092.93610617219
# Trying the combination number 78...
# ['altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 45978.484526961
# Trying the combination number 79...
# ['wtc', 'flown_distance', 'aircraft_type']
# Evaluation RMSE: 6507.499493896105
# Trying the combination number 80...
# ['wtc', 'flown_distance', 'groundspeed_max']
# Evaluation RMSE: 15202.35257529962
# Trying the combination number 81...
# ['wtc', 'flown_distance', 'airline']
# Evaluation RMSE: 11371.612418379276
# Trying the combination number 82...
# ['wtc', 'flown_distance', 'altitude_max']
# Evaluation RMSE: 13060.017048368245
# Trying the combination number 83...
# ['wtc', 'flown_distance', 'flight_duration']
# Evaluation RMSE: 14951.391403984126
# Trying the combination number 84...
# ['wtc', 'flown_distance', 'latitude_max']
# Evaluation RMSE: 12887.787707056807
# Trying the combination number 85...
# ['wtc', 'flown_distance', 'ades']
# Evaluation RMSE: 10740.978445256618
# Trying the combination number 86...
# ['wtc', 'flown_distance', 'adep']
# Evaluation RMSE: 10586.186697808738
# Trying the combination number 87...
# ['wtc', 'flown_distance', 'altitude_75percentile']
# Evaluation RMSE: 13406.932351187925
# Trying the combination number 88...
# ['wtc', 'flown_distance', 'altitude_median']
# Evaluation RMSE: 13831.06249557324
# Trying the combination number 89...
# ['wtc', 'aircraft_type', 'groundspeed_max']
# Evaluation RMSE: 10728.261360739582
# Trying the combination number 90...
# ['wtc', 'aircraft_type', 'airline']
# Evaluation RMSE: 8120.340386264888
# Trying the combination number 91...
# ['wtc', 'aircraft_type', 'altitude_max']
# Evaluation RMSE: 10279.202715120604
# Trying the combination number 92...
# ['wtc', 'aircraft_type', 'flight_duration']
# Evaluation RMSE: 7187.33528557969
# Trying the combination number 93...
# ['wtc', 'aircraft_type', 'latitude_max']
# Evaluation RMSE: 9136.30539653056
# Trying the combination number 94...
# ['wtc', 'aircraft_type', 'ades']
# Evaluation RMSE: 7852.715961095229
# Trying the combination number 95...
# ['wtc', 'aircraft_type', 'adep']
# Evaluation RMSE: 7724.386887888978
# Trying the combination number 96...
# ['wtc', 'aircraft_type', 'altitude_75percentile']
# Evaluation RMSE: 10155.809904773809
# Trying the combination number 97...
# ['wtc', 'aircraft_type', 'altitude_median']
# Evaluation RMSE: 10028.578516545213
# Trying the combination number 98...
# ['wtc', 'groundspeed_max', 'airline']
# Evaluation RMSE: 16114.584995991754
# Trying the combination number 99...
# ['wtc', 'groundspeed_max', 'altitude_max']
# Evaluation RMSE: 17258.626652288713
# Trying the combination number 100...
# ['wtc', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 15513.21299327541
# Trying the combination number 101...
# ['wtc', 'groundspeed_max', 'latitude_max']
# Evaluation RMSE: 17370.697591184362
# Trying the combination number 102...
# ['wtc', 'groundspeed_max', 'ades']
# Evaluation RMSE: 15738.533062352193
# Trying the combination number 103...
# ['wtc', 'groundspeed_max', 'adep']
# Evaluation RMSE: 15942.971853693676
# Trying the combination number 104...
# ['wtc', 'groundspeed_max', 'altitude_75percentile']
# Evaluation RMSE: 17693.345202598226
# Trying the combination number 105...
# ['wtc', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 17386.11048522532
# Trying the combination number 106...
# ['wtc', 'airline', 'altitude_max']
# Evaluation RMSE: 12653.790109084672
# Trying the combination number 107...
# ['wtc', 'airline', 'flight_duration']
# Evaluation RMSE: 12329.134855643637
# Trying the combination number 108...
# ['wtc', 'airline', 'latitude_max']
# Evaluation RMSE: 14531.712541883002
# Trying the combination number 109...
# ['wtc', 'airline', 'ades']
# Evaluation RMSE: 13769.52595836916
# Trying the combination number 110...
# ['wtc', 'airline', 'adep']
# Evaluation RMSE: 13813.044087792667
# Trying the combination number 111...
# ['wtc', 'airline', 'altitude_75percentile']
# Evaluation RMSE: 13337.307077168183
# Trying the combination number 112...
# ['wtc', 'airline', 'altitude_median']
# Evaluation RMSE: 13829.59278209869
# Trying the combination number 113...
# ['wtc', 'altitude_max', 'flight_duration']
# Evaluation RMSE: 13532.291280311956
# Trying the combination number 114...
# ['wtc', 'altitude_max', 'latitude_max']
# Evaluation RMSE: 14803.345278264445
# Trying the combination number 115...
# ['wtc', 'altitude_max', 'ades']
# Evaluation RMSE: 13181.878400282681
# Trying the combination number 116...
# ['wtc', 'altitude_max', 'adep']
# Evaluation RMSE: 13077.85824696543
# Trying the combination number 117...
# ['wtc', 'altitude_max', 'altitude_75percentile']
# Evaluation RMSE: 16958.805196393507
# Trying the combination number 118...
# ['wtc', 'altitude_max', 'altitude_median']
# Evaluation RMSE: 16282.4617852582
# Trying the combination number 119...
# ['wtc', 'flight_duration', 'latitude_max']
# Evaluation RMSE: 13790.363725259376
# Trying the combination number 120...
# ['wtc', 'flight_duration', 'ades']
# Evaluation RMSE: 11826.054280113678
# Trying the combination number 121...
# ['wtc', 'flight_duration', 'adep']
# Evaluation RMSE: 11662.311947324704
# Trying the combination number 122...
# ['wtc', 'flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 13929.101497795835
# Trying the combination number 123...
# ['wtc', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 14493.42088668319
# Trying the combination number 124...
# ['wtc', 'latitude_max', 'ades']
# Evaluation RMSE: 14114.167917328246
# Trying the combination number 125...
# ['wtc', 'latitude_max', 'adep']
# Evaluation RMSE: 14233.690866140287
# Trying the combination number 126...
# ['wtc', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 15129.592862093894
# Trying the combination number 127...
# ['wtc', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 15196.991257404343
# Trying the combination number 128...
# ['wtc', 'ades', 'adep']
# Evaluation RMSE: 9339.433468500045
# Trying the combination number 129...
# ['wtc', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 13456.535999658978
# Trying the combination number 130...
# ['wtc', 'ades', 'altitude_median']
# Evaluation RMSE: 13586.015850170064
# Trying the combination number 131...
# ['wtc', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 13539.27154625012
# Trying the combination number 132...
# ['wtc', 'adep', 'altitude_median']
# Evaluation RMSE: 13845.37447168515
# Trying the combination number 133...
# ['wtc', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 16812.233955447544
# Trying the combination number 134...
# ['flown_distance', 'aircraft_type', 'groundspeed_max']
# Evaluation RMSE: 6426.603655552713
# Trying the combination number 135...
# ['flown_distance', 'aircraft_type', 'airline']
# Evaluation RMSE: 4674.826334926265
# Trying the combination number 136...
# ['flown_distance', 'aircraft_type', 'altitude_max']
# Evaluation RMSE: 6096.746744920907
# Trying the combination number 137...
# ['flown_distance', 'aircraft_type', 'flight_duration']
# Evaluation RMSE: 6246.772131553683
# Trying the combination number 138...
# ['flown_distance', 'aircraft_type', 'latitude_max']
# Evaluation RMSE: 5714.474590418881
# Trying the combination number 139...
# ['flown_distance', 'aircraft_type', 'ades']
# Evaluation RMSE: 4384.918864440051
# Trying the combination number 140...
# ['flown_distance', 'aircraft_type', 'adep']
# Evaluation RMSE: 4417.855434242895
# Trying the combination number 141...
# ['flown_distance', 'aircraft_type', 'altitude_75percentile']
# Evaluation RMSE: 5888.075058751437
# Trying the combination number 142...
# ['flown_distance', 'aircraft_type', 'altitude_median']
# Evaluation RMSE: 5883.860162537934
# Trying the combination number 143...
# ['flown_distance', 'groundspeed_max', 'airline']
# Evaluation RMSE: 22533.44557245488
# Trying the combination number 144...
# ['flown_distance', 'groundspeed_max', 'altitude_max']
# Evaluation RMSE: 23031.552145684374
# Trying the combination number 145...
# ['flown_distance', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 26762.964467717593
# Trying the combination number 146...
# ['flown_distance', 'groundspeed_max', 'latitude_max']
# Evaluation RMSE: 22030.077860554058
# Trying the combination number 147...
# ['flown_distance', 'groundspeed_max', 'ades']
# Evaluation RMSE: 20764.18673215814
# Trying the combination number 148...
# ['flown_distance', 'groundspeed_max', 'adep']
# Evaluation RMSE: 20731.844203082062
# Trying the combination number 149...
# ['flown_distance', 'groundspeed_max', 'altitude_75percentile']
# Evaluation RMSE: 23902.332671280037
# Trying the combination number 150...
# ['flown_distance', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 24398.646053192253
# Trying the combination number 151...
# ['flown_distance', 'airline', 'altitude_max']
# Evaluation RMSE: 17623.53849276666
# Trying the combination number 152...
# ['flown_distance', 'airline', 'flight_duration']
# Evaluation RMSE: 22434.800283037508
# Trying the combination number 153...
# ['flown_distance', 'airline', 'latitude_max']
# Evaluation RMSE: 20317.097610433088
# Trying the combination number 154...
# ['flown_distance', 'airline', 'ades']
# Evaluation RMSE: 20474.441296722274
# Trying the combination number 155...
# ['flown_distance', 'airline', 'adep']
# Evaluation RMSE: 20715.013447935973
# Trying the combination number 156...
# ['flown_distance', 'airline', 'altitude_75percentile']
# Evaluation RMSE: 18144.80001720181
# Trying the combination number 157...
# ['flown_distance', 'airline', 'altitude_median']
# Evaluation RMSE: 19149.89775046087
# Trying the combination number 158...
# ['flown_distance', 'altitude_max', 'flight_duration']
# Evaluation RMSE: 23091.082186679956
# Trying the combination number 159...
# ['flown_distance', 'altitude_max', 'latitude_max']
# Evaluation RMSE: 18158.305838662855
# Trying the combination number 160...
# ['flown_distance', 'altitude_max', 'ades']
# Evaluation RMSE: 16090.217980035328
# Trying the combination number 161...
# ['flown_distance', 'altitude_max', 'adep']
# Evaluation RMSE: 16260.536373427807
# Trying the combination number 162...
# ['flown_distance', 'altitude_max', 'altitude_75percentile']
# Evaluation RMSE: 23070.468860605706
# Trying the combination number 163...
# ['flown_distance', 'altitude_max', 'altitude_median']
# Evaluation RMSE: 22810.149094929544
# Trying the combination number 164...
# ['flown_distance', 'flight_duration', 'latitude_max']
# Evaluation RMSE: 21960.066120938394
# Trying the combination number 165...
# ['flown_distance', 'flight_duration', 'ades']
# Evaluation RMSE: 20601.898014736867
# Trying the combination number 166...
# ['flown_distance', 'flight_duration', 'adep']
# Evaluation RMSE: 20736.796115363162
# Trying the combination number 167...
# ['flown_distance', 'flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 23907.46075800837
# Trying the combination number 168...
# ['flown_distance', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 24419.414871677334
# Trying the combination number 169...
# ['flown_distance', 'latitude_max', 'ades']
# Evaluation RMSE: 19606.56255042209
# Trying the combination number 170...
# ['flown_distance', 'latitude_max', 'adep']
# Evaluation RMSE: 19554.41913395759
# Trying the combination number 171...
# ['flown_distance', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 18596.99026995436
# Trying the combination number 172...
# ['flown_distance', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 19336.763272677304
# Trying the combination number 173...
# ['flown_distance', 'ades', 'adep']
# Evaluation RMSE: 18888.252384888332
# Trying the combination number 174...
# ['flown_distance', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 16590.368336364118
# Trying the combination number 175...
# ['flown_distance', 'ades', 'altitude_median']
# Evaluation RMSE: 17422.081274035645
# Trying the combination number 176...
# ['flown_distance', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 16777.590325971338
# Trying the combination number 177...
# ['flown_distance', 'adep', 'altitude_median']
# Evaluation RMSE: 17721.806704658302
# Trying the combination number 178...
# ['flown_distance', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 23841.647436727813
# Trying the combination number 179...
# ['aircraft_type', 'groundspeed_max', 'airline']
# Evaluation RMSE: 7804.321934627034
# Trying the combination number 180...
# ['aircraft_type', 'groundspeed_max', 'altitude_max']
# Evaluation RMSE: 10177.29012084896
# Trying the combination number 181...
# ['aircraft_type', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 7078.234497535309
# Trying the combination number 182...
# ['aircraft_type', 'groundspeed_max', 'latitude_max']
# Evaluation RMSE: 8990.673696798913
# Trying the combination number 183...
# ['aircraft_type', 'groundspeed_max', 'ades']
# Evaluation RMSE: 7201.8201533926285
# Trying the combination number 184...
# ['aircraft_type', 'groundspeed_max', 'adep']
# Evaluation RMSE: 7565.615462615461
# Trying the combination number 185...
# ['aircraft_type', 'groundspeed_max', 'altitude_75percentile']
# Evaluation RMSE: 10020.508002175047
# Trying the combination number 186...
# ['aircraft_type', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 9924.838385178822
# Trying the combination number 187...
# ['aircraft_type', 'airline', 'altitude_max']
# Evaluation RMSE: 7165.935006371521
# Trying the combination number 188...
# ['aircraft_type', 'airline', 'flight_duration']
# Evaluation RMSE: 4618.974955407495
# Trying the combination number 189...
# ['aircraft_type', 'airline', 'latitude_max']
# Evaluation RMSE: 6387.931419376585
# Trying the combination number 190...
# ['aircraft_type', 'airline', 'ades']
# Evaluation RMSE: 6550.856763161595
# Trying the combination number 191...
# ['aircraft_type', 'airline', 'adep']
# Evaluation RMSE: 6461.736318066386
# Trying the combination number 192...
# ['aircraft_type', 'airline', 'altitude_75percentile']
# Evaluation RMSE: 6884.503611312311
# Trying the combination number 193...
# ['aircraft_type', 'airline', 'altitude_median']
# Evaluation RMSE: 6815.486332948232
# Trying the combination number 194...
# ['aircraft_type', 'altitude_max', 'flight_duration']
# Evaluation RMSE: 6684.931072382169
# Trying the combination number 195...
# ['aircraft_type', 'altitude_max', 'latitude_max']
# Evaluation RMSE: 8620.454512645874
# Trying the combination number 196...
# ['aircraft_type', 'altitude_max', 'ades']
# Evaluation RMSE: 6939.205985455516
# Trying the combination number 197...
# ['aircraft_type', 'altitude_max', 'adep']
# Evaluation RMSE: 6951.491230010403
# Trying the combination number 198...
# ['aircraft_type', 'altitude_max', 'altitude_75percentile']
# Evaluation RMSE: 9932.883145559243
# Trying the combination number 199...
# ['aircraft_type', 'altitude_max', 'altitude_median']
# Evaluation RMSE: 9657.3749718434
# Trying the combination number 200...
# ['aircraft_type', 'flight_duration', 'latitude_max']
# Evaluation RMSE: 6490.895829139631
# Trying the combination number 201...
# ['aircraft_type', 'flight_duration', 'ades']
# Evaluation RMSE: 4568.85471016093
# Trying the combination number 202...
# ['aircraft_type', 'flight_duration', 'adep']
# Evaluation RMSE: 4652.5046317051465
# Trying the combination number 203...
# ['aircraft_type', 'flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 6430.515447416237
# Trying the combination number 204...
# ['aircraft_type', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 6497.753151433236
# Trying the combination number 205...
# ['aircraft_type', 'latitude_max', 'ades']
# Evaluation RMSE: 6317.100502712361
# Trying the combination number 206...
# ['aircraft_type', 'latitude_max', 'adep']
# Evaluation RMSE: 6202.3792094109185
# Trying the combination number 207...
# ['aircraft_type', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 8435.51018641836
# Trying the combination number 208...
# ['aircraft_type', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 8369.135795726388
# Trying the combination number 209...
# ['aircraft_type', 'ades', 'adep']
# Evaluation RMSE: 4278.38280618078
# Trying the combination number 210...
# ['aircraft_type', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 6623.066166505421
# Trying the combination number 211...
# ['aircraft_type', 'ades', 'altitude_median']
# Evaluation RMSE: 6572.95021497906
# Trying the combination number 212...
# ['aircraft_type', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 6717.581777563527
# Trying the combination number 213...
# ['aircraft_type', 'adep', 'altitude_median']
# Evaluation RMSE: 6715.545551914004
# Trying the combination number 214...
# ['aircraft_type', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 9761.452797899476
# Trying the combination number 215...
# ['groundspeed_max', 'airline', 'altitude_max']
# Evaluation RMSE: 31771.45039338157
# Trying the combination number 216...
# ['groundspeed_max', 'airline', 'flight_duration']
# Evaluation RMSE: 23724.128043457316
# Trying the combination number 217...
# ['groundspeed_max', 'airline', 'latitude_max']
# Evaluation RMSE: 31898.390338405326
# Trying the combination number 218...
# ['groundspeed_max', 'airline', 'ades']
# Evaluation RMSE: 27531.993173544208
# Trying the combination number 219...
# ['groundspeed_max', 'airline', 'adep']
# Evaluation RMSE: 32051.044709582016
# Trying the combination number 220...
# ['groundspeed_max', 'airline', 'altitude_75percentile']
# Evaluation RMSE: 33601.18197553514
# Trying the combination number 221...
# ['groundspeed_max', 'airline', 'altitude_median']
# Evaluation RMSE: 33303.43500053853
# Trying the combination number 222...
# ['groundspeed_max', 'altitude_max', 'flight_duration']
# Evaluation RMSE: 23987.53235256717
# Trying the combination number 223...
# ['groundspeed_max', 'altitude_max', 'latitude_max']
# Evaluation RMSE: 33667.09167334608
# Trying the combination number 224...
# ['groundspeed_max', 'altitude_max', 'ades']
# Evaluation RMSE: 25805.574198181217
# Trying the combination number 225...
# ['groundspeed_max', 'altitude_max', 'adep']
# Evaluation RMSE: 29388.05054096949
# Trying the combination number 226...
# ['groundspeed_max', 'altitude_max', 'altitude_75percentile']
# Evaluation RMSE: 38657.56351860069
# Trying the combination number 227...
# ['groundspeed_max', 'altitude_max', 'altitude_median']
# Evaluation RMSE: 36884.01599518229
# Trying the combination number 228...
# ['groundspeed_max', 'flight_duration', 'latitude_max']
# Evaluation RMSE: 23396.05815842505
# Trying the combination number 229...
# ['groundspeed_max', 'flight_duration', 'ades']
# Evaluation RMSE: 22060.097647531566
# Trying the combination number 230...
# ['groundspeed_max', 'flight_duration', 'adep']
# Evaluation RMSE: 22005.497858445626
# Trying the combination number 231...
# ['groundspeed_max', 'flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 24893.44841556276
# Trying the combination number 232...
# ['groundspeed_max', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 25335.293755161736
# Trying the combination number 233...
# ['groundspeed_max', 'latitude_max', 'ades']
# Evaluation RMSE: 26933.848165378964
# Trying the combination number 234...
# ['groundspeed_max', 'latitude_max', 'adep']
# Evaluation RMSE: 30848.060491317305
# Trying the combination number 235...
# ['groundspeed_max', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 34997.90132861661
# Trying the combination number 236...
# ['groundspeed_max', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 34283.13217228198
# Trying the combination number 237...
# ['groundspeed_max', 'ades', 'adep']
# Evaluation RMSE: 19317.192904097887
# Trying the combination number 238...
# ['groundspeed_max', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 26949.520922693075
# Trying the combination number 239...
# ['groundspeed_max', 'ades', 'altitude_median']
# Evaluation RMSE: 26476.772244619966
# Trying the combination number 240...
# ['groundspeed_max', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 30701.228319443395
# Trying the combination number 241...
# ['groundspeed_max', 'adep', 'altitude_median']
# Evaluation RMSE: 30582.327314704617
# Trying the combination number 242...
# ['groundspeed_max', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 39556.18717895066
# Trying the combination number 243...
# ['airline', 'altitude_max', 'flight_duration']
# Evaluation RMSE: 19315.8855954235
# Trying the combination number 244...
# ['airline', 'altitude_max', 'latitude_max']
# Evaluation RMSE: 29374.933919688843
# Trying the combination number 245...
# ['airline', 'altitude_max', 'ades']
# Evaluation RMSE: 26655.308779335202
# Trying the combination number 246...
# ['airline', 'altitude_max', 'adep']
# Evaluation RMSE: 27438.120032570976
# Trying the combination number 247...
# ['airline', 'altitude_max', 'altitude_75percentile']
# Evaluation RMSE: 35879.726943256435
# Trying the combination number 248...
# ['airline', 'altitude_max', 'altitude_median']
# Evaluation RMSE: 33545.69468715506
# Trying the combination number 249...
# ['airline', 'flight_duration', 'latitude_max']
# Evaluation RMSE: 21821.702388008838
# Trying the combination number 250...
# ['airline', 'flight_duration', 'ades']
# Evaluation RMSE: 21340.7073553112
# Trying the combination number 251...
# ['airline', 'flight_duration', 'adep']
# Evaluation RMSE: 21712.818766181303
# Trying the combination number 252...
# ['airline', 'flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 19810.98382544641
# Trying the combination number 253...
# ['airline', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 20749.241365616737
# Trying the combination number 254...
# ['airline', 'latitude_max', 'ades']
# Evaluation RMSE: 26622.073209129758
# Trying the combination number 255...
# ['airline', 'latitude_max', 'adep']
# Evaluation RMSE: 28433.528805688038
# Trying the combination number 256...
# ['airline', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 29725.106484211585
# Trying the combination number 257...
# ['airline', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 29277.766824507955
# Trying the combination number 258...
# ['airline', 'ades', 'adep']
# Evaluation RMSE: 19934.03547537091
# Trying the combination number 259...
# ['airline', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 26934.426718086484
# Trying the combination number 260...
# ['airline', 'ades', 'altitude_median']
# Evaluation RMSE: 26257.145528816694
# Trying the combination number 261...
# ['airline', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 28239.23385170652
# Trying the combination number 262...
# ['airline', 'adep', 'altitude_median']
# Evaluation RMSE: 28046.34484333836
# Trying the combination number 263...
# ['airline', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 36141.048869383936
# Trying the combination number 264...
# ['altitude_max', 'flight_duration', 'latitude_max']
# Evaluation RMSE: 19807.8550330061
# Trying the combination number 265...
# ['altitude_max', 'flight_duration', 'ades']
# Evaluation RMSE: 17789.25567377635
# Trying the combination number 266...
# ['altitude_max', 'flight_duration', 'adep']
# Evaluation RMSE: 17724.651603418682
# Trying the combination number 267...
# ['altitude_max', 'flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 24427.537302500004
# Trying the combination number 268...
# ['altitude_max', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 24190.485732112127
# Trying the combination number 269...
# ['altitude_max', 'latitude_max', 'ades']
# Evaluation RMSE: 24775.046298456084
# Trying the combination number 270...
# ['altitude_max', 'latitude_max', 'adep']
# Evaluation RMSE: 26623.92435838246
# Trying the combination number 271...
# ['altitude_max', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 37100.44753859862
# Trying the combination number 272...
# ['altitude_max', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 34615.705832337946
# Trying the combination number 273...
# ['altitude_max', 'ades', 'adep']
# Evaluation RMSE: 14615.81058692617
# Trying the combination number 274...
# ['altitude_max', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 29299.17206469549
# Trying the combination number 275...
# ['altitude_max', 'ades', 'altitude_median']
# Evaluation RMSE: 27109.13264005941
# Trying the combination number 276...
# ['altitude_max', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 30358.826242572326
# Trying the combination number 277...
# ['altitude_max', 'adep', 'altitude_median']
# Evaluation RMSE: 28233.19098570742
# Trying the combination number 278...
# ['altitude_max', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 42109.58013341006
# Trying the combination number 279...
# ['flight_duration', 'latitude_max', 'ades']
# Evaluation RMSE: 20575.936685467987
# Trying the combination number 280...
# ['flight_duration', 'latitude_max', 'adep']
# Evaluation RMSE: 20601.036984503186
# Trying the combination number 281...
# ['flight_duration', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 20397.563123627097
# Trying the combination number 282...
# ['flight_duration', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 21052.56735695827
# Trying the combination number 283...
# ['flight_duration', 'ades', 'adep']
# Evaluation RMSE: 18460.68160801797
# Trying the combination number 284...
# ['flight_duration', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 18457.141494449057
# Trying the combination number 285...
# ['flight_duration', 'ades', 'altitude_median']
# Evaluation RMSE: 19167.81978953713
# Trying the combination number 286...
# ['flight_duration', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 18260.462568652034
# Trying the combination number 287...
# ['flight_duration', 'adep', 'altitude_median']
# Evaluation RMSE: 19364.549353168633
# Trying the combination number 288...
# ['flight_duration', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 25259.998074525905
# Trying the combination number 289...
# ['latitude_max', 'ades', 'adep']
# Evaluation RMSE: 18955.576831687184
# Trying the combination number 290...
# ['latitude_max', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 24994.469918567458
# Trying the combination number 291...
# ['latitude_max', 'ades', 'altitude_median']
# Evaluation RMSE: 24851.94315663534
# Trying the combination number 292...
# ['latitude_max', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 26532.07132287385
# Trying the combination number 293...
# ['latitude_max', 'adep', 'altitude_median']
# Evaluation RMSE: 26335.311816270285
# Trying the combination number 294...
# ['latitude_max', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 36969.5329085018
# Trying the combination number 295...
# ['ades', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 15127.164270072602
# Trying the combination number 296...
# ['ades', 'adep', 'altitude_median']
# Evaluation RMSE: 16020.739504909076
# Trying the combination number 297...
# ['ades', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 29107.56063186725
# Trying the combination number 298...
# ['adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 30340.419164358096
# Trying the combination number 299...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max']
# Evaluation RMSE: 6439.312649874511
# Trying the combination number 300...
# ['wtc', 'flown_distance', 'aircraft_type', 'airline']
# Evaluation RMSE: 4679.574826393297
# Trying the combination number 301...
# ['wtc', 'flown_distance', 'aircraft_type', 'altitude_max']
# Evaluation RMSE: 6108.61945353274
# Trying the combination number 302...
# ['wtc', 'flown_distance', 'aircraft_type', 'flight_duration']
# Evaluation RMSE: 6254.092939049585
# Trying the combination number 303...
# ['wtc', 'flown_distance', 'aircraft_type', 'latitude_max']
# Evaluation RMSE: 5715.924018092832
# Trying the combination number 304...
# ['wtc', 'flown_distance', 'aircraft_type', 'ades']
# Evaluation RMSE: 4395.088640625215
# Trying the combination number 305...
# ['wtc', 'flown_distance', 'aircraft_type', 'adep']
# Evaluation RMSE: 4424.354795326616
# Trying the combination number 306...
# ['wtc', 'flown_distance', 'aircraft_type', 'altitude_75percentile']
# Evaluation RMSE: 5893.4658289889085
# Trying the combination number 307...
# ['wtc', 'flown_distance', 'aircraft_type', 'altitude_median']
# Evaluation RMSE: 5886.75744331264
# Trying the combination number 308...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline']
# Evaluation RMSE: 10987.945400276081
# Trying the combination number 309...
# ['wtc', 'flown_distance', 'groundspeed_max', 'altitude_max']
# Evaluation RMSE: 12816.534231153868
# Trying the combination number 310...
# ['wtc', 'flown_distance', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 14863.005144910196
# Trying the combination number 311...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_max']
# Evaluation RMSE: 12603.573941191631
# Trying the combination number 312...
# ['wtc', 'flown_distance', 'groundspeed_max', 'ades']
# Evaluation RMSE: 10559.656172124232
# Trying the combination number 313...
# ['wtc', 'flown_distance', 'groundspeed_max', 'adep']
# Evaluation RMSE: 10367.439112312748
# Trying the combination number 314...
# ['wtc', 'flown_distance', 'groundspeed_max', 'altitude_75percentile']
# Evaluation RMSE: 13129.438922101393
# Trying the combination number 315...
# ['wtc', 'flown_distance', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 13314.776211624587
# Trying the combination number 316...
# ['wtc', 'flown_distance', 'airline', 'altitude_max']
# Evaluation RMSE: 8375.475208469701
# Trying the combination number 317...
# ['wtc', 'flown_distance', 'airline', 'flight_duration']
# Evaluation RMSE: 10808.058497523169
# Trying the combination number 318...
# ['wtc', 'flown_distance', 'airline', 'latitude_max']
# Evaluation RMSE: 10081.488379974415
# Trying the combination number 319...
# ['wtc', 'flown_distance', 'airline', 'ades']
# Evaluation RMSE: 9580.195989599124
# Trying the combination number 320...
# ['wtc', 'flown_distance', 'airline', 'adep']
# Evaluation RMSE: 9528.18721176256
# Trying the combination number 321...
# ['wtc', 'flown_distance', 'airline', 'altitude_75percentile']
# Evaluation RMSE: 9011.573611327958
# Trying the combination number 322...
# ['wtc', 'flown_distance', 'airline', 'altitude_median']
# Evaluation RMSE: 9606.456283197016
# Trying the combination number 323...
# ['wtc', 'flown_distance', 'altitude_max', 'flight_duration']
# Evaluation RMSE: 12648.748154309722
# Trying the combination number 324...
# ['wtc', 'flown_distance', 'altitude_max', 'latitude_max']
# Evaluation RMSE: 10655.293850373086
# Trying the combination number 325...
# ['wtc', 'flown_distance', 'altitude_max', 'ades']
# Evaluation RMSE: 8611.227644539678
# Trying the combination number 326...
# ['wtc', 'flown_distance', 'altitude_max', 'adep']
# Evaluation RMSE: 8436.96517657053
# Trying the combination number 327...
# ['wtc', 'flown_distance', 'altitude_max', 'altitude_75percentile']
# Evaluation RMSE: 12458.384550199045
# Trying the combination number 328...
# ['wtc', 'flown_distance', 'altitude_max', 'altitude_median']
# Evaluation RMSE: 12213.90446276476
# Trying the combination number 329...
# ['wtc', 'flown_distance', 'flight_duration', 'latitude_max']
# Evaluation RMSE: 12427.818382275407
# Trying the combination number 330...
# ['wtc', 'flown_distance', 'flight_duration', 'ades']
# Evaluation RMSE: 10399.30396354521
# Trying the combination number 331...
# ['wtc', 'flown_distance', 'flight_duration', 'adep']
# Evaluation RMSE: 10203.893260856705
# Trying the combination number 332...
# ['wtc', 'flown_distance', 'flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 12959.729130927137
# Trying the combination number 333...
# ['wtc', 'flown_distance', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 13232.899827449475
# Trying the combination number 334...
# ['wtc', 'flown_distance', 'latitude_max', 'ades']
# Evaluation RMSE: 9868.592426084908
# Trying the combination number 335...
# ['wtc', 'flown_distance', 'latitude_max', 'adep']
# Evaluation RMSE: 9664.040649950384
# Trying the combination number 336...
# ['wtc', 'flown_distance', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 10850.196349745209
# Trying the combination number 337...
# ['wtc', 'flown_distance', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 11103.35277424714
# Trying the combination number 338...
# ['wtc', 'flown_distance', 'ades', 'adep']
# Evaluation RMSE: 8792.102194812143
# Trying the combination number 339...
# ['wtc', 'flown_distance', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 8915.761868589427
# Trying the combination number 340...
# ['wtc', 'flown_distance', 'ades', 'altitude_median']
# Evaluation RMSE: 9238.410181034333
# Trying the combination number 341...
# ['wtc', 'flown_distance', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 8749.498558014793
# Trying the combination number 342...
# ['wtc', 'flown_distance', 'adep', 'altitude_median']
# Evaluation RMSE: 9165.861519488933
# Trying the combination number 343...
# ['wtc', 'flown_distance', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 12616.59937359448
# Trying the combination number 344...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline']
# Evaluation RMSE: 7817.704355481016
# Trying the combination number 345...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'altitude_max']
# Evaluation RMSE: 10195.132894373306
# Trying the combination number 346...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 7090.624821939498
# Trying the combination number 347...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_max']
# Evaluation RMSE: 8985.291051242131
# Trying the combination number 348...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'ades']
# Evaluation RMSE: 7210.821431529024
# Trying the combination number 349...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'adep']
# Evaluation RMSE: 7554.531795236345
# Trying the combination number 350...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'altitude_75percentile']
# Evaluation RMSE: 10040.614843681893
# Trying the combination number 351...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 9935.882475825229
# Trying the combination number 352...
# ['wtc', 'aircraft_type', 'airline', 'altitude_max']
# Evaluation RMSE: 7179.905995910213
# Trying the combination number 353...
# ['wtc', 'aircraft_type', 'airline', 'flight_duration']
# Evaluation RMSE: 4622.230947335075
# Trying the combination number 354...
# ['wtc', 'aircraft_type', 'airline', 'latitude_max']
# Evaluation RMSE: 6385.597086448482
# Trying the combination number 355...
# ['wtc', 'aircraft_type', 'airline', 'ades']
# Evaluation RMSE: 6558.716573475423
# Trying the combination number 356...
# ['wtc', 'aircraft_type', 'airline', 'adep']
# Evaluation RMSE: 6468.834678108327
# Trying the combination number 357...
# ['wtc', 'aircraft_type', 'airline', 'altitude_75percentile']
# Evaluation RMSE: 6901.753622513126
# Trying the combination number 358...
# ['wtc', 'aircraft_type', 'airline', 'altitude_median']
# Evaluation RMSE: 6836.291648961167
# Trying the combination number 359...
# ['wtc', 'aircraft_type', 'altitude_max', 'flight_duration']
# Evaluation RMSE: 6678.7986102867135
# Trying the combination number 360...
# ['wtc', 'aircraft_type', 'altitude_max', 'latitude_max']
# Evaluation RMSE: 8627.790996275164
# Trying the combination number 361...
# ['wtc', 'aircraft_type', 'altitude_max', 'ades']
# Evaluation RMSE: 6958.095456787972
# Trying the combination number 362...
# ['wtc', 'aircraft_type', 'altitude_max', 'adep']
# Evaluation RMSE: 6959.852703054235
# Trying the combination number 363...
# ['wtc', 'aircraft_type', 'altitude_max', 'altitude_75percentile']
# Evaluation RMSE: 9954.30571278995
# Trying the combination number 364...
# ['wtc', 'aircraft_type', 'altitude_max', 'altitude_median']
# Evaluation RMSE: 9678.752114873072
# Trying the combination number 365...
# ['wtc', 'aircraft_type', 'flight_duration', 'latitude_max']
# Evaluation RMSE: 6494.563432450061
# Trying the combination number 366...
# ['wtc', 'aircraft_type', 'flight_duration', 'ades']
# Evaluation RMSE: 4567.082962302705
# Trying the combination number 367...
# ['wtc', 'aircraft_type', 'flight_duration', 'adep']
# Evaluation RMSE: 4649.354990384139
# Trying the combination number 368...
# ['wtc', 'aircraft_type', 'flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 6434.406745000542
# Trying the combination number 369...
# ['wtc', 'aircraft_type', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 6502.224695903831
# Trying the combination number 370...
# ['wtc', 'aircraft_type', 'latitude_max', 'ades']
# Evaluation RMSE: 6304.1260023089735
# Trying the combination number 371...
# ['wtc', 'aircraft_type', 'latitude_max', 'adep']
# Evaluation RMSE: 6192.552351130852
# Trying the combination number 372...
# ['wtc', 'aircraft_type', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 8446.903791362882
# Trying the combination number 373...
# ['wtc', 'aircraft_type', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 8352.548242485916
# Trying the combination number 374...
# ['wtc', 'aircraft_type', 'ades', 'adep']
# Evaluation RMSE: 4280.275286656096
# Trying the combination number 375...
# ['wtc', 'aircraft_type', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 6635.690433721803
# Trying the combination number 376...
# ['wtc', 'aircraft_type', 'ades', 'altitude_median']
# Evaluation RMSE: 6572.0820045058035
# Trying the combination number 377...
# ['wtc', 'aircraft_type', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 6736.352391099802
# Trying the combination number 378...
# ['wtc', 'aircraft_type', 'adep', 'altitude_median']
# Evaluation RMSE: 6696.00879958012
# Trying the combination number 379...
# ['wtc', 'aircraft_type', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 9775.878133539367
# Trying the combination number 380...
# ['wtc', 'groundspeed_max', 'airline', 'altitude_max']
# Evaluation RMSE: 11923.392440431053
# Trying the combination number 381...
# ['wtc', 'groundspeed_max', 'airline', 'flight_duration']
# Evaluation RMSE: 11672.484109087409
# Trying the combination number 382...
# ['wtc', 'groundspeed_max', 'airline', 'latitude_max']
# Evaluation RMSE: 13769.936607960432
# Trying the combination number 383...
# ['wtc', 'groundspeed_max', 'airline', 'ades']
# Evaluation RMSE: 12345.754979577925
# Trying the combination number 384...
# ['wtc', 'groundspeed_max', 'airline', 'adep']
# Evaluation RMSE: 12782.408542524106
# Trying the combination number 385...
# ['wtc', 'groundspeed_max', 'airline', 'altitude_75percentile']
# Evaluation RMSE: 12669.029118416802
# Trying the combination number 386...
# ['wtc', 'groundspeed_max', 'airline', 'altitude_median']
# Evaluation RMSE: 13029.145648823936
# Trying the combination number 387...
# ['wtc', 'groundspeed_max', 'altitude_max', 'flight_duration']
# Evaluation RMSE: 13294.757548247653
# Trying the combination number 388...
# ['wtc', 'groundspeed_max', 'altitude_max', 'latitude_max']
# Evaluation RMSE: 14571.037618825554
# Trying the combination number 389...
# ['wtc', 'groundspeed_max', 'altitude_max', 'ades']
# Evaluation RMSE: 12514.92748193225
# Trying the combination number 390...
# ['wtc', 'groundspeed_max', 'altitude_max', 'adep']
# Evaluation RMSE: 12800.170382871423
# Trying the combination number 391...
# ['wtc', 'groundspeed_max', 'altitude_max', 'altitude_75percentile']
# Evaluation RMSE: 16735.310685886132
# Trying the combination number 392...
# ['wtc', 'groundspeed_max', 'altitude_max', 'altitude_median']
# Evaluation RMSE: 16060.667034991411
# Trying the combination number 393...
# ['wtc', 'groundspeed_max', 'flight_duration', 'latitude_max']
# Evaluation RMSE: 13288.047055295108
# Trying the combination number 394...
# ['wtc', 'groundspeed_max', 'flight_duration', 'ades']
# Evaluation RMSE: 11348.309399423166
# Trying the combination number 395...
# ['wtc', 'groundspeed_max', 'flight_duration', 'adep']
# Evaluation RMSE: 11175.68533121449
# Trying the combination number 396...
# ['wtc', 'groundspeed_max', 'flight_duration', 'altitude_75percentile']
# Evaluation RMSE: 13585.867011143999
# Trying the combination number 397...
# ['wtc', 'groundspeed_max', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 13791.722847246172
# Trying the combination number 398...
# ['wtc', 'groundspeed_max', 'latitude_max', 'ades']
# Evaluation RMSE: 13518.938862967241
# Trying the combination number 399...
# ['wtc', 'groundspeed_max', 'latitude_max', 'adep']
# Evaluation RMSE: 13581.363320581522
# Trying the combination number 400...
# ['wtc', 'groundspeed_max', 'latitude_max', 'altitude_75percentile']
# Evaluation RMSE: 14907.66939738138
# Trying the combination number 401...
# ['wtc', 'groundspeed_max', 'latitude_max', 'altitude_median']
# Evaluation RMSE: 14813.642825558956
# Trying the combination number 402...
# ['wtc', 'groundspeed_max', 'ades', 'adep']
# Evaluation RMSE: 9068.95925562315
# Trying the combination number 403...
# ['wtc', 'groundspeed_max', 'ades', 'altitude_75percentile']
# Evaluation RMSE: 12849.033598207885
# Trying the combination number 404...
# ['wtc', 'groundspeed_max', 'ades', 'altitude_median']
# Evaluation RMSE: 12875.343182467468
# Trying the combination number 405...
# ['wtc', 'groundspeed_max', 'adep', 'altitude_75percentile']
# ...
# Evaluation RMSE: 3711.3520942464825
# Trying the combination number 4027...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'latitude_max', 'ades', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 3681.50826478917
# Trying the combination number 4028...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'latitude_max', 'ades', 'adep', 'altitude_median']
# Evaluation RMSE: 3656.856262536032
# Trying the combination number 4029...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'latitude_max', 'ades', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3666.9413453583147
# Trying the combination number 4030...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'latitude_max', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3681.67486367788
# Trying the combination number 4031...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3623.8344237461606
# Trying the combination number 4032...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 3691.4507899417185
# Trying the combination number 4033...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_median']
# Evaluation RMSE: 3746.6636831869323
# Trying the combination number 4034...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'flight_duration', 'latitude_max', 'ades', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3677.1792354472086
# Trying the combination number 4035...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'flight_duration', 'latitude_max', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3682.9744466356938
# Trying the combination number 4036...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'flight_duration', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3625.5620855534703
# Trying the combination number 4037...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3607.83487875862
# Trying the combination number 4038...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 3707.86643171204
# Trying the combination number 4039...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_median']
# Evaluation RMSE: 3682.3097896251506
# Trying the combination number 4040...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3864.1997717427607
# Trying the combination number 4041...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'altitude_max', 'flight_duration', 'latitude_max', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3851.407333748106
# Trying the combination number 4042...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'altitude_max', 'flight_duration', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3648.2727028239683
# Trying the combination number 4043...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'altitude_max', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3644.4412951362006
# Trying the combination number 4044...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3628.3363087157795
# Trying the combination number 4045...
# ['wtc', 'flown_distance', 'aircraft_type', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 3673.186380826619
# Trying the combination number 4046...
# ['wtc', 'flown_distance', 'aircraft_type', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_median']
# Evaluation RMSE: 3642.2665252565116
# Trying the combination number 4047...
# ['wtc', 'flown_distance', 'aircraft_type', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3655.4120718972736
# Trying the combination number 4048...
# ['wtc', 'flown_distance', 'aircraft_type', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3670.2990253465837
# Trying the combination number 4049...
# ['wtc', 'flown_distance', 'aircraft_type', 'airline', 'altitude_max', 'flight_duration', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3603.110236132245
# Trying the combination number 4050...
# ['wtc', 'flown_distance', 'aircraft_type', 'airline', 'altitude_max', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3602.537607634549
# Trying the combination number 4051...
# ['wtc', 'flown_distance', 'aircraft_type', 'airline', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3587.7802303150274
# Trying the combination number 4052...
# ['wtc', 'flown_distance', 'aircraft_type', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3625.4066858347937
# Trying the combination number 4053...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 6533.977948866207
# Trying the combination number 4054...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_median']
# Evaluation RMSE: 6456.013944490635
# Trying the combination number 4055...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 6667.5065599109175
# Trying the combination number 4056...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 6708.754583620354
# Trying the combination number 4057...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 6425.818561883837
# Trying the combination number 4058...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline', 'altitude_max', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 6407.459811922962
# Trying the combination number 4059...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 6740.263557863797
# Trying the combination number 4060...
# ['wtc', 'flown_distance', 'groundspeed_max', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 6641.509372451122
# Trying the combination number 4061...
# ['wtc', 'flown_distance', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 6404.014565474856
# Trying the combination number 4062...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 3694.2335068976104
# Trying the combination number 4063...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_median']
# Evaluation RMSE: 3672.353831010211
# Trying the combination number 4064...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3712.1596678486494
# Trying the combination number 4065...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3720.044371413489
# Trying the combination number 4066...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3639.854726281932
# Trying the combination number 4067...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3870.5357189979827
# Trying the combination number 4068...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3634.369077551078
# Trying the combination number 4069...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3658.070706993603
# Trying the combination number 4070...
# ['wtc', 'aircraft_type', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3624.9326677867098
# Trying the combination number 4071...
# ['wtc', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 6503.938624066393
# Trying the combination number 4072...
# ['flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 3689.662564143239
# Trying the combination number 4073...
# ['flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_median']
# Evaluation RMSE: 3665.236001113626
# Trying the combination number 4074...
# ['flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3665.6399086176684
# Trying the combination number 4075...
# ['flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3690.577997190429
# Trying the combination number 4076...
# ['flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3633.8709583086743
# Trying the combination number 4077...
# ['flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3621.157285144525
# Trying the combination number 4078...
# ['flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3626.6448481409475
# Trying the combination number 4079...
# ['flown_distance', 'aircraft_type', 'groundspeed_max', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3665.900293543927
# Trying the combination number 4080...
# ['flown_distance', 'aircraft_type', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3617.4093104810577
# Trying the combination number 4081...
# ['flown_distance', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 12226.903409617853
# Trying the combination number 4082...
# ['aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3645.018066499519
# Trying the combination number 4083...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile']
# Evaluation RMSE: 3682.788535922445
# Trying the combination number 4084...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_median']
# Evaluation RMSE: 3650.1368415261127
# Trying the combination number 4085...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3663.3671571443415
# Trying the combination number 4086...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3672.549873112677
# Trying the combination number 4087...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3621.961876725545
# Trying the combination number 4088...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3610.809737332896
# Trying the combination number 4089...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3607.016646185702
# Trying the combination number 4090...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3636.1573613290384
# Trying the combination number 4091...
# ['wtc', 'flown_distance', 'aircraft_type', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3592.136086263665
# Trying the combination number 4092...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 6392.716516007903
# Trying the combination number 4093...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3621.256753300471
# Trying the combination number 4094...
# ['flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3616.743530338525
# Trying the combination number 4095...
# ['wtc', 'flown_distance', 'aircraft_type', 'groundspeed_max', 'airline', 'altitude_max', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']
# Evaluation RMSE: 3606.897258806947

# %%
print(f"Minimum RMSE: ", combinations_rmse_scores[np.argmin(combinations_rmse_scores)])
# Out:
# Minimum RMSE:  3587.7802303150274

# %%
print(f"Top features: ")
top_features_with_lowest_rmse = tried_combination[np.argmin(combinations_rmse_scores)]
print(top_features_with_lowest_rmse)
# Out:
# Top features:
# ['wtc', 'flown_distance', 'aircraft_type', 'airline', 'flight_duration', 'latitude_max', 'ades', 'adep', 'altitude_75percentile', 'altitude_median']

# %%
print(f"Number of top features giving minimum RMSE: ", len(top_features_with_lowest_rmse))
# Out:
# Number of top features giving minimum RMSE:  10
