# %%
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.preprocessing import StandardScaler
from xgboost import plot_importance
import matplotlib.pyplot as plt
import xgboost as xgb
import pandas as pd
import numpy as np

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
identifier_name = 'flight_id'

most_important_features_names = [
    'wtc', 
    'aircraft_type', 
    'flown_distance', 
    'groundspeed_max', 
    'latitude_min', 
    'altitude_25percentile', 
    'airline', 
    'flight_duration', 
    'longitude_max', 
    'vertical_rate_75percentile', 
    'altitude_median', 
    'ades', 
    'longitude_mean', 
    'altitude_75percentile', 
    'latitude_75percentile', 
    'vertical_rate_std',
    'adep', 
    'latitude_std', 
    'vertical_rate_max', 
    'latitude_max', 
    'longitude_std', 
    'vertical_rate_25percentile', 
    'longitude_min', 
    'longitude_75percentile', 
    'altitude_mean', 
    'groundspeed_75percentile', 
    'country_code_adep', 
    'latitude_median', 
    'longitude_25percentile', 
    'groundspeed_min', 
    'country_code_ades', 
    'latitude_25percentile', 
    'actual_offblock_time_hour', 
    'longitude_median', 
    'month', 
    'altitude_std', 
    'latitude_count', 
    'taxiout_time', 
    'vertical_rate_median', 
    'month_day', 
    'latitude_mean', 
    'temperature_25percentile', 
    'arrival_time_hour', 
    'track_25percentile', 
    'track_75percentile', 
    'track_median', 
    'arrival_time_hour_minute', 
    'specific_humidity_median', 
    'track_mean', 
    'specific_humidity_75percentile', 
    'temperature_mean', 
    'actual_offblock_time_hour_minute', 
    'track_std', 
    'temperature_max', 
    'vertical_rate_min', 
    'temperature_std', 
    'groundspeed_mean', 
    'altitude_max', 
    'specific_humidity_max', 
    'temperature_75percentile', 
    'altitude_min', 
    'temperature_median', 
    'specific_humidity_std', 
    'vertical_rate_mean', 
    'groundspeed_std', 
    'u_component_of_wind_median', 
    'groundspeed_25percentile', 
    'v_component_of_wind_max', 
    'u_component_of_wind_mean', 
    'groundspeed_median', 
    'temperature_min', 
    'v_component_of_wind_25percentile', 
    'specific_humidity_25percentile', 
    'specific_humidity_mean', 
    'u_component_of_wind_25percentile', 
    'track_min', 
    'v_component_of_wind_75percentile', 
    'v_component_of_wind_median', 
    'u_component_of_wind_75percentile', 
    'specific_humidity_min', 
    'v_component_of_wind_min', 
    'track_max', 
    'v_component_of_wind_std', 
    'u_component_of_wind_max',
    'u_component_of_wind_min', 
    'v_component_of_wind_mean', 
    'u_component_of_wind_std', 
    'day', 
    'arrival_time_minute', 
    'actual_offblock_time_minute', 
    'track_count', 
    'temperature_count', 
    'v_component_of_wind_count', 
    'altitude_count', 
    'longitude_count', 
    'specific_humidity_count', 
    'u_component_of_wind_count', 
    'vertical_rate_count', 
    'groundspeed_count'
]

target_name = 'tow'

global_random_state = 123

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def evaluate_model(model, data_df, features_columns, target_column):
    features = data_df[features_columns]
    target = data_df[target_column]
    X_array = features.values
    y_array = target.values
    rmse_scores = []
    kf = KFold(n_splits=3, shuffle=True, random_state=global_random_state)
    for train_index, test_index in kf.split(X_array):
        X_train, X_test = features.iloc[train_index], features.iloc[test_index]
        y_train, y_test = target.iloc[train_index], target.iloc[test_index]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        rmse_scores.append(rmse(y_test, y_pred))
    return np.mean(rmse_scores)

# %%
encoded_challenge_set = pd.read_csv('data/encoded_challenge_set.csv')
encoded_challenge_set = encoded_challenge_set.fillna(0)

# %%
xgb_model = xgb.XGBRegressor(
    n_estimators=91,
    max_depth=10,
    learning_rate=0.1,
    subsample=1.0,
    colsample_bytree=1.0,
    objective='reg:squarederror', 
    eval_metric='rmse',
    random_state=global_random_state
)

rmse_score = evaluate_model(
    model=xgb_model, 
    data_df=encoded_challenge_set, 
    features_columns=most_important_features_names, 
    target_column=target_name
)
print("Evaluation RMSE:", rmse_score)
# Out:
# Evaluation RMSE: 3056.712200507244

# %%
num_top_features = []
all_rmse_scores = []

for top_important_features in range(1, len(most_important_features_names)+1):
    print(f"Trying top {top_important_features} important features...")
    
    current_top_features = most_important_features_names[0:top_important_features]
    
    xgb_model = xgb.XGBRegressor(
        n_estimators=91,
        max_depth=10,
        learning_rate=0.1,
        subsample=1.0,
        colsample_bytree=1.0,
        objective='reg:squarederror', 
        eval_metric='rmse',
        random_state=global_random_state
    )
    
    rmse_score = evaluate_model(
        model=xgb_model, 
        data_df=encoded_challenge_set, 
        features_columns=current_top_features, 
        target_column=target_name
    )
    print("Evaluation RMSE:", rmse_score)
    num_top_features.append(len(current_top_features))
    all_rmse_scores.append(rmse_score)
# Out:
# Trying top 1 important features...
# Evaluation RMSE: 20350.17311080975
# Trying top 2 important features...
# Evaluation RMSE: 10830.147034063946
# Trying top 3 important features...
# Evaluation RMSE: 6507.453055885133
# Trying top 4 important features...
# Evaluation RMSE: 6460.312140896219
# Trying top 5 important features...
# Evaluation RMSE: 4768.397683392136
# Trying top 6 important features...
# Evaluation RMSE: 4583.551480418025
# Trying top 7 important features...
# Evaluation RMSE: 4080.2622687964954
# Trying top 8 important features...
# Evaluation RMSE: 4038.816034545401
# Trying top 9 important features...
# Evaluation RMSE: 3978.1439477120507
# Trying top 10 important features...
# Evaluation RMSE: 3906.986067857573
# Trying top 11 important features...
# Evaluation RMSE: 3589.2240219982264
# Trying top 12 important features...
# Evaluation RMSE: 3535.3328363843807
# Trying top 13 important features...
# Evaluation RMSE: 3524.5121015249238
# Trying top 14 important features...
# Evaluation RMSE: 3384.9094453555717
# Trying top 15 important features...
# Evaluation RMSE: 3378.7417108816935
# Trying top 16 important features...
# Evaluation RMSE: 3275.9947327960745
# Trying top 17 important features...
# Evaluation RMSE: 3259.846277864783
# Trying top 18 important features...
# Evaluation RMSE: 3261.1990241264016
# Trying top 19 important features...
# Evaluation RMSE: 3201.6837533536345
# Trying top 20 important features...
# Evaluation RMSE: 3198.894987125939
# Trying top 21 important features...
# Evaluation RMSE: 3197.1987576303204
# Trying top 22 important features...
# Evaluation RMSE: 3199.4933376575996
# Trying top 23 important features...
# Evaluation RMSE: 3194.4504001350597
# Trying top 24 important features...
# Evaluation RMSE: 3194.0358052567717
# Trying top 25 important features...
# Evaluation RMSE: 3195.0736648087513
# Trying top 26 important features...
# Evaluation RMSE: 3196.8157349899934
# Trying top 27 important features...
# Evaluation RMSE: 3192.4954672912113
# Trying top 28 important features...
# Evaluation RMSE: 3190.4111019554953
# Trying top 29 important features...
# Evaluation RMSE: 3197.0603745747085
# Trying top 30 important features...
# Evaluation RMSE: 3171.4818362334663
# Trying top 31 important features...
# Evaluation RMSE: 3166.4770180254977
# Trying top 32 important features...
# Evaluation RMSE: 3166.9550182814814
# Trying top 33 important features...
# Evaluation RMSE: 3153.7501698959954
# Trying top 34 important features...
# Evaluation RMSE: 3151.5693908082976
# Trying top 35 important features...
# Evaluation RMSE: 3060.746362077514
# Trying top 36 important features...
# Evaluation RMSE: 3066.52136428125
# Trying top 37 important features...
# Evaluation RMSE: 3062.1490888715502
# Trying top 38 important features...
# Evaluation RMSE: 3063.611427841055
# Trying top 39 important features...
# Evaluation RMSE: 3056.7855930829987
# Trying top 40 important features...
# Evaluation RMSE: 3013.3382277540463
# Trying top 41 important features...
# Evaluation RMSE: 3014.8051909916408
# Trying top 42 important features...
# Evaluation RMSE: 3019.5337146097186
# Trying top 43 important features...
# Evaluation RMSE: 3023.683698320468
# Trying top 44 important features...
# Evaluation RMSE: 3021.309863834074
# Trying top 45 important features...
# Evaluation RMSE: 3018.8681632985936
# Trying top 46 important features...
# Evaluation RMSE: 3023.1126901185658
# Trying top 47 important features...
# Evaluation RMSE: 3022.320300736834
# Trying top 48 important features...
# Evaluation RMSE: 3028.399719226909
# Trying top 49 important features...
# Evaluation RMSE: 3025.7142824619864
# Trying top 50 important features...
# Evaluation RMSE: 3026.9673095203016
# Trying top 51 important features...
# Evaluation RMSE: 3025.4657704112437
# Trying top 52 important features...
# Evaluation RMSE: 3027.4101060673784
# Trying top 53 important features...
# Evaluation RMSE: 3027.2901207975888
# Trying top 54 important features...
# Evaluation RMSE: 3026.393750194268
# Trying top 55 important features...
# Evaluation RMSE: 3036.6091728798697
# Trying top 56 important features...
# Evaluation RMSE: 3034.1545190082106
# Trying top 57 important features...
# Evaluation RMSE: 3041.5533023413827
# Trying top 58 important features...
# Evaluation RMSE: 3041.6511845390014
# Trying top 59 important features...
# Evaluation RMSE: 3038.590736155695
# Trying top 60 important features...
# Evaluation RMSE: 3035.043506274409
# Trying top 61 important features...
# Evaluation RMSE: 3041.464990102335
# Trying top 62 important features...
# Evaluation RMSE: 3043.570248133847
# Trying top 63 important features...
# Evaluation RMSE: 3043.5801689038058
# Trying top 64 important features...
# Evaluation RMSE: 3043.0767469972775
# Trying top 65 important features...
# Evaluation RMSE: 3042.7726645884254
# Trying top 66 important features...
# Evaluation RMSE: 3041.7484557335224
# Trying top 67 important features...
# Evaluation RMSE: 3043.945060785142
# Trying top 68 important features...
# Evaluation RMSE: 3044.976802522157
# Trying top 69 important features...
# Evaluation RMSE: 3043.5981309175163
# Trying top 70 important features...
# Evaluation RMSE: 3048.200922354134
# Trying top 71 important features...
# Evaluation RMSE: 3047.5432457692805
# Trying top 72 important features...
# Evaluation RMSE: 3046.931324562915
# Trying top 73 important features...
# Evaluation RMSE: 3051.9721355841702
# Trying top 74 important features...
# Evaluation RMSE: 3050.5566024905256
# Trying top 75 important features...
# Evaluation RMSE: 3048.523327844403
# Trying top 76 important features...
# Evaluation RMSE: 3047.3873163712233
# Trying top 77 important features...
# Evaluation RMSE: 3048.0014625907993
# Trying top 78 important features...
# Evaluation RMSE: 3052.3401369225517
# Trying top 79 important features...
# Evaluation RMSE: 3048.4610795612584
# Trying top 80 important features...
# Evaluation RMSE: 3051.5233567406012
# Trying top 81 important features...
# Evaluation RMSE: 3053.560075362199
# Trying top 82 important features...
# Evaluation RMSE: 3051.248028946229
# Trying top 83 important features...
# Evaluation RMSE: 3051.780665511123
# Trying top 84 important features...
# Evaluation RMSE: 3050.124113154698
# Trying top 85 important features...
# Evaluation RMSE: 3053.871666869471
# Trying top 86 important features...
# Evaluation RMSE: 3055.9150931008976
# Trying top 87 important features...
# Evaluation RMSE: 3053.007295296667
# Trying top 88 important features...
# Evaluation RMSE: 3052.26778656495
# Trying top 89 important features...
# Evaluation RMSE: 3055.544918827151
# Trying top 90 important features...
# Evaluation RMSE: 3056.712200507244
# Trying top 91 important features...
# Evaluation RMSE: 3056.712200507244
# Trying top 92 important features...
# Evaluation RMSE: 3056.712200507244
# Trying top 93 important features...
# Evaluation RMSE: 3056.712200507244
# Trying top 94 important features...
# Evaluation RMSE: 3056.712200507244
# Trying top 95 important features...
# Evaluation RMSE: 3056.712200507244
# Trying top 96 important features...
# Evaluation RMSE: 3056.712200507244
# Trying top 97 important features...
# Evaluation RMSE: 3056.712200507244
# Trying top 98 important features...
# Evaluation RMSE: 3056.712200507244
# Trying top 99 important features...
# Evaluation RMSE: 3056.712200507244

# %%
step = 25
for to_index in range(25, 126, step):
    from_index = to_index-step
    if to_index > len(all_rmse_scores)-1:
        to_index = len(all_rmse_scores)-1
    
    plt.bar(num_top_features[from_index:to_index], all_rmse_scores[from_index:to_index])
    plt.title(f"Bar Plot of top_features with XGBoost and model RMSE")
    plt.xlabel("Number of top important features used in model")
    plt.ylabel("RMSE Score")
    plt.xticks(ticks=num_top_features[from_index:to_index])
    plt.show()
    print()

# %%
print(f"Minimum RMSE: ", all_rmse_scores[np.argmin(all_rmse_scores)])
# Out:
# Minimum RMSE:  3013.3382277540463

# %%
print(f"Number of top features: ", num_top_features[np.argmin(all_rmse_scores)])
# Out:
# Number of top features:  40

# %%
print(f"Top features: ")
top_features_with_lowest_rmse = most_important_features_names[0: np.argmin(all_rmse_scores)+1]
print(top_features_with_lowest_rmse)
print(len(top_features_with_lowest_rmse))
# Out:
# Top features:
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades', 'longitude_mean', 'altitude_75percentile', 'latitude_75percentile', 'vertical_rate_std', 'adep', 'latitude_std', 'vertical_rate_max', 'latitude_max', 'longitude_std', 'vertical_rate_25percentile', 'longitude_min', 'longitude_75percentile', 'altitude_mean', 'groundspeed_75percentile', 'country_code_adep', 'latitude_median', 'longitude_25percentile', 'groundspeed_min', 'country_code_ades', 'latitude_25percentile', 'actual_offblock_time_hour', 'longitude_median', 'month', 'altitude_std', 'latitude_count', 'taxiout_time', 'vertical_rate_median', 'month_day']
# 40
