# %% [markdown]
# <h1>Add Trajectory Summary to Dataset.ipynb</h1>

# %%
import pandas as pd
from datetime import timedelta
import pyarrow.parquet as pq

# %%
challenge_set = pd.read_csv('../challenge_set.csv')

challenge_set['date'] = pd.to_datetime(challenge_set['date'])

display(challenge_set)
# Out:
#         flight_id       date                          callsign  adep  \
# 0       248763780 2022-01-01  3840d84f25d3f5fcc0a1be3076bb4039  EGLL
# 1       248760618 2022-01-01  f6f610e73002b8892a239a81321f7f1d  LEBL
# 2       248753824 2022-01-01  139670936660762c230ca92556ba842b  ESSA
# 3       248753852 2022-01-01  509dc61bb54fbab0e5406067c95603e2  LSZH
# 4       248755934 2022-01-01  d0610d000dcf26b1d7bba8103ecc393d  EIDW
# ...           ...        ...                               ...   ...
# 369008  258058361 2022-12-31  85ee68e5b7b5acf24ba00d1318eca1e8  LFPG
# 369009  258071247 2022-12-31  570cf7d5ebbd691bcba63e7466607da7  LTFM
# 369010  258059152 2022-12-31  5a7e43e4f981539ae3d3b1cb31591b7c  EDDL
# 369011  258072276 2022-12-31  a1c078516f9f9e90cacec61854cad45b  LFPG
# 369012  258069969 2022-12-31  6c98fcaa191dec632b87b46511f1d2da  LEMD
#
#                       name_adep country_code_adep  ades           name_ades  \
# 0               London Heathrow                GB  EICK                Cork
# 1                     Barcelona                ES  KMIA               Miami
# 2             Stockholm Arlanda                SE  KORD      Chicago O'Hare
# 3                        Zurich                CH  KPHL        Philadelphia
# 4                        Dublin                IE  EGLL     London Heathrow
# ...                         ...               ...   ...                 ...
# 369008  Paris Charles de Gaulle                FR  KMIA               Miami
# 369009             iGA Istanbul                TR  EDDB  Berlin Brandenburg
# 369010               Dusseldorf                DE  EIDW              Dublin
# 369011  Paris Charles de Gaulle                FR  EIDW              Dublin
# 369012           Madrid Barajas                ES  KJFK        New York JFK
#
#        country_code_ades  actual_offblock_time          arrival_time  \
# 0                     IE  2022-01-01T13:46:00Z  2022-01-01T15:04:56Z
# 1                     US  2022-01-01T09:55:00Z  2022-01-01T19:37:56Z
# 2                     US  2022-01-01T09:39:00Z  2022-01-01T19:08:13Z
# 3                     US  2022-01-01T11:04:00Z  2022-01-01T19:32:13Z
# 4                     GB  2022-01-01T12:36:00Z  2022-01-01T13:44:32Z
# ...                  ...                   ...                   ...
# 369008                US  2022-12-31T09:38:00Z  2022-12-31T19:03:48Z
# 369009                DE  2022-12-31T09:27:00Z  2022-12-31T12:29:41Z
# 369010                IE  2022-12-31T09:52:00Z  2022-12-31T11:41:51Z
# 369011                IE  2022-12-31T09:37:00Z  2022-12-31T11:13:10Z
# 369012                US  2022-12-31T09:38:00Z  2022-12-31T17:26:35Z
#
#        aircraft_type wtc                           airline  flight_duration  \
# 0               A320   M  a73f82288988b79be490c6322f4c32ed               61
# 1               B772   H  5543e4dc327359ffaf5b9c0e6faaf0e1              570
# 2               A333   H  8be5c854fd664bcb97fb543339f74770              554
# 3               B788   H  5543e4dc327359ffaf5b9c0e6faaf0e1              497
# 4               A21N   M  a73f82288988b79be490c6322f4c32ed               55
# ...              ...  ..                               ...              ...
# 369008          B788   H  5543e4dc327359ffaf5b9c0e6faaf0e1              545
# 369009          A21N   M  6351ec1b849adacc0cbb3b1313d8d39b              158
# 369010          A320   M  a73f82288988b79be490c6322f4c32ed               99
# 369011          A21N   M  a73f82288988b79be490c6322f4c32ed               84
# 369012          B772   H  5543e4dc327359ffaf5b9c0e6faaf0e1              453
#
#         taxiout_time  flown_distance            tow
# 0                 18             321   54748.000000
# 1                 13            4193  185441.000000
# 2                 15            3770  230396.000000
# 3                 11            3607  157615.000000
# 4                 14             305   70318.447226
# ...              ...             ...            ...
# 369008            21            4046  163438.000000
# 369009            25             946   78707.000000
# 369010            11             522   62942.750000
# 369011            12             466   72611.161024
# 369012            16            3213  195373.000000
#
# [369013 rows x 18 columns]

# %%
def calculate_stat(
    dataframe: pd.DataFrame, 
    group_by_column: str, 
    target_column: str,
    stat_type: str
) -> pd.Series | None:
    result = None
    if stat_type == 'median':
        result = dataframe.groupby(group_by_column)[target_column].median()
    elif stat_type == 'mean':
        result = dataframe.groupby(group_by_column)[target_column].mean()
    return result

# %%
def summarize_trajectories(
    trajectory_df: pd.DataFrame
) -> pd.DataFrame:
    latitude_median = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='latitude', stat_type='median')
    longitude_median = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='longitude', stat_type='median')
    altitude_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='altitude', stat_type='mean')
    groundspeed_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='groundspeed', stat_type='mean')
    track_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='track', stat_type='mean')
    vertical_rate_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='vertical_rate', stat_type='mean')
    track_unwrapped_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='track_unwrapped', stat_type='mean')
    u_component_of_wind_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='u_component_of_wind', stat_type='mean')
    v_component_of_wind_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='v_component_of_wind', stat_type='mean')
    temperature_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='temperature', stat_type='mean')
    specific_humidity_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='specific_humidity', stat_type='mean')

    trajactory_summary_df = pd.DataFrame({
        "latitude_median": latitude_median,
        "longitude_median": longitude_median,
        "altitude_mean": altitude_mean,
        "groundspeed_mean": groundspeed_mean,
        "track_mean": track_mean,
        "vertical_rate_mean": vertical_rate_mean,
        "track_unwrapped_mean": track_unwrapped_mean,
        "u_component_of_wind_mean": u_component_of_wind_mean,
        "v_component_of_wind_mean": v_component_of_wind_mean,
        "temperature_mean": temperature_mean,
        "specific_humidity_mean": specific_humidity_mean
    })
    trajactory_summary_df = trajactory_summary_df.reset_index()
    trajactory_summary_df.rename(columns={'index': 'flight_id'}, inplace=True)
    trajactory_summary_df['flight_id'] = trajactory_summary_df['flight_id'].astype('int64')
    
    return trajactory_summary_df

# %%
challenge_set_with_trajectory = pd.DataFrame({})

unique_dates = challenge_set['date'].unique()
for current_date in unique_dates:
    today_date = str(current_date.date())
    tomorrow_date = str((current_date + timedelta(days=1)).date())
    print(f"Prosessing flights from {today_date = } to {tomorrow_date = }")

    if today_date != '2022-12-31':
        today_trajectory_df = pq.ParquetDataset(f'../data/trajactory_files/{today_date}.parquet').read().to_pandas()
        tomorrow_trajectory_df = pq.ParquetDataset(f'../data/trajactory_files/{tomorrow_date}.parquet').read().to_pandas()
        trajectory_df = pd.concat([today_trajectory_df, tomorrow_trajectory_df], ignore_index=True)
    else:
        trajectory_df = pq.ParquetDataset(f'../data/trajactory_files/{today_date}.parquet').read().to_pandas()
        
    summarized_trajectory_df = summarize_trajectories(trajectory_df=trajectory_df)
    
    filtered_df = challenge_set[challenge_set['date'] == current_date]

    merged_df = pd.merge(filtered_df, summarized_trajectory_df, on='flight_id', how='left')
    
    challenge_set_with_trajectory = pd.concat([challenge_set_with_trajectory, merged_df], ignore_index=False)
        
display(challenge_set_with_trajectory)
# Out:
# Prosessing flights from today_date = '2022-01-01' to tomorrow_date = '2022-01-02'
# Prosessing flights from today_date = '2022-01-02' to tomorrow_date = '2022-01-03'
# Prosessing flights from today_date = '2022-01-03' to tomorrow_date = '2022-01-04'
# Prosessing flights from today_date = '2022-01-04' to tomorrow_date = '2022-01-05'
# Prosessing flights from today_date = '2022-01-05' to tomorrow_date = '2022-01-06'
# Prosessing flights from today_date = '2022-01-06' to tomorrow_date = '2022-01-07'
# Prosessing flights from today_date = '2022-01-07' to tomorrow_date = '2022-01-08'
# Prosessing flights from today_date = '2022-01-08' to tomorrow_date = '2022-01-09'
# Prosessing flights from today_date = '2022-01-09' to tomorrow_date = '2022-01-10'
# Prosessing flights from today_date = '2022-01-10' to tomorrow_date = '2022-01-11'
# Prosessing flights from today_date = '2022-01-11' to tomorrow_date = '2022-01-12'
# Prosessing flights from today_date = '2022-01-12' to tomorrow_date = '2022-01-13'
# Prosessing flights from today_date = '2022-01-13' to tomorrow_date = '2022-01-14'
# Prosessing flights from today_date = '2022-01-14' to tomorrow_date = '2022-01-15'
# Prosessing flights from today_date = '2022-01-15' to tomorrow_date = '2022-01-16'
# Prosessing flights from today_date = '2022-01-16' to tomorrow_date = '2022-01-17'
# Prosessing flights from today_date = '2022-01-17' to tomorrow_date = '2022-01-18'
# Prosessing flights from today_date = '2022-01-18' to tomorrow_date = '2022-01-19'
# Prosessing flights from today_date = '2022-01-19' to tomorrow_date = '2022-01-20'
# Prosessing flights from today_date = '2022-01-20' to tomorrow_date = '2022-01-21'
# Prosessing flights from today_date = '2022-01-21' to tomorrow_date = '2022-01-22'
# Prosessing flights from today_date = '2022-01-22' to tomorrow_date = '2022-01-23'
# Prosessing flights from today_date = '2022-01-23' to tomorrow_date = '2022-01-24'
# Prosessing flights from today_date = '2022-01-24' to tomorrow_date = '2022-01-25'
# Prosessing flights from today_date = '2022-01-25' to tomorrow_date = '2022-01-26'
# Prosessing flights from today_date = '2022-01-26' to tomorrow_date = '2022-01-27'
# Prosessing flights from today_date = '2022-01-27' to tomorrow_date = '2022-01-28'
# Prosessing flights from today_date = '2022-01-28' to tomorrow_date = '2022-01-29'
# Prosessing flights from today_date = '2022-01-29' to tomorrow_date = '2022-01-30'
# Prosessing flights from today_date = '2022-01-30' to tomorrow_date = '2022-01-31'
# Prosessing flights from today_date = '2022-01-31' to tomorrow_date = '2022-02-01'
# Prosessing flights from today_date = '2022-02-01' to tomorrow_date = '2022-02-02'
# Prosessing flights from today_date = '2022-02-02' to tomorrow_date = '2022-02-03'
# Prosessing flights from today_date = '2022-02-03' to tomorrow_date = '2022-02-04'
# Prosessing flights from today_date = '2022-02-04' to tomorrow_date = '2022-02-05'
# Prosessing flights from today_date = '2022-02-05' to tomorrow_date = '2022-02-06'
# Prosessing flights from today_date = '2022-02-06' to tomorrow_date = '2022-02-07'
# Prosessing flights from today_date = '2022-02-07' to tomorrow_date = '2022-02-08'
# Prosessing flights from today_date = '2022-02-08' to tomorrow_date = '2022-02-09'
# Prosessing flights from today_date = '2022-02-09' to tomorrow_date = '2022-02-10'
# Prosessing flights from today_date = '2022-02-10' to tomorrow_date = '2022-02-11'
# Prosessing flights from today_date = '2022-02-11' to tomorrow_date = '2022-02-12'
# Prosessing flights from today_date = '2022-02-12' to tomorrow_date = '2022-02-13'
# Prosessing flights from today_date = '2022-02-13' to tomorrow_date = '2022-02-14'
# Prosessing flights from today_date = '2022-02-14' to tomorrow_date = '2022-02-15'
# Prosessing flights from today_date = '2022-02-15' to tomorrow_date = '2022-02-16'
# Prosessing flights from today_date = '2022-02-16' to tomorrow_date = '2022-02-17'
# Prosessing flights from today_date = '2022-02-17' to tomorrow_date = '2022-02-18'
# Prosessing flights from today_date = '2022-02-18' to tomorrow_date = '2022-02-19'
# Prosessing flights from today_date = '2022-02-19' to tomorrow_date = '2022-02-20'
# Prosessing flights from today_date = '2022-02-20' to tomorrow_date = '2022-02-21'
# Prosessing flights from today_date = '2022-02-21' to tomorrow_date = '2022-02-22'
# Prosessing flights from today_date = '2022-02-22' to tomorrow_date = '2022-02-23'
# Prosessing flights from today_date = '2022-02-23' to tomorrow_date = '2022-02-24'
# Prosessing flights from today_date = '2022-02-24' to tomorrow_date = '2022-02-25'
# Prosessing flights from today_date = '2022-02-25' to tomorrow_date = '2022-02-26'
# Prosessing flights from today_date = '2022-02-26' to tomorrow_date = '2022-02-27'
# Prosessing flights from today_date = '2022-02-27' to tomorrow_date = '2022-02-28'
# Prosessing flights from today_date = '2022-02-28' to tomorrow_date = '2022-03-01'
# Prosessing flights from today_date = '2022-03-01' to tomorrow_date = '2022-03-02'
# Prosessing flights from today_date = '2022-03-02' to tomorrow_date = '2022-03-03'
# Prosessing flights from today_date = '2022-03-03' to tomorrow_date = '2022-03-04'
# Prosessing flights from today_date = '2022-03-04' to tomorrow_date = '2022-03-05'
# Prosessing flights from today_date = '2022-03-05' to tomorrow_date = '2022-03-06'
# Prosessing flights from today_date = '2022-03-06' to tomorrow_date = '2022-03-07'
# Prosessing flights from today_date = '2022-03-07' to tomorrow_date = '2022-03-08'
# Prosessing flights from today_date = '2022-03-08' to tomorrow_date = '2022-03-09'
# Prosessing flights from today_date = '2022-03-09' to tomorrow_date = '2022-03-10'
# Prosessing flights from today_date = '2022-03-10' to tomorrow_date = '2022-03-11'
# Prosessing flights from today_date = '2022-03-11' to tomorrow_date = '2022-03-12'
# Prosessing flights from today_date = '2022-03-12' to tomorrow_date = '2022-03-13'
# Prosessing flights from today_date = '2022-03-13' to tomorrow_date = '2022-03-14'
# Prosessing flights from today_date = '2022-03-14' to tomorrow_date = '2022-03-15'
# Prosessing flights from today_date = '2022-03-15' to tomorrow_date = '2022-03-16'
# Prosessing flights from today_date = '2022-03-16' to tomorrow_date = '2022-03-17'
# Prosessing flights from today_date = '2022-03-17' to tomorrow_date = '2022-03-18'
# Prosessing flights from today_date = '2022-03-18' to tomorrow_date = '2022-03-19'
# Prosessing flights from today_date = '2022-03-19' to tomorrow_date = '2022-03-20'
# Prosessing flights from today_date = '2022-03-20' to tomorrow_date = '2022-03-21'
# Prosessing flights from today_date = '2022-03-21' to tomorrow_date = '2022-03-22'
# Prosessing flights from today_date = '2022-03-22' to tomorrow_date = '2022-03-23'
# Prosessing flights from today_date = '2022-03-23' to tomorrow_date = '2022-03-24'
# Prosessing flights from today_date = '2022-03-24' to tomorrow_date = '2022-03-25'
# Prosessing flights from today_date = '2022-03-25' to tomorrow_date = '2022-03-26'
# Prosessing flights from today_date = '2022-03-26' to tomorrow_date = '2022-03-27'
# Prosessing flights from today_date = '2022-03-27' to tomorrow_date = '2022-03-28'
# Prosessing flights from today_date = '2022-03-28' to tomorrow_date = '2022-03-29'
# Prosessing flights from today_date = '2022-03-29' to tomorrow_date = '2022-03-30'
# Prosessing flights from today_date = '2022-03-30' to tomorrow_date = '2022-03-31'
# Prosessing flights from today_date = '2022-03-31' to tomorrow_date = '2022-04-01'
# Prosessing flights from today_date = '2022-04-01' to tomorrow_date = '2022-04-02'
# Prosessing flights from today_date = '2022-04-02' to tomorrow_date = '2022-04-03'
# Prosessing flights from today_date = '2022-04-03' to tomorrow_date = '2022-04-04'
# Prosessing flights from today_date = '2022-04-04' to tomorrow_date = '2022-04-05'
# Prosessing flights from today_date = '2022-04-05' to tomorrow_date = '2022-04-06'
# Prosessing flights from today_date = '2022-04-06' to tomorrow_date = '2022-04-07'
# Prosessing flights from today_date = '2022-04-07' to tomorrow_date = '2022-04-08'
# Prosessing flights from today_date = '2022-04-08' to tomorrow_date = '2022-04-09'
# Prosessing flights from today_date = '2022-04-09' to tomorrow_date = '2022-04-10'
# Prosessing flights from today_date = '2022-04-10' to tomorrow_date = '2022-04-11'
# Prosessing flights from today_date = '2022-04-11' to tomorrow_date = '2022-04-12'
# Prosessing flights from today_date = '2022-04-12' to tomorrow_date = '2022-04-13'
# Prosessing flights from today_date = '2022-04-13' to tomorrow_date = '2022-04-14'
# Prosessing flights from today_date = '2022-04-14' to tomorrow_date = '2022-04-15'
# Prosessing flights from today_date = '2022-04-15' to tomorrow_date = '2022-04-16'
# Prosessing flights from today_date = '2022-04-16' to tomorrow_date = '2022-04-17'
# Prosessing flights from today_date = '2022-04-17' to tomorrow_date = '2022-04-18'
# Prosessing flights from today_date = '2022-04-18' to tomorrow_date = '2022-04-19'
# Prosessing flights from today_date = '2022-04-19' to tomorrow_date = '2022-04-20'
# Prosessing flights from today_date = '2022-04-20' to tomorrow_date = '2022-04-21'
# Prosessing flights from today_date = '2022-04-21' to tomorrow_date = '2022-04-22'
# Prosessing flights from today_date = '2022-04-22' to tomorrow_date = '2022-04-23'
# Prosessing flights from today_date = '2022-04-23' to tomorrow_date = '2022-04-24'
# Prosessing flights from today_date = '2022-04-24' to tomorrow_date = '2022-04-25'
# Prosessing flights from today_date = '2022-04-25' to tomorrow_date = '2022-04-26'
# Prosessing flights from today_date = '2022-04-26' to tomorrow_date = '2022-04-27'
# Prosessing flights from today_date = '2022-04-27' to tomorrow_date = '2022-04-28'
# Prosessing flights from today_date = '2022-04-28' to tomorrow_date = '2022-04-29'
# Prosessing flights from today_date = '2022-04-29' to tomorrow_date = '2022-04-30'
# Prosessing flights from today_date = '2022-04-30' to tomorrow_date = '2022-05-01'
# Prosessing flights from today_date = '2022-05-01' to tomorrow_date = '2022-05-02'
# Prosessing flights from today_date = '2022-05-02' to tomorrow_date = '2022-05-03'
# Prosessing flights from today_date = '2022-05-03' to tomorrow_date = '2022-05-04'
# Prosessing flights from today_date = '2022-05-04' to tomorrow_date = '2022-05-05'
# Prosessing flights from today_date = '2022-05-05' to tomorrow_date = '2022-05-06'
# Prosessing flights from today_date = '2022-05-06' to tomorrow_date = '2022-05-07'
# Prosessing flights from today_date = '2022-05-07' to tomorrow_date = '2022-05-08'
# Prosessing flights from today_date = '2022-05-08' to tomorrow_date = '2022-05-09'
# Prosessing flights from today_date = '2022-05-09' to tomorrow_date = '2022-05-10'
# Prosessing flights from today_date = '2022-05-10' to tomorrow_date = '2022-05-11'
# Prosessing flights from today_date = '2022-05-11' to tomorrow_date = '2022-05-12'
# Prosessing flights from today_date = '2022-05-12' to tomorrow_date = '2022-05-13'
# Prosessing flights from today_date = '2022-05-13' to tomorrow_date = '2022-05-14'
# Prosessing flights from today_date = '2022-05-14' to tomorrow_date = '2022-05-15'
# Prosessing flights from today_date = '2022-05-15' to tomorrow_date = '2022-05-16'
# Prosessing flights from today_date = '2022-05-16' to tomorrow_date = '2022-05-17'
# Prosessing flights from today_date = '2022-05-17' to tomorrow_date = '2022-05-18'
# Prosessing flights from today_date = '2022-05-18' to tomorrow_date = '2022-05-19'
# Prosessing flights from today_date = '2022-05-19' to tomorrow_date = '2022-05-20'
# Prosessing flights from today_date = '2022-05-20' to tomorrow_date = '2022-05-21'
# Prosessing flights from today_date = '2022-05-21' to tomorrow_date = '2022-05-22'
# Prosessing flights from today_date = '2022-05-22' to tomorrow_date = '2022-05-23'
# Prosessing flights from today_date = '2022-05-23' to tomorrow_date = '2022-05-24'
# Prosessing flights from today_date = '2022-05-24' to tomorrow_date = '2022-05-25'
# Prosessing flights from today_date = '2022-05-25' to tomorrow_date = '2022-05-26'
# Prosessing flights from today_date = '2022-05-26' to tomorrow_date = '2022-05-27'
# Prosessing flights from today_date = '2022-05-27' to tomorrow_date = '2022-05-28'
# Prosessing flights from today_date = '2022-05-28' to tomorrow_date = '2022-05-29'
# Prosessing flights from today_date = '2022-05-29' to tomorrow_date = '2022-05-30'
# Prosessing flights from today_date = '2022-05-30' to tomorrow_date = '2022-05-31'
# Prosessing flights from today_date = '2022-05-31' to tomorrow_date = '2022-06-01'
# Prosessing flights from today_date = '2022-06-01' to tomorrow_date = '2022-06-02'
# Prosessing flights from today_date = '2022-06-02' to tomorrow_date = '2022-06-03'
# Prosessing flights from today_date = '2022-06-03' to tomorrow_date = '2022-06-04'
# Prosessing flights from today_date = '2022-06-04' to tomorrow_date = '2022-06-05'
# Prosessing flights from today_date = '2022-06-05' to tomorrow_date = '2022-06-06'
# Prosessing flights from today_date = '2022-06-06' to tomorrow_date = '2022-06-07'
# Prosessing flights from today_date = '2022-06-07' to tomorrow_date = '2022-06-08'
# Prosessing flights from today_date = '2022-06-08' to tomorrow_date = '2022-06-09'
# Prosessing flights from today_date = '2022-06-09' to tomorrow_date = '2022-06-10'
# Prosessing flights from today_date = '2022-06-10' to tomorrow_date = '2022-06-11'
# Prosessing flights from today_date = '2022-06-11' to tomorrow_date = '2022-06-12'
# Prosessing flights from today_date = '2022-06-12' to tomorrow_date = '2022-06-13'
# Prosessing flights from today_date = '2022-06-13' to tomorrow_date = '2022-06-14'
# Prosessing flights from today_date = '2022-06-14' to tomorrow_date = '2022-06-15'
# Prosessing flights from today_date = '2022-06-15' to tomorrow_date = '2022-06-16'
# Prosessing flights from today_date = '2022-06-16' to tomorrow_date = '2022-06-17'
# Prosessing flights from today_date = '2022-06-17' to tomorrow_date = '2022-06-18'
# Prosessing flights from today_date = '2022-06-18' to tomorrow_date = '2022-06-19'
# Prosessing flights from today_date = '2022-06-19' to tomorrow_date = '2022-06-20'
# Prosessing flights from today_date = '2022-06-20' to tomorrow_date = '2022-06-21'
# Prosessing flights from today_date = '2022-06-21' to tomorrow_date = '2022-06-22'
# Prosessing flights from today_date = '2022-06-22' to tomorrow_date = '2022-06-23'
# Prosessing flights from today_date = '2022-06-23' to tomorrow_date = '2022-06-24'
# Prosessing flights from today_date = '2022-06-24' to tomorrow_date = '2022-06-25'
# Prosessing flights from today_date = '2022-06-25' to tomorrow_date = '2022-06-26'
# Prosessing flights from today_date = '2022-06-26' to tomorrow_date = '2022-06-27'
# Prosessing flights from today_date = '2022-06-27' to tomorrow_date = '2022-06-28'
# Prosessing flights from today_date = '2022-06-28' to tomorrow_date = '2022-06-29'
# Prosessing flights from today_date = '2022-06-29' to tomorrow_date = '2022-06-30'
# Prosessing flights from today_date = '2022-06-30' to tomorrow_date = '2022-07-01'
# Prosessing flights from today_date = '2022-07-01' to tomorrow_date = '2022-07-02'
# Prosessing flights from today_date = '2022-07-02' to tomorrow_date = '2022-07-03'
# Prosessing flights from today_date = '2022-07-03' to tomorrow_date = '2022-07-04'
# Prosessing flights from today_date = '2022-07-04' to tomorrow_date = '2022-07-05'
# Prosessing flights from today_date = '2022-07-05' to tomorrow_date = '2022-07-06'
# Prosessing flights from today_date = '2022-07-06' to tomorrow_date = '2022-07-07'
# Prosessing flights from today_date = '2022-07-07' to tomorrow_date = '2022-07-08'
# Prosessing flights from today_date = '2022-07-08' to tomorrow_date = '2022-07-09'
# Prosessing flights from today_date = '2022-07-09' to tomorrow_date = '2022-07-10'
# Prosessing flights from today_date = '2022-07-10' to tomorrow_date = '2022-07-11'
# Prosessing flights from today_date = '2022-07-11' to tomorrow_date = '2022-07-12'
# Prosessing flights from today_date = '2022-07-12' to tomorrow_date = '2022-07-13'
# Prosessing flights from today_date = '2022-07-13' to tomorrow_date = '2022-07-14'
# Prosessing flights from today_date = '2022-07-14' to tomorrow_date = '2022-07-15'
# Prosessing flights from today_date = '2022-07-15' to tomorrow_date = '2022-07-16'
# Prosessing flights from today_date = '2022-07-16' to tomorrow_date = '2022-07-17'
# Prosessing flights from today_date = '2022-07-17' to tomorrow_date = '2022-07-18'
# Prosessing flights from today_date = '2022-07-18' to tomorrow_date = '2022-07-19'
# Prosessing flights from today_date = '2022-07-19' to tomorrow_date = '2022-07-20'
# Prosessing flights from today_date = '2022-07-20' to tomorrow_date = '2022-07-21'
# Prosessing flights from today_date = '2022-07-21' to tomorrow_date = '2022-07-22'
# Prosessing flights from today_date = '2022-07-22' to tomorrow_date = '2022-07-23'
# Prosessing flights from today_date = '2022-07-23' to tomorrow_date = '2022-07-24'
# Prosessing flights from today_date = '2022-07-24' to tomorrow_date = '2022-07-25'
# Prosessing flights from today_date = '2022-07-25' to tomorrow_date = '2022-07-26'
# Prosessing flights from today_date = '2022-07-26' to tomorrow_date = '2022-07-27'
# Prosessing flights from today_date = '2022-07-27' to tomorrow_date = '2022-07-28'
# Prosessing flights from today_date = '2022-07-28' to tomorrow_date = '2022-07-29'
# Prosessing flights from today_date = '2022-07-29' to tomorrow_date = '2022-07-30'
# Prosessing flights from today_date = '2022-07-30' to tomorrow_date = '2022-07-31'
# Prosessing flights from today_date = '2022-07-31' to tomorrow_date = '2022-08-01'
# Prosessing flights from today_date = '2022-08-01' to tomorrow_date = '2022-08-02'
# Prosessing flights from today_date = '2022-08-02' to tomorrow_date = '2022-08-03'
# Prosessing flights from today_date = '2022-08-03' to tomorrow_date = '2022-08-04'
# Prosessing flights from today_date = '2022-08-04' to tomorrow_date = '2022-08-05'
# Prosessing flights from today_date = '2022-08-05' to tomorrow_date = '2022-08-06'
# Prosessing flights from today_date = '2022-08-06' to tomorrow_date = '2022-08-07'
# Prosessing flights from today_date = '2022-08-07' to tomorrow_date = '2022-08-08'
# Prosessing flights from today_date = '2022-08-08' to tomorrow_date = '2022-08-09'
# Prosessing flights from today_date = '2022-08-09' to tomorrow_date = '2022-08-10'
# Prosessing flights from today_date = '2022-08-10' to tomorrow_date = '2022-08-11'
# Prosessing flights from today_date = '2022-08-11' to tomorrow_date = '2022-08-12'
# Prosessing flights from today_date = '2022-08-12' to tomorrow_date = '2022-08-13'
# Prosessing flights from today_date = '2022-08-13' to tomorrow_date = '2022-08-14'
# Prosessing flights from today_date = '2022-08-14' to tomorrow_date = '2022-08-15'
# Prosessing flights from today_date = '2022-08-15' to tomorrow_date = '2022-08-16'
# Prosessing flights from today_date = '2022-08-16' to tomorrow_date = '2022-08-17'
# Prosessing flights from today_date = '2022-08-17' to tomorrow_date = '2022-08-18'
# Prosessing flights from today_date = '2022-08-18' to tomorrow_date = '2022-08-19'
# Prosessing flights from today_date = '2022-08-19' to tomorrow_date = '2022-08-20'
# Prosessing flights from today_date = '2022-08-20' to tomorrow_date = '2022-08-21'
# Prosessing flights from today_date = '2022-08-21' to tomorrow_date = '2022-08-22'
# Prosessing flights from today_date = '2022-08-22' to tomorrow_date = '2022-08-23'
# Prosessing flights from today_date = '2022-08-23' to tomorrow_date = '2022-08-24'
# Prosessing flights from today_date = '2022-08-24' to tomorrow_date = '2022-08-25'
# Prosessing flights from today_date = '2022-08-25' to tomorrow_date = '2022-08-26'
# Prosessing flights from today_date = '2022-08-26' to tomorrow_date = '2022-08-27'
# Prosessing flights from today_date = '2022-08-27' to tomorrow_date = '2022-08-28'
# Prosessing flights from today_date = '2022-08-28' to tomorrow_date = '2022-08-29'
# Prosessing flights from today_date = '2022-08-29' to tomorrow_date = '2022-08-30'
# Prosessing flights from today_date = '2022-08-30' to tomorrow_date = '2022-08-31'
# Prosessing flights from today_date = '2022-08-31' to tomorrow_date = '2022-09-01'
# Prosessing flights from today_date = '2022-09-01' to tomorrow_date = '2022-09-02'
# Prosessing flights from today_date = '2022-09-02' to tomorrow_date = '2022-09-03'
# Prosessing flights from today_date = '2022-09-03' to tomorrow_date = '2022-09-04'
# Prosessing flights from today_date = '2022-09-04' to tomorrow_date = '2022-09-05'
# Prosessing flights from today_date = '2022-09-05' to tomorrow_date = '2022-09-06'
# Prosessing flights from today_date = '2022-09-06' to tomorrow_date = '2022-09-07'
# Prosessing flights from today_date = '2022-09-07' to tomorrow_date = '2022-09-08'
# Prosessing flights from today_date = '2022-09-08' to tomorrow_date = '2022-09-09'
# Prosessing flights from today_date = '2022-09-09' to tomorrow_date = '2022-09-10'
# Prosessing flights from today_date = '2022-09-10' to tomorrow_date = '2022-09-11'
# Prosessing flights from today_date = '2022-09-11' to tomorrow_date = '2022-09-12'
# Prosessing flights from today_date = '2022-09-12' to tomorrow_date = '2022-09-13'
# Prosessing flights from today_date = '2022-09-13' to tomorrow_date = '2022-09-14'
# Prosessing flights from today_date = '2022-09-14' to tomorrow_date = '2022-09-15'
# Prosessing flights from today_date = '2022-09-15' to tomorrow_date = '2022-09-16'
# Prosessing flights from today_date = '2022-09-16' to tomorrow_date = '2022-09-17'
# Prosessing flights from today_date = '2022-09-17' to tomorrow_date = '2022-09-18'
# Prosessing flights from today_date = '2022-09-18' to tomorrow_date = '2022-09-19'
# Prosessing flights from today_date = '2022-09-19' to tomorrow_date = '2022-09-20'
# Prosessing flights from today_date = '2022-09-20' to tomorrow_date = '2022-09-21'
# Prosessing flights from today_date = '2022-09-21' to tomorrow_date = '2022-09-22'
# Prosessing flights from today_date = '2022-09-22' to tomorrow_date = '2022-09-23'
# Prosessing flights from today_date = '2022-09-23' to tomorrow_date = '2022-09-24'
# Prosessing flights from today_date = '2022-09-24' to tomorrow_date = '2022-09-25'
# Prosessing flights from today_date = '2022-09-25' to tomorrow_date = '2022-09-26'
# Prosessing flights from today_date = '2022-09-26' to tomorrow_date = '2022-09-27'
# Prosessing flights from today_date = '2022-09-27' to tomorrow_date = '2022-09-28'
# Prosessing flights from today_date = '2022-09-28' to tomorrow_date = '2022-09-29'
# Prosessing flights from today_date = '2022-09-29' to tomorrow_date = '2022-09-30'
# Prosessing flights from today_date = '2022-09-30' to tomorrow_date = '2022-10-01'
# Prosessing flights from today_date = '2022-10-01' to tomorrow_date = '2022-10-02'
# Prosessing flights from today_date = '2022-10-02' to tomorrow_date = '2022-10-03'
# Prosessing flights from today_date = '2022-10-03' to tomorrow_date = '2022-10-04'
# Prosessing flights from today_date = '2022-10-04' to tomorrow_date = '2022-10-05'
# Prosessing flights from today_date = '2022-10-05' to tomorrow_date = '2022-10-06'
# Prosessing flights from today_date = '2022-10-06' to tomorrow_date = '2022-10-07'
# Prosessing flights from today_date = '2022-10-07' to tomorrow_date = '2022-10-08'
# Prosessing flights from today_date = '2022-10-08' to tomorrow_date = '2022-10-09'
# Prosessing flights from today_date = '2022-10-09' to tomorrow_date = '2022-10-10'
# Prosessing flights from today_date = '2022-10-10' to tomorrow_date = '2022-10-11'
# Prosessing flights from today_date = '2022-10-11' to tomorrow_date = '2022-10-12'
# Prosessing flights from today_date = '2022-10-12' to tomorrow_date = '2022-10-13'
# Prosessing flights from today_date = '2022-10-13' to tomorrow_date = '2022-10-14'
# Prosessing flights from today_date = '2022-10-14' to tomorrow_date = '2022-10-15'
# Prosessing flights from today_date = '2022-10-15' to tomorrow_date = '2022-10-16'
# Prosessing flights from today_date = '2022-10-16' to tomorrow_date = '2022-10-17'
# Prosessing flights from today_date = '2022-10-17' to tomorrow_date = '2022-10-18'
# Prosessing flights from today_date = '2022-10-18' to tomorrow_date = '2022-10-19'
# Prosessing flights from today_date = '2022-10-19' to tomorrow_date = '2022-10-20'
# Prosessing flights from today_date = '2022-10-20' to tomorrow_date = '2022-10-21'
# Prosessing flights from today_date = '2022-10-21' to tomorrow_date = '2022-10-22'
# Prosessing flights from today_date = '2022-10-22' to tomorrow_date = '2022-10-23'
# Prosessing flights from today_date = '2022-10-23' to tomorrow_date = '2022-10-24'
# Prosessing flights from today_date = '2022-10-24' to tomorrow_date = '2022-10-25'
# Prosessing flights from today_date = '2022-10-25' to tomorrow_date = '2022-10-26'
# Prosessing flights from today_date = '2022-10-26' to tomorrow_date = '2022-10-27'
# Prosessing flights from today_date = '2022-10-27' to tomorrow_date = '2022-10-28'
# Prosessing flights from today_date = '2022-10-28' to tomorrow_date = '2022-10-29'
# Prosessing flights from today_date = '2022-10-29' to tomorrow_date = '2022-10-30'
# Prosessing flights from today_date = '2022-10-30' to tomorrow_date = '2022-10-31'
# Prosessing flights from today_date = '2022-10-31' to tomorrow_date = '2022-11-01'
# Prosessing flights from today_date = '2022-11-01' to tomorrow_date = '2022-11-02'
# Prosessing flights from today_date = '2022-11-02' to tomorrow_date = '2022-11-03'
# Prosessing flights from today_date = '2022-11-03' to tomorrow_date = '2022-11-04'
# Prosessing flights from today_date = '2022-11-04' to tomorrow_date = '2022-11-05'
# Prosessing flights from today_date = '2022-11-05' to tomorrow_date = '2022-11-06'
# Prosessing flights from today_date = '2022-11-06' to tomorrow_date = '2022-11-07'
# Prosessing flights from today_date = '2022-11-07' to tomorrow_date = '2022-11-08'
# Prosessing flights from today_date = '2022-11-08' to tomorrow_date = '2022-11-09'
# Prosessing flights from today_date = '2022-11-09' to tomorrow_date = '2022-11-10'
# Prosessing flights from today_date = '2022-11-10' to tomorrow_date = '2022-11-11'
# Prosessing flights from today_date = '2022-11-11' to tomorrow_date = '2022-11-12'
# Prosessing flights from today_date = '2022-11-12' to tomorrow_date = '2022-11-13'
# Prosessing flights from today_date = '2022-11-13' to tomorrow_date = '2022-11-14'
# Prosessing flights from today_date = '2022-11-14' to tomorrow_date = '2022-11-15'
# Prosessing flights from today_date = '2022-11-15' to tomorrow_date = '2022-11-16'
# Prosessing flights from today_date = '2022-11-16' to tomorrow_date = '2022-11-17'
# Prosessing flights from today_date = '2022-11-17' to tomorrow_date = '2022-11-18'
# Prosessing flights from today_date = '2022-11-18' to tomorrow_date = '2022-11-19'
# Prosessing flights from today_date = '2022-11-19' to tomorrow_date = '2022-11-20'
# Prosessing flights from today_date = '2022-11-20' to tomorrow_date = '2022-11-21'
# Prosessing flights from today_date = '2022-11-21' to tomorrow_date = '2022-11-22'
# Prosessing flights from today_date = '2022-11-22' to tomorrow_date = '2022-11-23'
# Prosessing flights from today_date = '2022-11-23' to tomorrow_date = '2022-11-24'
# Prosessing flights from today_date = '2022-11-24' to tomorrow_date = '2022-11-25'
# Prosessing flights from today_date = '2022-11-25' to tomorrow_date = '2022-11-26'
# Prosessing flights from today_date = '2022-11-26' to tomorrow_date = '2022-11-27'
# Prosessing flights from today_date = '2022-11-27' to tomorrow_date = '2022-11-28'
# Prosessing flights from today_date = '2022-11-28' to tomorrow_date = '2022-11-29'
# Prosessing flights from today_date = '2022-11-29' to tomorrow_date = '2022-11-30'
# Prosessing flights from today_date = '2022-11-30' to tomorrow_date = '2022-12-01'
# Prosessing flights from today_date = '2022-12-01' to tomorrow_date = '2022-12-02'
# Prosessing flights from today_date = '2022-12-02' to tomorrow_date = '2022-12-03'
# Prosessing flights from today_date = '2022-12-03' to tomorrow_date = '2022-12-04'
# Prosessing flights from today_date = '2022-12-04' to tomorrow_date = '2022-12-05'
# Prosessing flights from today_date = '2022-12-05' to tomorrow_date = '2022-12-06'
# Prosessing flights from today_date = '2022-12-06' to tomorrow_date = '2022-12-07'
# Prosessing flights from today_date = '2022-12-07' to tomorrow_date = '2022-12-08'
# Prosessing flights from today_date = '2022-12-08' to tomorrow_date = '2022-12-09'
# Prosessing flights from today_date = '2022-12-09' to tomorrow_date = '2022-12-10'
# Prosessing flights from today_date = '2022-12-10' to tomorrow_date = '2022-12-11'
# Prosessing flights from today_date = '2022-12-11' to tomorrow_date = '2022-12-12'
# Prosessing flights from today_date = '2022-12-12' to tomorrow_date = '2022-12-13'
# Prosessing flights from today_date = '2022-12-13' to tomorrow_date = '2022-12-14'
# Prosessing flights from today_date = '2022-12-14' to tomorrow_date = '2022-12-15'
# Prosessing flights from today_date = '2022-12-15' to tomorrow_date = '2022-12-16'
# Prosessing flights from today_date = '2022-12-16' to tomorrow_date = '2022-12-17'
# Prosessing flights from today_date = '2022-12-17' to tomorrow_date = '2022-12-18'
# Prosessing flights from today_date = '2022-12-18' to tomorrow_date = '2022-12-19'
# Prosessing flights from today_date = '2022-12-19' to tomorrow_date = '2022-12-20'
# Prosessing flights from today_date = '2022-12-20' to tomorrow_date = '2022-12-21'
# Prosessing flights from today_date = '2022-12-21' to tomorrow_date = '2022-12-22'
# Prosessing flights from today_date = '2022-12-22' to tomorrow_date = '2022-12-23'
# Prosessing flights from today_date = '2022-12-23' to tomorrow_date = '2022-12-24'
# Prosessing flights from today_date = '2022-12-24' to tomorrow_date = '2022-12-25'
# Prosessing flights from today_date = '2022-12-25' to tomorrow_date = '2022-12-26'
# Prosessing flights from today_date = '2022-12-26' to tomorrow_date = '2022-12-27'
# Prosessing flights from today_date = '2022-12-27' to tomorrow_date = '2022-12-28'
# Prosessing flights from today_date = '2022-12-28' to tomorrow_date = '2022-12-29'
# Prosessing flights from today_date = '2022-12-29' to tomorrow_date = '2022-12-30'
# Prosessing flights from today_date = '2022-12-30' to tomorrow_date = '2022-12-31'
# Prosessing flights from today_date = '2022-12-31' to tomorrow_date = '2023-01-01'
#      flight_id       date                          callsign  adep  \
# 0    248763780 2022-01-01  3840d84f25d3f5fcc0a1be3076bb4039  EGLL
# 1    248760618 2022-01-01  f6f610e73002b8892a239a81321f7f1d  LEBL
# 2    248753824 2022-01-01  139670936660762c230ca92556ba842b  ESSA
# 3    248753852 2022-01-01  509dc61bb54fbab0e5406067c95603e2  LSZH
# 4    248755934 2022-01-01  d0610d000dcf26b1d7bba8103ecc393d  EIDW
# ..         ...        ...                               ...   ...
# 282  258058361 2022-12-31  85ee68e5b7b5acf24ba00d1318eca1e8  LFPG
# 283  258071247 2022-12-31  570cf7d5ebbd691bcba63e7466607da7  LTFM
# 284  258059152 2022-12-31  5a7e43e4f981539ae3d3b1cb31591b7c  EDDL
# 285  258072276 2022-12-31  a1c078516f9f9e90cacec61854cad45b  LFPG
# 286  258069969 2022-12-31  6c98fcaa191dec632b87b46511f1d2da  LEMD
#
#                    name_adep country_code_adep  ades           name_ades  \
# 0            London Heathrow                GB  EICK                Cork
# 1                  Barcelona                ES  KMIA               Miami
# 2          Stockholm Arlanda                SE  KORD      Chicago O'Hare
# 3                     Zurich                CH  KPHL        Philadelphia
# 4                     Dublin                IE  EGLL     London Heathrow
# ..                       ...               ...   ...                 ...
# 282  Paris Charles de Gaulle                FR  KMIA               Miami
# 283             iGA Istanbul                TR  EDDB  Berlin Brandenburg
# 284               Dusseldorf                DE  EIDW              Dublin
# 285  Paris Charles de Gaulle                FR  EIDW              Dublin
# 286           Madrid Barajas                ES  KJFK        New York JFK
#
#     country_code_ades  actual_offblock_time  ... longitude_median  \
# 0                  IE  2022-01-01T13:46:00Z  ...        -4.895513
# 1                  US  2022-01-01T09:55:00Z  ...       -10.289873
# 2                  US  2022-01-01T09:39:00Z  ...         0.848592
# 3                  US  2022-01-01T11:04:00Z  ...       -58.456228
# 4                  GB  2022-01-01T12:36:00Z  ...        -6.001753
# ..                ...                   ...  ...              ...
# 282                US  2022-12-31T09:38:00Z  ...        -6.812298
# 283                DE  2022-12-31T09:27:00Z  ...        19.895807
# 284                IE  2022-12-31T09:52:00Z  ...        -1.753693
# 285                IE  2022-12-31T09:37:00Z  ...        -2.913676
# 286                US  2022-12-31T09:38:00Z  ...        -8.061205
#
#     altitude_mean groundspeed_mean  track_mean  vertical_rate_mean  \
# 0    20996.873271       317.161594  266.904445           12.768124
# 1    30316.293173       425.555502  253.416154           66.719357
# 2    28087.460730       346.017174  234.214404          -35.945267
# 3    31606.355298       405.077422  260.254022           80.900909
# 4    14895.710572       354.972270  131.665419         2754.662045
# ..            ...              ...         ...                 ...
# 282  27520.238596       352.816281  258.075719          105.885193
# 283  31307.635402       358.665526  312.942321          -74.184695
# 284  27064.704323       306.001767  278.353987         -246.922841
# 285  29506.571457       302.045249  299.062133         -271.516294
# 286  33049.457127       451.331570  301.079038          397.202673
#
#      track_unwrapped_mean  u_component_of_wind_mean  v_component_of_wind_mean  \
# 0              266.904445                 31.354330                 28.956784
# 1              254.283623                 21.483643                 -8.009300
# 2              226.498682                 28.988018                  5.062526
# 3              177.655929                 32.200133                  2.404330
# 4              131.665419                 22.697229                 20.421709
# ..                    ...                       ...                       ...
# 282            258.075719                 41.300959                 34.816118
# 283            312.942321                 16.449682                -17.756664
# 284            279.965484                 48.607200                 26.609141
# 285            299.062133                 45.752148                 27.416125
# 286            301.079038                 23.918405                 29.032129
#
#      temperature_mean  specific_humidity_mean
# 0          244.875034                0.001527
# 1          227.431051                0.000523
# 2          225.055003                0.000467
# 3          227.891101                0.000931
# 4          255.205584                0.001545
# ..                ...                     ...
# 282        230.600595                0.001169
# 283        222.159498                0.000440
# 284        229.831493                0.001106
# 285        225.945456                0.000713
# 286        222.094395                0.000051
#
# [369013 rows x 29 columns]

# %%
def save_dataframe(path: str, dataframe: pd.DataFrame) -> None:
    dataframe.to_csv(path, index=False)
    print(f"{path} is saved!")

# %%
save_dataframe(path="../challenge_set_with_trajectory.csv", dataframe=challenge_set_with_trajectory)
# Out:
# ../challenge_set_with_trajectory.csv is saved!

# %%
submission_set = pd.read_csv('../submission_set.csv')

submission_set['date'] = pd.to_datetime(submission_set['date'])

display(submission_set)
# Out:
#         flight_id       date                          callsign  adep  \
# 0       248753821 2022-01-01  3b3de0f3ad0ee192513995c02f7bf7cf  LTFJ
# 1       248753822 2022-01-01  e06dd03d4a879ca37d9e18c1bd7cad16  EBBR
# 2       248754498 2022-01-01  2d3b1c962c78c4ebeef11bcd51b9e94c  KMIA
# 3       248757623 2022-01-01  81564432d3ee97c4bdf4cd8f006753dc  EGCN
# 4       248763603 2022-01-01  84be079d7e660db105d91f600b4b3d59  EIDW
# ...           ...        ...                               ...   ...
# 105954  258066302 2022-12-31  2d3b4446c4d05a25196a9d52cab936fb  LTFJ
# 105955  258068609 2022-12-31  253fd692ed441fac523081471c067772  LOWW
# 105956  258068876 2022-12-31  c9fca302ca2e28acab0eb0bb1b46f11b  LTFM
# 105957  258064675 2022-12-31  00f96ad0e382476649574ba044c764fc  EHAM
# 105958  258058370 2022-12-31  5f0c222c7f7ceff3fbe75c854cce74c9  UBBB
#
#                      name_adep country_code_adep  ades          name_ades  \
# 0       Istanbul Sabiha Gokcen                TR  LFLL               Lyon
# 1                     Brussels                BE  KJFK       New York JFK
# 2                        Miami                US  EGLL    London Heathrow
# 3          Doncaster Sheffield                GB  LEAL           Alicante
# 4                       Dublin                IE  LFLL               Lyon
# ...                        ...               ...   ...                ...
# 105954  Istanbul Sabiha Gokcen                TR  EKCH         Copenhagen
# 105955                  Vienna                AT  KIAD  Washington Dulles
# 105956            iGA Istanbul                TR  LSZH             Zurich
# 105957               Amsterdam                NL  EDDF          Frankfurt
# 105958                    Baku                AZ  LTFM       iGA Istanbul
#
#        country_code_ades  actual_offblock_time          arrival_time  \
# 0                     FR  2022-01-01T09:44:00Z  2022-01-01T12:48:33Z
# 1                     US  2022-01-01T09:45:00Z  2022-01-01T17:49:51Z
# 2                     GB  2022-01-01T01:52:00Z  2022-01-01T09:55:16Z
# 3                     ES  2022-01-01T08:20:00Z  2022-01-01T11:06:08Z
# 4                     FR  2022-01-01T11:01:00Z  2022-01-01T13:00:43Z
# ...                  ...                   ...                   ...
# 105954                DK  2022-12-31T09:36:00Z  2022-12-31T13:12:17Z
# 105955                US  2022-12-31T09:49:00Z  2022-12-31T19:38:26Z
# 105956                CH  2022-12-31T09:25:00Z  2022-12-31T12:24:24Z
# 105957                DE  2022-12-31T10:04:21Z  2022-12-31T10:55:35Z
# 105958                TR  2022-12-31T09:40:00Z  2022-12-31T12:28:00Z
#
#        aircraft_type wtc                           airline  flight_duration  \
# 0               B738   M  6351ec1b849adacc0cbb3b1313d8d39b              170
# 1               A333   H  bdeeef3a675587d530de70a25d7118d2              470
# 2               B77W   H  5543e4dc327359ffaf5b9c0e6faaf0e1              473
# 3               B38M   M  3922524069809ac4326134429751e26f              156
# 4               A320   M  a73f82288988b79be490c6322f4c32ed              105
# ...              ...  ..                               ...              ...
# 105954          B38M   M  6351ec1b849adacc0cbb3b1313d8d39b              201
# 105955          B763   H  5d407cb11cc29578cc3e292e743f5393              575
# 105956          A321   M  6351ec1b849adacc0cbb3b1313d8d39b              154
# 105957          A320   M  f502877cab405652cf0dd70c2213e730               42
# 105958          B738   M  6351ec1b849adacc0cbb3b1313d8d39b              158
#
#         taxiout_time  flown_distance  tow
# 0                 15            1122  NaN
# 1                 15            3205  NaN
# 2                 10            3965  NaN
# 3                 10             986  NaN
# 4                 15             686  NaN
# ...              ...             ...  ...
# 105954            15            1199  NaN
# 105955            14            3937  NaN
# 105956            25             988  NaN
# 105957             9             240  NaN
# 105958            10            1014  NaN
#
# [105959 rows x 18 columns]

# %%
submission_set_with_trajectory = pd.DataFrame({})

unique_dates = submission_set['date'].unique()
for current_date in unique_dates:
    today_date = str(current_date.date())
    tomorrow_date = str((current_date + timedelta(days=1)).date())
    print(f"Prosessing flights from {today_date = } to {tomorrow_date = }")

    if today_date != '2022-12-31':
        today_trajectory_df = pq.ParquetDataset(f'../data/trajactory_files/{today_date}.parquet').read().to_pandas()
        tomorrow_trajectory_df = pq.ParquetDataset(f'../data/trajactory_files/{tomorrow_date}.parquet').read().to_pandas()
        trajectory_df = pd.concat([today_trajectory_df, tomorrow_trajectory_df], ignore_index=True)
    else:
        trajectory_df = pq.ParquetDataset(f'../data/trajactory_files/{today_date}.parquet').read().to_pandas()
        
    summarized_trajectory_df = summarize_trajectories(trajectory_df=trajectory_df)
    
    filtered_df = submission_set[submission_set['date'] == current_date]

    merged_df = pd.merge(filtered_df, summarized_trajectory_df, on='flight_id', how='left')
    
    submission_set_with_trajectory = pd.concat([submission_set_with_trajectory, merged_df], ignore_index=False)
        
display(submission_set_with_trajectory)
# Out:
# Prosessing flights from today_date = '2022-01-01' to tomorrow_date = '2022-01-02'
# Prosessing flights from today_date = '2022-01-02' to tomorrow_date = '2022-01-03'
# Prosessing flights from today_date = '2022-01-03' to tomorrow_date = '2022-01-04'
# Prosessing flights from today_date = '2022-01-04' to tomorrow_date = '2022-01-05'
# Prosessing flights from today_date = '2022-01-05' to tomorrow_date = '2022-01-06'
# Prosessing flights from today_date = '2022-01-06' to tomorrow_date = '2022-01-07'
# Prosessing flights from today_date = '2022-01-07' to tomorrow_date = '2022-01-08'
# Prosessing flights from today_date = '2022-01-08' to tomorrow_date = '2022-01-09'
# Prosessing flights from today_date = '2022-01-09' to tomorrow_date = '2022-01-10'
# Prosessing flights from today_date = '2022-01-10' to tomorrow_date = '2022-01-11'
# Prosessing flights from today_date = '2022-01-11' to tomorrow_date = '2022-01-12'
# Prosessing flights from today_date = '2022-01-12' to tomorrow_date = '2022-01-13'
# Prosessing flights from today_date = '2022-01-13' to tomorrow_date = '2022-01-14'
# Prosessing flights from today_date = '2022-01-14' to tomorrow_date = '2022-01-15'
# Prosessing flights from today_date = '2022-01-15' to tomorrow_date = '2022-01-16'
# Prosessing flights from today_date = '2022-01-16' to tomorrow_date = '2022-01-17'
# Prosessing flights from today_date = '2022-01-17' to tomorrow_date = '2022-01-18'
# Prosessing flights from today_date = '2022-01-18' to tomorrow_date = '2022-01-19'
# Prosessing flights from today_date = '2022-01-19' to tomorrow_date = '2022-01-20'
# Prosessing flights from today_date = '2022-01-20' to tomorrow_date = '2022-01-21'
# Prosessing flights from today_date = '2022-01-21' to tomorrow_date = '2022-01-22'
# Prosessing flights from today_date = '2022-01-22' to tomorrow_date = '2022-01-23'
# Prosessing flights from today_date = '2022-01-23' to tomorrow_date = '2022-01-24'
# Prosessing flights from today_date = '2022-01-24' to tomorrow_date = '2022-01-25'
# Prosessing flights from today_date = '2022-01-25' to tomorrow_date = '2022-01-26'
# Prosessing flights from today_date = '2022-01-26' to tomorrow_date = '2022-01-27'
# Prosessing flights from today_date = '2022-01-27' to tomorrow_date = '2022-01-28'
# Prosessing flights from today_date = '2022-01-28' to tomorrow_date = '2022-01-29'
# Prosessing flights from today_date = '2022-01-29' to tomorrow_date = '2022-01-30'
# Prosessing flights from today_date = '2022-01-30' to tomorrow_date = '2022-01-31'
# Prosessing flights from today_date = '2022-01-31' to tomorrow_date = '2022-02-01'
# Prosessing flights from today_date = '2022-02-01' to tomorrow_date = '2022-02-02'
# Prosessing flights from today_date = '2022-02-02' to tomorrow_date = '2022-02-03'
# Prosessing flights from today_date = '2022-02-03' to tomorrow_date = '2022-02-04'
# Prosessing flights from today_date = '2022-02-04' to tomorrow_date = '2022-02-05'
# Prosessing flights from today_date = '2022-02-05' to tomorrow_date = '2022-02-06'
# Prosessing flights from today_date = '2022-02-06' to tomorrow_date = '2022-02-07'
# Prosessing flights from today_date = '2022-02-07' to tomorrow_date = '2022-02-08'
# Prosessing flights from today_date = '2022-02-08' to tomorrow_date = '2022-02-09'
# Prosessing flights from today_date = '2022-02-09' to tomorrow_date = '2022-02-10'
# Prosessing flights from today_date = '2022-02-10' to tomorrow_date = '2022-02-11'
# Prosessing flights from today_date = '2022-02-11' to tomorrow_date = '2022-02-12'
# Prosessing flights from today_date = '2022-02-12' to tomorrow_date = '2022-02-13'
# Prosessing flights from today_date = '2022-02-13' to tomorrow_date = '2022-02-14'
# Prosessing flights from today_date = '2022-02-14' to tomorrow_date = '2022-02-15'
# Prosessing flights from today_date = '2022-02-15' to tomorrow_date = '2022-02-16'
# Prosessing flights from today_date = '2022-02-16' to tomorrow_date = '2022-02-17'
# Prosessing flights from today_date = '2022-02-17' to tomorrow_date = '2022-02-18'
# Prosessing flights from today_date = '2022-02-18' to tomorrow_date = '2022-02-19'
# Prosessing flights from today_date = '2022-02-19' to tomorrow_date = '2022-02-20'
# Prosessing flights from today_date = '2022-02-20' to tomorrow_date = '2022-02-21'
# Prosessing flights from today_date = '2022-02-21' to tomorrow_date = '2022-02-22'
# Prosessing flights from today_date = '2022-02-22' to tomorrow_date = '2022-02-23'
# Prosessing flights from today_date = '2022-02-23' to tomorrow_date = '2022-02-24'
# Prosessing flights from today_date = '2022-02-24' to tomorrow_date = '2022-02-25'
# Prosessing flights from today_date = '2022-02-25' to tomorrow_date = '2022-02-26'
# Prosessing flights from today_date = '2022-02-26' to tomorrow_date = '2022-02-27'
# Prosessing flights from today_date = '2022-02-27' to tomorrow_date = '2022-02-28'
# Prosessing flights from today_date = '2022-02-28' to tomorrow_date = '2022-03-01'
# Prosessing flights from today_date = '2022-03-01' to tomorrow_date = '2022-03-02'
# Prosessing flights from today_date = '2022-03-02' to tomorrow_date = '2022-03-03'
# Prosessing flights from today_date = '2022-03-03' to tomorrow_date = '2022-03-04'
# Prosessing flights from today_date = '2022-03-04' to tomorrow_date = '2022-03-05'
# Prosessing flights from today_date = '2022-03-05' to tomorrow_date = '2022-03-06'
# Prosessing flights from today_date = '2022-03-06' to tomorrow_date = '2022-03-07'
# Prosessing flights from today_date = '2022-03-07' to tomorrow_date = '2022-03-08'
# Prosessing flights from today_date = '2022-03-08' to tomorrow_date = '2022-03-09'
# Prosessing flights from today_date = '2022-03-09' to tomorrow_date = '2022-03-10'
# Prosessing flights from today_date = '2022-03-10' to tomorrow_date = '2022-03-11'
# Prosessing flights from today_date = '2022-03-11' to tomorrow_date = '2022-03-12'
# Prosessing flights from today_date = '2022-03-12' to tomorrow_date = '2022-03-13'
# Prosessing flights from today_date = '2022-03-13' to tomorrow_date = '2022-03-14'
# Prosessing flights from today_date = '2022-03-14' to tomorrow_date = '2022-03-15'
# Prosessing flights from today_date = '2022-03-15' to tomorrow_date = '2022-03-16'
# Prosessing flights from today_date = '2022-03-16' to tomorrow_date = '2022-03-17'
# Prosessing flights from today_date = '2022-03-17' to tomorrow_date = '2022-03-18'
# Prosessing flights from today_date = '2022-03-18' to tomorrow_date = '2022-03-19'
# Prosessing flights from today_date = '2022-03-19' to tomorrow_date = '2022-03-20'
# Prosessing flights from today_date = '2022-03-20' to tomorrow_date = '2022-03-21'
# Prosessing flights from today_date = '2022-03-21' to tomorrow_date = '2022-03-22'
# Prosessing flights from today_date = '2022-03-22' to tomorrow_date = '2022-03-23'
# Prosessing flights from today_date = '2022-03-23' to tomorrow_date = '2022-03-24'
# Prosessing flights from today_date = '2022-03-24' to tomorrow_date = '2022-03-25'
# Prosessing flights from today_date = '2022-03-25' to tomorrow_date = '2022-03-26'
# Prosessing flights from today_date = '2022-03-26' to tomorrow_date = '2022-03-27'
# Prosessing flights from today_date = '2022-03-27' to tomorrow_date = '2022-03-28'
# Prosessing flights from today_date = '2022-03-28' to tomorrow_date = '2022-03-29'
# Prosessing flights from today_date = '2022-03-29' to tomorrow_date = '2022-03-30'
# Prosessing flights from today_date = '2022-03-30' to tomorrow_date = '2022-03-31'
# Prosessing flights from today_date = '2022-03-31' to tomorrow_date = '2022-04-01'
# Prosessing flights from today_date = '2022-04-01' to tomorrow_date = '2022-04-02'
# Prosessing flights from today_date = '2022-04-02' to tomorrow_date = '2022-04-03'
# Prosessing flights from today_date = '2022-04-03' to tomorrow_date = '2022-04-04'
# Prosessing flights from today_date = '2022-04-04' to tomorrow_date = '2022-04-05'
# Prosessing flights from today_date = '2022-04-05' to tomorrow_date = '2022-04-06'
# Prosessing flights from today_date = '2022-04-06' to tomorrow_date = '2022-04-07'
# Prosessing flights from today_date = '2022-04-07' to tomorrow_date = '2022-04-08'
# Prosessing flights from today_date = '2022-04-08' to tomorrow_date = '2022-04-09'
# Prosessing flights from today_date = '2022-04-09' to tomorrow_date = '2022-04-10'
# Prosessing flights from today_date = '2022-04-10' to tomorrow_date = '2022-04-11'
# Prosessing flights from today_date = '2022-04-11' to tomorrow_date = '2022-04-12'
# Prosessing flights from today_date = '2022-04-12' to tomorrow_date = '2022-04-13'
# Prosessing flights from today_date = '2022-04-13' to tomorrow_date = '2022-04-14'
# Prosessing flights from today_date = '2022-04-14' to tomorrow_date = '2022-04-15'
# Prosessing flights from today_date = '2022-04-15' to tomorrow_date = '2022-04-16'
# Prosessing flights from today_date = '2022-04-16' to tomorrow_date = '2022-04-17'
# Prosessing flights from today_date = '2022-04-17' to tomorrow_date = '2022-04-18'
# Prosessing flights from today_date = '2022-04-18' to tomorrow_date = '2022-04-19'
# Prosessing flights from today_date = '2022-04-19' to tomorrow_date = '2022-04-20'
# Prosessing flights from today_date = '2022-04-20' to tomorrow_date = '2022-04-21'
# Prosessing flights from today_date = '2022-04-21' to tomorrow_date = '2022-04-22'
# Prosessing flights from today_date = '2022-04-22' to tomorrow_date = '2022-04-23'
# Prosessing flights from today_date = '2022-04-23' to tomorrow_date = '2022-04-24'
# Prosessing flights from today_date = '2022-04-24' to tomorrow_date = '2022-04-25'
# Prosessing flights from today_date = '2022-04-25' to tomorrow_date = '2022-04-26'
# Prosessing flights from today_date = '2022-04-26' to tomorrow_date = '2022-04-27'
# Prosessing flights from today_date = '2022-04-27' to tomorrow_date = '2022-04-28'
# Prosessing flights from today_date = '2022-04-28' to tomorrow_date = '2022-04-29'
# Prosessing flights from today_date = '2022-04-29' to tomorrow_date = '2022-04-30'
# Prosessing flights from today_date = '2022-04-30' to tomorrow_date = '2022-05-01'
# Prosessing flights from today_date = '2022-05-01' to tomorrow_date = '2022-05-02'
# Prosessing flights from today_date = '2022-05-02' to tomorrow_date = '2022-05-03'
# Prosessing flights from today_date = '2022-05-03' to tomorrow_date = '2022-05-04'
# Prosessing flights from today_date = '2022-05-04' to tomorrow_date = '2022-05-05'
# Prosessing flights from today_date = '2022-05-05' to tomorrow_date = '2022-05-06'
# Prosessing flights from today_date = '2022-05-06' to tomorrow_date = '2022-05-07'
# Prosessing flights from today_date = '2022-05-07' to tomorrow_date = '2022-05-08'
# Prosessing flights from today_date = '2022-05-08' to tomorrow_date = '2022-05-09'
# Prosessing flights from today_date = '2022-05-09' to tomorrow_date = '2022-05-10'
# Prosessing flights from today_date = '2022-05-10' to tomorrow_date = '2022-05-11'
# Prosessing flights from today_date = '2022-05-11' to tomorrow_date = '2022-05-12'
# Prosessing flights from today_date = '2022-05-12' to tomorrow_date = '2022-05-13'
# Prosessing flights from today_date = '2022-05-13' to tomorrow_date = '2022-05-14'
# Prosessing flights from today_date = '2022-05-14' to tomorrow_date = '2022-05-15'
# Prosessing flights from today_date = '2022-05-15' to tomorrow_date = '2022-05-16'
# Prosessing flights from today_date = '2022-05-16' to tomorrow_date = '2022-05-17'
# Prosessing flights from today_date = '2022-05-17' to tomorrow_date = '2022-05-18'
# Prosessing flights from today_date = '2022-05-18' to tomorrow_date = '2022-05-19'
# Prosessing flights from today_date = '2022-05-19' to tomorrow_date = '2022-05-20'
# Prosessing flights from today_date = '2022-05-20' to tomorrow_date = '2022-05-21'
# Prosessing flights from today_date = '2022-05-21' to tomorrow_date = '2022-05-22'
# Prosessing flights from today_date = '2022-05-22' to tomorrow_date = '2022-05-23'
# Prosessing flights from today_date = '2022-05-23' to tomorrow_date = '2022-05-24'
# Prosessing flights from today_date = '2022-05-24' to tomorrow_date = '2022-05-25'
# Prosessing flights from today_date = '2022-05-25' to tomorrow_date = '2022-05-26'
# Prosessing flights from today_date = '2022-05-26' to tomorrow_date = '2022-05-27'
# Prosessing flights from today_date = '2022-05-27' to tomorrow_date = '2022-05-28'
# Prosessing flights from today_date = '2022-05-28' to tomorrow_date = '2022-05-29'
# Prosessing flights from today_date = '2022-05-29' to tomorrow_date = '2022-05-30'
# Prosessing flights from today_date = '2022-05-30' to tomorrow_date = '2022-05-31'
# Prosessing flights from today_date = '2022-05-31' to tomorrow_date = '2022-06-01'
# Prosessing flights from today_date = '2022-06-01' to tomorrow_date = '2022-06-02'

# %%
save_dataframe(path="../submission_set_with_trajectory.csv", dataframe=submission_set_with_trajectory)
