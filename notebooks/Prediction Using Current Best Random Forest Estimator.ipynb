# %% [markdown]
# <h1>Prediction Using Current Best Random Forest Estimator</h1>

# %%
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h3>A - Import Training Data</h3>

# %%
encoded_challenge_set = pd.read_csv('../data/encoded_challenge_set.csv')

# Pick up features from dataset
enccoded_training_features = encoded_challenge_set[['adep', 'country_code_adep', 'ades', 
                                           'country_code_ades', 'aircraft_type', 
                                           'wtc', 'airline', 'flight_duration', 
                                           'taxiout_time', 'flown_distance', 
                                           'month-day', 'month', 'day_in_month', 'min_tow', 'max_tow' ]]

# Pick up target from dataset
target = encoded_challenge_set['tow']

# %% [markdown]
# <h3>B - Train a RandomForestRegressor</h3>

# %%
rf = RandomForestRegressor(
    n_estimators=12, # From elbow graph in CV Grid Search 
)

rf.fit(enccoded_training_features, target)
# Out:
# RandomForestRegressor(n_estimators=12)

# %% [markdown]
# <h3>C - Predict for Submission</h3>

# %%
encoded_submission_set = pd.read_csv('../data/encoded_submission_set.csv')

# Pick up features from dataset
encoded_submission_features = encoded_submission_set[['adep', 'country_code_adep', 'ades', 'country_code_ades', 'aircraft_type', 'wtc', 'airline', 
                                                      'flight_duration', 'taxiout_time', 'flown_distance', 'month-day', 'month', 'day_in_month', 
                                                      'min_tow', 'max_tow']]

predicted_tow = rf.predict(encoded_submission_features)

predicted_submission_set = encoded_submission_features.copy()
predicted_submission_set['flight_id'] = encoded_submission_set['flight_id']
predicted_submission_set['tow'] = predicted_tow.astype("int64")
display(predicted_submission_set)

submission_file_content = predicted_submission_set[['flight_id', 'tow']]
display(submission_file_content)
# Out:
#         adep  country_code_adep  ades  country_code_ades  aircraft_type  wtc  \
# 0        384                 96   216                 26             14    1
# 1         17                 11   162                 78              7    0
# 2        190                 99    58                 27             20    0
# 3         61                 37   189                 24             11    1
# 4         92                 44   216                 26              4    1
# ...      ...                ...   ...                ...            ...  ...
# 105954   384                 96    85                 20             11    1
# 105955   321                  5   160                 78             17    0
# 105956   385                 96   309                 14              5    1
# 105957    85                 73    18                 19              4    1
# 105958   439                  7   337                 75             14    1
#
#         airline  flight_duration  taxiout_time  flown_distance  month-day  \
# 0            14              170            15            1122          0
# 1            22              470            15            3205          0
# 2            10              473            10            3965          0
# 3             6              156            10             986          0
# 4            20              105            15             686          0
# ...         ...              ...           ...             ...        ...
# 105954       14              201            15            1199        364
# 105955       13              575            14            3937        364
# 105956       14              154            25             988        364
# 105957       27               42             9             240        364
# 105958       14              158            10            1014        364
#
#         month  day_in_month   min_tow   max_tow  flight_id     tow
# 0           1             1   43724.0   78816.0  248753821   66938
# 1           1             1  134373.0  241487.0  248753822  202563
# 2           1             1  181041.0  351327.0  248754498  220493
# 3           1             1   45835.0   81835.0  248757623   61417
# 4           1             1   44861.0   76844.0  248763603   63043
# ...       ...           ...       ...       ...        ...     ...
# 105954     12            31   45835.0   81835.0  258066302   69119
# 105955     12            31   96542.0  186611.0  258068609  173234
# 105956     12            31   51694.0   88682.0  258068876   75411
# 105957     12            31   44861.0   76844.0  258064675   60732
# 105958     12            31   43724.0   78816.0  258058370   66907
#
# [105959 rows x 17 columns]
#         flight_id     tow
# 0       248753821   66938
# 1       248753822  202563
# 2       248754498  220493
# 3       248757623   61417
# 4       248763603   63043
# ...           ...     ...
# 105954  258066302   69119
# 105955  258068609  173234
# 105956  258068876   75411
# 105957  258064675   60732
# 105958  258058370   66907
#
# [105959 rows x 2 columns]

# %%
def save_dataframe(path: str, df: pd.DataFrame) -> None:
    df.to_csv(path, index=False)
    print(f"{path} is saved!")

save_dataframe(path="../data/my_submission.csv", df=submission_file_content)
# Out:
# ../data/my_submission.csv is saved!
