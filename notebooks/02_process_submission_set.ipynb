# %%
import pandas as pd

# %%
submission_set_df = pd.read_csv('../PRC_data/submission_set.csv')

# %%
display(submission_set_df)
# Out:
#         flight_id        date                          callsign  adep  \
# 0       248753821  2022-01-01  3b3de0f3ad0ee192513995c02f7bf7cf  LTFJ
# 1       248753822  2022-01-01  e06dd03d4a879ca37d9e18c1bd7cad16  EBBR
# 2       248754498  2022-01-01  2d3b1c962c78c4ebeef11bcd51b9e94c  KMIA
# 3       248757623  2022-01-01  81564432d3ee97c4bdf4cd8f006753dc  EGCN
# 4       248763603  2022-01-01  84be079d7e660db105d91f600b4b3d59  EIDW
# ...           ...         ...                               ...   ...
# 105954  258066302  2022-12-31  2d3b4446c4d05a25196a9d52cab936fb  LTFJ
# 105955  258068609  2022-12-31  253fd692ed441fac523081471c067772  LOWW
# 105956  258068876  2022-12-31  c9fca302ca2e28acab0eb0bb1b46f11b  LTFM
# 105957  258064675  2022-12-31  00f96ad0e382476649574ba044c764fc  EHAM
# 105958  258058370  2022-12-31  5f0c222c7f7ceff3fbe75c854cce74c9  UBBB
#
#                      name_adep country_code_adep  ades          name_ades  \
# ...

# %% [markdown]
# <h3>Drop the columns <strong>callsign, name_adep, and name_ades<strong/></h3>

# %%
submission_set_df = submission_set_df.drop(columns=['callsign', 'name_adep', 'name_ades'])

# %% [markdown]
# <h3>Split the <strong>date</strong> column into</h3>
# <ul>
#     <li>month_day</li>
#     <li>month</li>
#     <li>day</li>
# </ul>
# <h3>Drop the <strong>date</strong> columns</h3>

# %%
submission_set_df['date'] = pd.to_datetime(submission_set_df['date'])
submission_set_df['month_day'] = submission_set_df['date'].dt.strftime('%m-%d')  # Format to get month and day together
submission_set_df['month'] = submission_set_df['date'].dt.month  # Extract the month
submission_set_df['day'] = submission_set_df['date'].dt.day  # Extract the day

# %%
display(submission_set_df[['flight_id', 'date', 'month_day', 'month', 'day']])
# Out:
#         flight_id       date month_day  month  day
# 0       248753821 2022-01-01     01-01      1    1
# 1       248753822 2022-01-01     01-01      1    1
# 2       248754498 2022-01-01     01-01      1    1
# 3       248757623 2022-01-01     01-01      1    1
# 4       248763603 2022-01-01     01-01      1    1
# ...           ...        ...       ...    ...  ...
# 105954  258066302 2022-12-31     12-31     12   31
# 105955  258068609 2022-12-31     12-31     12   31
# 105956  258068876 2022-12-31     12-31     12   31
# 105957  258064675 2022-12-31     12-31     12   31
# 105958  258058370 2022-12-31     12-31     12   31
#
# [105959 rows x 5 columns]

# %%
submission_set_df = submission_set_df.drop(columns=['date'])

# %% [markdown]
# <h3>Split the <strong>actual_offblock_time</strong> and <strong>arrival_time</strong> columns into</h3>
# <ul>
#     <li><strong>actual_offblock_time_hour_minute<strong/></li>
#     <li><strong>actual_offblock_time_hour<strong/></li>
#     <li><strong>actual_offblock_time_minute<strong/></li>
#     <li><strong>arrival_time_hour_minute<strong/></li>
#     <li><strong>arrival_time_hour<strong/></li>
#     <li><strong>arrival_time_minute<strong/></li>
# </ul>
# <h3>Drop the <strong>actual_offblock_time</strong> and <strong>arrival_time</strong> columns</h3>

# %%
submission_set_df['actual_offblock_time'] = pd.to_datetime(submission_set_df['actual_offblock_time'])
submission_set_df['actual_offblock_time_hour_minute'] = submission_set_df['actual_offblock_time'].dt.strftime('%H:%M')
submission_set_df['actual_offblock_time_hour'] = submission_set_df['actual_offblock_time'].dt.hour
submission_set_df['actual_offblock_time_minute'] = submission_set_df['actual_offblock_time'].dt.minute

submission_set_df['arrival_time'] = pd.to_datetime(submission_set_df['arrival_time'])
submission_set_df['arrival_time_hour_minute'] = submission_set_df['arrival_time'].dt.strftime('%H:%M')
submission_set_df['arrival_time_hour'] = submission_set_df['arrival_time'].dt.hour
submission_set_df['arrival_time_minute'] = submission_set_df['arrival_time'].dt.minute

# %%
display(submission_set_df[['flight_id', 
                          'actual_offblock_time', 'actual_offblock_time_hour_minute', 'actual_offblock_time_hour', 'actual_offblock_time_minute',
                          'arrival_time', 'arrival_time_hour_minute', 'arrival_time_hour', 'arrival_time_minute']])
# Out:
#         flight_id      actual_offblock_time actual_offblock_time_hour_minute  \
# 0       248753821 2022-01-01 09:44:00+00:00                            09:44
# 1       248753822 2022-01-01 09:45:00+00:00                            09:45
# 2       248754498 2022-01-01 01:52:00+00:00                            01:52
# 3       248757623 2022-01-01 08:20:00+00:00                            08:20
# 4       248763603 2022-01-01 11:01:00+00:00                            11:01
# ...           ...                       ...                              ...
# 105954  258066302 2022-12-31 09:36:00+00:00                            09:36
# 105955  258068609 2022-12-31 09:49:00+00:00                            09:49
# 105956  258068876 2022-12-31 09:25:00+00:00                            09:25
# 105957  258064675 2022-12-31 10:04:21+00:00                            10:04
# 105958  258058370 2022-12-31 09:40:00+00:00                            09:40
#
# ...

# %%
submission_set_df = submission_set_df.drop(columns=['actual_offblock_time', 'arrival_time'])

# %% [markdown]
# <h3>Construct/Order submission set</h3>

# %%
submission_set_df = submission_set_df[[
    'flight_id', 'month_day', 'month', 'day', 'actual_offblock_time_hour_minute', 'actual_offblock_time_hour', 'actual_offblock_time_minute',
    'adep', 'country_code_adep', 'arrival_time_hour_minute', 'arrival_time_hour', 'arrival_time_minute', 'ades', 'country_code_ades',
    'aircraft_type', 'wtc', 'airline', 'flight_duration', 'taxiout_time', 'flown_distance', 'tow'
]]

# %%
display(submission_set_df)
# Out:
#         flight_id month_day  month  day actual_offblock_time_hour_minute  \
# 0       248753821     01-01      1    1                            09:44
# 1       248753822     01-01      1    1                            09:45
# 2       248754498     01-01      1    1                            01:52
# 3       248757623     01-01      1    1                            08:20
# 4       248763603     01-01      1    1                            11:01
# ...           ...       ...    ...  ...                              ...
# 105954  258066302     12-31     12   31                            09:36
# 105955  258068609     12-31     12   31                            09:49
# 105956  258068876     12-31     12   31                            09:25
# 105957  258064675     12-31     12   31                            10:04
# 105958  258058370     12-31     12   31                            09:40
#
#         actual_offblock_time_hour  actual_offblock_time_minute  adep  \
# ...

# %%
df_filtered = submission_set_df.loc[:, submission_set_df.columns != 'tow']
rows_with_nan = df_filtered[df_filtered.isna().any(axis=1)]
display(rows_with_nan)
# Out:
# Empty DataFrame
# Columns: [flight_id, month_day, month, day, actual_offblock_time_hour_minute, actual_offblock_time_hour, actual_offblock_time_minute, adep, country_code_adep, arrival_time_hour_minute, arrival_time_hour, arrival_time_minute, ades, country_code_ades, aircraft_type, wtc, airline, flight_duration, taxiout_time, flown_distance]
# Index: []

# %%
submission_set_df.to_csv("./data/processed_submission_set.csv", index=False)
print(f"./data/processed_submission_set.csv is saved!")
# Out:
# ./data/processed_submission_set.csv is saved!
