# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import xgboost as xgb
import pandas as pd
import numpy as np

# %%
identifier_name = 'flight_id'

features_names = [
 'month_day',
 'month',
 'day',
 'actual_offblock_time_hour_minute',
 'actual_offblock_time_hour',
 'actual_offblock_time_minute',
 'adep',
 'country_code_adep',
 'arrival_time_hour_minute',
 'arrival_time_hour',
 'arrival_time_minute',
 'ades',
 'country_code_ades',
 'aircraft_type',
 'wtc',
 'airline',
 'flight_duration',
 'taxiout_time',
 'flown_distance',
 'latitude_count',
 'latitude_mean',
 'latitude_std',
 'latitude_min',
 'latitude_25percentile',
 'latitude_median',
 'latitude_75percentile',
 'latitude_max',
 'longitude_count',
 'longitude_mean',
 'longitude_std',
 'longitude_min',
 'longitude_25percentile',
 'longitude_median',
 'longitude_75percentile',
 'longitude_max',
 'altitude_count',
 'altitude_mean',
 'altitude_std',
 'altitude_min',
 'altitude_25percentile',
 'altitude_median',
 'altitude_75percentile',
 'altitude_max',
 'groundspeed_count',
 'groundspeed_mean',
 'groundspeed_std',
 'groundspeed_min',
 'groundspeed_25percentile',
 'groundspeed_median',
 'groundspeed_75percentile',
 'groundspeed_max',
 'track_count',
 'track_mean',
 'track_std',
 'track_min',
 'track_25percentile',
 'track_median',
 'track_75percentile',
 'track_max',
 'vertical_rate_count',
 'vertical_rate_mean',
 'vertical_rate_std',
 'vertical_rate_min',
 'vertical_rate_25percentile',
 'vertical_rate_median',
 'vertical_rate_75percentile',
 'vertical_rate_max',
 'track_unwrapped_count',
 'track_unwrapped_mean',
 'track_unwrapped_std',
 'track_unwrapped_min',
 'track_unwrapped_25percentile',
 'track_unwrapped_median',
 'track_unwrapped_75percentile',
 'track_unwrapped_max',
 'u_component_of_wind_count',
 'u_component_of_wind_mean',
 'u_component_of_wind_std',
 'u_component_of_wind_min',
 'u_component_of_wind_25percentile',
 'u_component_of_wind_median',
 'u_component_of_wind_75percentile',
 'u_component_of_wind_max',
 'v_component_of_wind_count',
 'v_component_of_wind_mean',
 'v_component_of_wind_std',
 'v_component_of_wind_min',
 'v_component_of_wind_25percentile',
 'v_component_of_wind_median',
 'v_component_of_wind_75percentile',
 'v_component_of_wind_max',
 'temperature_count',
 'temperature_mean',
 'temperature_std',
 'temperature_min',
 'temperature_25percentile',
 'temperature_median',
 'temperature_75percentile',
 'temperature_max',
 'specific_humidity_count',
 'specific_humidity_mean',
 'specific_humidity_std',
 'specific_humidity_min',
 'specific_humidity_25percentile',
 'specific_humidity_median',
 'specific_humidity_75percentile',
 'specific_humidity_max'
]

target_name = 'tow'

global_random_state = 123

# %%
encoded_challenge_set = pd.read_csv('data/encoded_challenge_set.csv')
encoded_challenge_set = encoded_challenge_set.fillna(0)
data_df = encoded_challenge_set[features_names+[target_name]]

# %%
all_rmse = []
n_clusters = list(range(1, 51, 1))

for n in n_clusters:
    print(f"Trying n_clusters: {n}...")
    
    #scaler = StandardScaler()
    #df_scaled = scaler.fit_transform(data_df)
    
    kmeans = KMeans(n_clusters=3, random_state=global_random_state)
    data_df['cluster'] = kmeans.fit_predict(data_df[features_names])

    mean_mse_score = []
    for cluster_nr in range(0, n, 1):
        cluster_df = data_df[data_df['cluster'] == cluster_nr]
        
        X = cluster_df[features_names]
        y = cluster_df[target_name]
        if cluster_df.empty:
            print(f"---> No samples in this cluster number: {cluster_nr}")
            continue

        model = xgb.XGBRegressor(
            colsample_bytree=1.0,
            learning_rate=0.1, 
            max_depth=10, 
            n_estimators=91, 
            subsample=1.0,
            objective='reg:squarederror', 
            eval_metric='rmse',
            random_state=global_random_state
        )
        
        kf = KFold(n_splits=3, shuffle=True, random_state=global_random_state)
        scores = cross_val_score(model, X, y, cv=kf, scoring='neg_mean_squared_error')
        mse_scores = -scores
        mean_mse = np.mean(mse_scores)
        mean_mse_score.append(mean_mse)
        print(f'---> cluster number: {cluster_nr}, MSE: {mean_mse:.4f}')

    n_clusters_rmse_score = np.sqrt(np.mean(mean_mse_score))
    all_rmse.append(n_clusters_rmse_score)
    print(f'***n_clusters={n}: {cluster_nr}, RMSE: {n_clusters_rmse_score:.4f}\n')
# Out:
# Trying n_clusters: 1...
# ---> cluster number: 0, MSE: 8412879.7320
# ***n_clusters=1: 0, RMSE: 2900.4965
#
# Trying n_clusters: 2...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ***n_clusters=2: 1, RMSE: 3531.5597
#
# Trying n_clusters: 3...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ***n_clusters=3: 2, RMSE: 3323.5726
#
# Trying n_clusters: 4...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ***n_clusters=4: 3, RMSE: 3323.5726
#
# Trying n_clusters: 5...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ***n_clusters=5: 4, RMSE: 3323.5726
#
# Trying n_clusters: 6...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ***n_clusters=6: 5, RMSE: 3323.5726
#
# Trying n_clusters: 7...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ***n_clusters=7: 6, RMSE: 3323.5726
#
# Trying n_clusters: 8...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ***n_clusters=8: 7, RMSE: 3323.5726
#
# Trying n_clusters: 9...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ***n_clusters=9: 8, RMSE: 3323.5726
#
# Trying n_clusters: 10...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ***n_clusters=10: 9, RMSE: 3323.5726
#
# Trying n_clusters: 11...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ***n_clusters=11: 10, RMSE: 3323.5726
#
# Trying n_clusters: 12...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ***n_clusters=12: 11, RMSE: 3323.5726
#
# Trying n_clusters: 13...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ***n_clusters=13: 12, RMSE: 3323.5726
#
# Trying n_clusters: 14...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ***n_clusters=14: 13, RMSE: 3323.5726
#
# Trying n_clusters: 15...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ***n_clusters=15: 14, RMSE: 3323.5726
#
# Trying n_clusters: 16...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ***n_clusters=16: 15, RMSE: 3323.5726
#
# Trying n_clusters: 17...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ***n_clusters=17: 16, RMSE: 3323.5726
#
# Trying n_clusters: 18...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ***n_clusters=18: 17, RMSE: 3323.5726
#
# Trying n_clusters: 19...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ***n_clusters=19: 18, RMSE: 3323.5726
#
# Trying n_clusters: 20...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ***n_clusters=20: 19, RMSE: 3323.5726
#
# Trying n_clusters: 21...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ***n_clusters=21: 20, RMSE: 3323.5726
#
# Trying n_clusters: 22...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ***n_clusters=22: 21, RMSE: 3323.5726
#
# Trying n_clusters: 23...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ***n_clusters=23: 22, RMSE: 3323.5726
#
# Trying n_clusters: 24...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ***n_clusters=24: 23, RMSE: 3323.5726
#
# Trying n_clusters: 25...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ---> No samples in this cluster number: 24
# ***n_clusters=25: 24, RMSE: 3323.5726
#
# Trying n_clusters: 26...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ---> No samples in this cluster number: 24
# ---> No samples in this cluster number: 25
# ***n_clusters=26: 25, RMSE: 3323.5726
#
# Trying n_clusters: 27...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ---> No samples in this cluster number: 24
# ---> No samples in this cluster number: 25
# ---> No samples in this cluster number: 26
# ***n_clusters=27: 26, RMSE: 3323.5726
#
# Trying n_clusters: 28...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ---> No samples in this cluster number: 24
# ---> No samples in this cluster number: 25
# ---> No samples in this cluster number: 26
# ---> No samples in this cluster number: 27
# ***n_clusters=28: 27, RMSE: 3323.5726
#
# Trying n_clusters: 29...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ---> No samples in this cluster number: 24
# ---> No samples in this cluster number: 25
# ---> No samples in this cluster number: 26
# ---> No samples in this cluster number: 27
# ---> No samples in this cluster number: 28
# ***n_clusters=29: 28, RMSE: 3323.5726
#
# Trying n_clusters: 30...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ---> No samples in this cluster number: 24
# ---> No samples in this cluster number: 25
# ---> No samples in this cluster number: 26
# ---> No samples in this cluster number: 27
# ---> No samples in this cluster number: 28
# ---> No samples in this cluster number: 29
# ***n_clusters=30: 29, RMSE: 3323.5726
#
# Trying n_clusters: 31...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ---> No samples in this cluster number: 24
# ---> No samples in this cluster number: 25
# ---> No samples in this cluster number: 26
# ---> No samples in this cluster number: 27
# ---> No samples in this cluster number: 28
# ---> No samples in this cluster number: 29
# ---> No samples in this cluster number: 30
# ***n_clusters=31: 30, RMSE: 3323.5726
#
# Trying n_clusters: 32...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ---> No samples in this cluster number: 24
# ---> No samples in this cluster number: 25
# ---> No samples in this cluster number: 26
# ---> No samples in this cluster number: 27
# ---> No samples in this cluster number: 28
# ---> No samples in this cluster number: 29
# ---> No samples in this cluster number: 30
# ---> No samples in this cluster number: 31
# ***n_clusters=32: 31, RMSE: 3323.5726
#
# Trying n_clusters: 33...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---> cluster number: 2, MSE: 8194576.7683
# ---> No samples in this cluster number: 3
# ---> No samples in this cluster number: 4
# ---> No samples in this cluster number: 5
# ---> No samples in this cluster number: 6
# ---> No samples in this cluster number: 7
# ---> No samples in this cluster number: 8
# ---> No samples in this cluster number: 9
# ---> No samples in this cluster number: 10
# ---> No samples in this cluster number: 11
# ---> No samples in this cluster number: 12
# ---> No samples in this cluster number: 13
# ---> No samples in this cluster number: 14
# ---> No samples in this cluster number: 15
# ---> No samples in this cluster number: 16
# ---> No samples in this cluster number: 17
# ---> No samples in this cluster number: 18
# ---> No samples in this cluster number: 19
# ---> No samples in this cluster number: 20
# ---> No samples in this cluster number: 21
# ---> No samples in this cluster number: 22
# ---> No samples in this cluster number: 23
# ---> No samples in this cluster number: 24
# ---> No samples in this cluster number: 25
# ---> No samples in this cluster number: 26
# ---> No samples in this cluster number: 27
# ---> No samples in this cluster number: 28
# ---> No samples in this cluster number: 29
# ---> No samples in this cluster number: 30
# ---> No samples in this cluster number: 31
# ---> No samples in this cluster number: 32
# ***n_clusters=33: 32, RMSE: 3323.5726
#
# Trying n_clusters: 34...
# ---> cluster number: 0, MSE: 8412879.7320
# ---> cluster number: 1, MSE: 16530948.0708
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 35
#      23 model = xgb.XGBRegressor(
#      24     colsample_bytree=1.0,
#      25     learning_rate=0.1,
#    (...)
#      31     random_state=global_random_state
#      32 )
#      34 kf = KFold(n_splits=3, shuffle=True, random_state=global_random_state)
# ---> 35 scores = cross_val_score(model, X, y, cv=kf, scoring='neg_mean_squared_error')
#      36 mse_scores = -scores
#      37 mean_mse = np.mean(mse_scores)
#
# File ~\miniconda3\envs\prc\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\miniconda3\envs\prc\Lib\site-packages\sklearn\model_selection\_validation.py:712, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, error_score)
#     709 # To ensure multimetric format is not supported
#     710 scorer = check_scoring(estimator, scoring=scoring)
# --> 712 cv_results = cross_validate(
#     713     estimator=estimator,
#     714     X=X,
#     715     y=y,
#     716     groups=groups,
#     717     scoring={"score": scorer},
#     718     cv=cv,
#     719     n_jobs=n_jobs,
#     720     verbose=verbose,
#     721     fit_params=fit_params,
#     722     params=params,
#     723     pre_dispatch=pre_dispatch,
#     724     error_score=error_score,
#     725 )
#     726 return cv_results["test_score"]
#
# File ~\miniconda3\envs\prc\Lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\miniconda3\envs\prc\Lib\site-packages\sklearn\model_selection\_validation.py:423, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     420 # We clone the estimator to make sure that all the folds are
#     421 # independent, and that it is pickle-able.
#     422 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 423 results = parallel(
#     424     delayed(_fit_and_score)(
#     425         clone(estimator),
#     426         X,
#     427         y,
#     428         scorer=scorers,
#     429         train=train,
#     430         test=test,
#     431         verbose=verbose,
#     432         parameters=None,
#     433         fit_params=routed_params.estimator.fit,
#     434         score_params=routed_params.scorer.score,
#     435         return_train_score=return_train_score,
#     436         return_times=True,
#     437         return_estimator=return_estimator,
#     438         error_score=error_score,
#     439     )
#     440     for train, test in indices
#     441 )
#     443 _warn_or_raise_about_fit_failures(results, error_score)
#     445 # For callable scoring, the return type is only know after calling. If the
#     446 # return type is a dictionary, the error scores can now be inserted with
#     447 # the correct key.
#
# File ~\miniconda3\envs\prc\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File ~\miniconda3\envs\prc\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File ~\miniconda3\envs\prc\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File ~\miniconda3\envs\prc\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File ~\miniconda3\envs\prc\Lib\site-packages\sklearn\model_selection\_validation.py:888, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     886         estimator.fit(X_train, **fit_params)
#     887     else:
# --> 888         estimator.fit(X_train, y_train, **fit_params)
#     890 except Exception:
#     891     # Note fit time as time until error
#     892     fit_time = time.time() - start_time
#
# File ~\miniconda3\envs\prc\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~\miniconda3\envs\prc\Lib\site-packages\xgboost\sklearn.py:1108, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1105     obj = None
#    1107 model, metric, params = self._configure_fit(xgb_model, params)
# -> 1108 self._Booster = train(
#    1109     params,
#    1110     train_dmatrix,
#    1111     self.get_num_boosting_rounds(),
#    1112     evals=evals,
#    1113     early_stopping_rounds=self.early_stopping_rounds,
#    1114     evals_result=evals_result,
#    1115     obj=obj,
#    1116     custom_metric=metric,
#    1117     verbose_eval=verbose,
#    1118     xgb_model=model,
#    1119     callbacks=self.callbacks,
#    1120 )
#    1122 self._set_evaluation_result(evals_result)
#    1123 return self
#
# File ~\miniconda3\envs\prc\Lib\site-packages\xgboost\core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~\miniconda3\envs\prc\Lib\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~\miniconda3\envs\prc\Lib\site-packages\xgboost\core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
for n_step in range(0, 50, 10):
    plt.bar(n_clusters[n_step:n_step+9], all_rmse[n_step+9])
    plt.title(f"Bar Plot of n_clusters with XGBoost RMSE {n_step}:{n_step+9}")
    plt.xlabel("n_clusters")
    plt.ylabel("RMSE Score")
    plt.xticks(ticks=n_clusters[n_step:n_step++9])
    plt.show()
    print()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 for n_step in range(0, 50, 10):
# ----> 2     plt.bar(n_clusters[n_step:n_step+9], all_rmse[n_step+9])
#       3     plt.title(f"Bar Plot of n_clusters with XGBoost RMSE {n_step}:{n_step+9}")
#       4     plt.xlabel("n_clusters")
#
# IndexError: list index out of range
