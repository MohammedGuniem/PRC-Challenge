# %% [markdown]
# <h1>Train, Evaluate & Test Optimal Model</h1>

# %%
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# <h3>A - Predicting using the tunned parameters of optimal model - RandomForestRegressor()</h3>

# %%
one_hot_encoded_challenge_set_df = pd.read_csv('../data/one_hot_encoded_challenge_set_df.csv')

excluded_columns = ['tow', 'aircraft_max_weight']
correlated_features = []
for column in one_hot_encoded_challenge_set_df.columns:
    if column not in excluded_columns:
        corr = one_hot_encoded_challenge_set_df[[column, 'tow']].corr().iloc[0, 1]
        if corr > 0.01 or corr < -0.01:
            print(f"correlation between '{column}' and target 'tow' is {corr}")
            correlated_features.append(column)

print(len(correlated_features))
print(correlated_features)
# Out:
# correlation between 'flight_duration' and target 'tow' is 0.8350272248730813
# correlation between 'taxiout_time' and target 'tow' is 0.3337631964550785
# correlation between 'flown_distance' and target 'tow' is 0.8433684844951457
# correlation between 'day_in_month' and target 'tow' is 0.01624142015804772
# correlation between 'adep_BKPR' and target 'tow' is -0.01095578246238765
# correlation between 'adep_CYUL' and target 'tow' is 0.012856071527535769
# correlation between 'adep_CYVR' and target 'tow' is 0.018977985668767405
# correlation between 'adep_CYYZ' and target 'tow' is 0.015048322037868203
# correlation between 'adep_EBAW' and target 'tow' is -0.024507555023334505
# correlation between 'adep_EBBR' and target 'tow' is -0.07739802964412812
# correlation between 'adep_EBOS' and target 'tow' is -0.01406596144052795
# correlation between 'adep_EDDB' and target 'tow' is -0.017738540569121473
# correlation between 'adep_EDDH' and target 'tow' is -0.03104382172970393
# correlation between 'adep_EDDK' and target 'tow' is -0.01954962912455184
# correlation between 'adep_EDDL' and target 'tow' is -0.026364323568613984
# correlation between 'adep_EDDM' and target 'tow' is -0.011657821854796748
# correlation between 'adep_EDDN' and target 'tow' is -0.013621979423520149
# correlation between 'adep_EDDP' and target 'tow' is -0.018729779758303578
# correlation between 'adep_EDDS' and target 'tow' is -0.021291136682470412
# correlation between 'adep_EDDV' and target 'tow' is -0.026721532222850196
# correlation between 'adep_EETN' and target 'tow' is -0.030364935720318502
# correlation between 'adep_EFHK' and target 'tow' is -0.039888113384042585
# correlation between 'adep_EFTU' and target 'tow' is -0.011257589961486984
# correlation between 'adep_EGAC' and target 'tow' is -0.01771143564537866
# correlation between 'adep_EGBB' and target 'tow' is -0.011078343932242751
# correlation between 'adep_EGKK' and target 'tow' is -0.014023010756753477
# correlation between 'adep_EGLC' and target 'tow' is -0.018962805511221953
# correlation between 'adep_EGLL' and target 'tow' is 0.09432361120292163
# correlation between 'adep_EGPD' and target 'tow' is -0.018709827018912162
# correlation between 'adep_EGPH' and target 'tow' is -0.013833006478070191
# correlation between 'adep_EICK' and target 'tow' is -0.020459874491309857
# correlation between 'adep_EIDW' and target 'tow' is 0.01878071373305388
# correlation between 'adep_EKAH' and target 'tow' is -0.048406435173154794
# correlation between 'adep_EKBI' and target 'tow' is -0.029466476646816158
# correlation between 'adep_EKCH' and target 'tow' is -0.10382152818993746
# correlation between 'adep_EKYT' and target 'tow' is -0.050280204487026005
# correlation between 'adep_ENAL' and target 'tow' is -0.02199518300369659
# correlation between 'adep_ENBO' and target 'tow' is -0.017902956379978113
# correlation between 'adep_ENBR' and target 'tow' is -0.06374834251565378
# correlation between 'adep_ENCN' and target 'tow' is -0.02473408783356954
# correlation between 'adep_ENGM' and target 'tow' is -0.06608302990497178
# correlation between 'adep_ENHD' and target 'tow' is -0.019074857066516814
# correlation between 'adep_ENVA' and target 'tow' is -0.0375391994010918
# correlation between 'adep_ENZV' and target 'tow' is -0.05121506540048726
# correlation between 'adep_EPGD' and target 'tow' is -0.02439891065788592
# correlation between 'adep_EPKK' and target 'tow' is -0.02041469838406873
# correlation between 'adep_EPPO' and target 'tow' is -0.01216004507300098
# correlation between 'adep_EPWA' and target 'tow' is -0.030416845826616114
# correlation between 'adep_ESDF' and target 'tow' is -0.02330816744703611
# correlation between 'adep_ESGG' and target 'tow' is -0.04257634217322028
# correlation between 'adep_ESMQ' and target 'tow' is -0.022041427157571136
# correlation between 'adep_ESMS' and target 'tow' is -0.025239897702165292
# correlation between 'adep_ESNN' and target 'tow' is -0.01729751626443672
# correlation between 'adep_ESNS' and target 'tow' is -0.016108829810688882
# correlation between 'adep_ESNU' and target 'tow' is -0.015385941814521445
# correlation between 'adep_ESNZ' and target 'tow' is -0.03145346811913441
# correlation between 'adep_ESPA' and target 'tow' is -0.015284353594066704
# correlation between 'adep_ESSA' and target 'tow' is -0.09330002287617147
# correlation between 'adep_ESSB' and target 'tow' is -0.012735102930875495
# correlation between 'adep_ESSV' and target 'tow' is -0.015485966165001181
# correlation between 'adep_ESTA' and target 'tow' is -0.040893931786158806
# correlation between 'adep_EYPA' and target 'tow' is -0.017003281563733895
# correlation between 'adep_EYVI' and target 'tow' is -0.03204597289997567
# correlation between 'adep_FACT' and target 'tow' is 0.010185678628330202
# correlation between 'adep_GLRB' and target 'tow' is 0.013600242519232782
# correlation between 'adep_KATL' and target 'tow' is 0.06268827193356577
# correlation between 'adep_KBOS' and target 'tow' is 0.10721365437433089
# correlation between 'adep_KCLT' and target 'tow' is 0.10205369412658341
# correlation between 'adep_KDFW' and target 'tow' is 0.15313528473936616
# correlation between 'adep_KEWR' and target 'tow' is 0.11996575949521716
# correlation between 'adep_KIAD' and target 'tow' is 0.08511782105349618
# correlation between 'adep_KIAH' and target 'tow' is 0.06697440202950765
# correlation between 'adep_KJFK' and target 'tow' is 0.23818832453329628
# correlation between 'adep_KLAX' and target 'tow' is 0.20537581404923128
# correlation between 'adep_KMCO' and target 'tow' is 0.07477448135199279
# correlation between 'adep_KMIA' and target 'tow' is 0.17288712152771493
# correlation between 'adep_KMLB' and target 'tow' is 0.054623070182868445
# correlation between 'adep_KORD' and target 'tow' is 0.19372253432495362
# correlation between 'adep_KPHL' and target 'tow' is 0.09095509130256825
# correlation between 'adep_KPHX' and target 'tow' is 0.03951084642561883
# correlation between 'adep_KRDU' and target 'tow' is 0.032065119853372896
# correlation between 'adep_KSEA' and target 'tow' is 0.06110477151306813
# correlation between 'adep_KSFO' and target 'tow' is 0.16739494851411765
# correlation between 'adep_LBSF' and target 'tow' is -0.020389218842368252
# correlation between 'adep_LDZA' and target 'tow' is -0.013438753738887003
# correlation between 'adep_LDZD' and target 'tow' is -0.010556670868234898
# correlation between 'adep_LEAL' and target 'tow' is -0.022801313127695094
# correlation between 'adep_LEBL' and target 'tow' is 0.0205434633888317
# correlation between 'adep_LEIB' and target 'tow' is -0.013668789031793716
# correlation between 'adep_LEMD' and target 'tow' is 0.050051285330577344
# correlation between 'adep_LEMG' and target 'tow' is -0.013609325537219604
# correlation between 'adep_LEMI' and target 'tow' is -0.011363724131311717
# correlation between 'adep_LEPA' and target 'tow' is -0.02240385360406067
# correlation between 'adep_LFBO' and target 'tow' is -0.01620571368964268
# correlation between 'adep_LFLL' and target 'tow' is -0.018432469585777482
# correlation between 'adep_LFML' and target 'tow' is -0.014030871047195855
# correlation between 'adep_LFMN' and target 'tow' is -0.02322233102830698
# correlation between 'adep_LFPG' and target 'tow' is 0.023149159314497725
# correlation between 'adep_LFSB' and target 'tow' is -0.01740576384654324
# correlation between 'adep_LGAV' and target 'tow' is 0.017396405617850063
# correlation between 'adep_LGTS' and target 'tow' is -0.010052374285683887
# correlation between 'adep_LHBP' and target 'tow' is -0.026221875340596112
# correlation between 'adep_LIML' and target 'tow' is -0.01962974820520894
# correlation between 'adep_LIPE' and target 'tow' is -0.022793836003370243
# correlation between 'adep_LIPZ' and target 'tow' is -0.02500487855089303
# correlation between 'adep_LIRF' and target 'tow' is 0.015863402546051817
# correlation between 'adep_LIRN' and target 'tow' is -0.010180597276614268
# correlation between 'adep_LIRQ' and target 'tow' is -0.01977165491806141
# correlation between 'adep_LKPR' and target 'tow' is -0.02921634013057968
# correlation between 'adep_LLBG' and target 'tow' is 0.047381087457072445
# correlation between 'adep_LOWG' and target 'tow' is -0.02654034431807734
# correlation between 'adep_LOWI' and target 'tow' is -0.028856309483747088
# correlation between 'adep_LOWK' and target 'tow' is -0.01626737293322755
# correlation between 'adep_LOWW' and target 'tow' is -0.09845178594921905
# correlation between 'adep_LPPR' and target 'tow' is -0.015688456462604385
# correlation between 'adep_LQSA' and target 'tow' is -0.01226451149270041
# correlation between 'adep_LROP' and target 'tow' is 0.010143386158546552
# correlation between 'adep_LSGG' and target 'tow' is -0.04600767934753439
# correlation between 'adep_LTAC' and target 'tow' is -0.014065639157949136
# correlation between 'adep_LTFJ' and target 'tow' is -0.030021648898509255
# correlation between 'adep_LTFM' and target 'tow' is 0.16990694569897552
# correlation between 'adep_LUKK' and target 'tow' is -0.011545654531793003
# correlation between 'adep_LWSK' and target 'tow' is -0.010010051068595323
# correlation between 'adep_LYBE' and target 'tow' is -0.02700212349186383
# correlation between 'adep_LZKZ' and target 'tow' is -0.01806902944117084
# correlation between 'adep_MDPC' and target 'tow' is 0.015892743074312037
# correlation between 'adep_MKJS' and target 'tow' is 0.030270098371844422
# correlation between 'adep_MMUN' and target 'tow' is 0.028889877538350078
# correlation between 'adep_MPTO' and target 'tow' is 0.021125480612868352
# correlation between 'adep_MUVR' and target 'tow' is 0.014199430819259085
# correlation between 'adep_OMDB' and target 'tow' is 0.025204694822153217
# correlation between 'adep_OPLA' and target 'tow' is 0.01636389908947286
# correlation between 'adep_RKSI' and target 'tow' is 0.014458145905854087
# correlation between 'adep_TLPL' and target 'tow' is 0.010411361714111837
# correlation between 'adep_TNCB' and target 'tow' is 0.028342787929255493
# correlation between 'adep_TNCC' and target 'tow' is 0.02173077008489644
# correlation between 'adep_VABB' and target 'tow' is 0.03857406273044467
# correlation between 'adep_VIDP' and target 'tow' is 0.011639595319196986
# correlation between 'adep_VTSP' and target 'tow' is 0.013919932781459615
# correlation between 'adep_WIII' and target 'tow' is 0.029098851646198923
# correlation between 'adep_ZMCK' and target 'tow' is 0.011925147395346043
# correlation between 'country_code_adep_AE' and target 'tow' is 0.023906697234494276
# correlation between 'country_code_adep_AN' and target 'tow' is 0.03569021264511297
# correlation between 'country_code_adep_AT' and target 'tow' is -0.10651894418916716
# correlation between 'country_code_adep_BA' and target 'tow' is -0.01226451149270041
# correlation between 'country_code_adep_BE' and target 'tow' is -0.08266732205100606
# correlation between 'country_code_adep_BG' and target 'tow' is -0.02160565168362409
# correlation between 'country_code_adep_CA' and target 'tow' is 0.026725392542433918
# correlation between 'country_code_adep_CH' and target 'tow' is -0.021986616448778962
# correlation between 'country_code_adep_CU' and target 'tow' is 0.014199430819259085
# correlation between 'country_code_adep_CZ' and target 'tow' is -0.02921634013057968
# correlation between 'country_code_adep_DE' and target 'tow' is -0.058376533354368015
# correlation between 'country_code_adep_DK' and target 'tow' is -0.12377033181929975
# correlation between 'country_code_adep_DO' and target 'tow' is 0.017897069575219252
# correlation between 'country_code_adep_EE' and target 'tow' is -0.030979566292889005
# correlation between 'country_code_adep_ES' and target 'tow' is -0.010596019131554762
# correlation between 'country_code_adep_FI' and target 'tow' is -0.041203135220641354
# correlation between 'country_code_adep_FR' and target 'tow' is -0.013900164536170668
# correlation between 'country_code_adep_GB' and target 'tow' is 0.046496832278846253
# correlation between 'country_code_adep_HR' and target 'tow' is -0.02089807964440519
# correlation between 'country_code_adep_HU' and target 'tow' is -0.026221875340596112
# correlation between 'country_code_adep_ID' and target 'tow' is 0.029919580444312314
# correlation between 'country_code_adep_IE' and target 'tow' is 0.010366981534833576
# correlation between 'country_code_adep_IL' and target 'tow' is 0.047381087457072445
# correlation between 'country_code_adep_IN' and target 'tow' is 0.04033857165271725
# correlation between 'country_code_adep_IT' and target 'tow' is -0.026593650291830268
# correlation between 'country_code_adep_JM' and target 'tow' is 0.030270098371844422
# correlation between 'country_code_adep_KR' and target 'tow' is 0.014458145905854087
# correlation between 'country_code_adep_LC' and target 'tow' is 0.010411361714111837
# correlation between 'country_code_adep_LR' and target 'tow' is 0.013600242519232782
# correlation between 'country_code_adep_LT' and target 'tow' is -0.03625535777979269
# correlation between 'country_code_adep_MD' and target 'tow' is -0.011545654531793003
# correlation between 'country_code_adep_ME' and target 'tow' is -0.01042221584023018
# correlation between 'country_code_adep_MK' and target 'tow' is -0.010093252921172758
# correlation between 'country_code_adep_MN' and target 'tow' is 0.011925147395346043
# correlation between 'country_code_adep_MX' and target 'tow' is 0.028889877538350078
# correlation between 'country_code_adep_NO' and target 'tow' is -0.11850136381872936
# correlation between 'country_code_adep_PA' and target 'tow' is 0.021125480612868352
# correlation between 'country_code_adep_PK' and target 'tow' is 0.018265995633355757
# correlation between 'country_code_adep_PL' and target 'tow' is -0.0454613763311932
# correlation between 'country_code_adep_PT' and target 'tow' is -0.014756209014130077
# correlation between 'country_code_adep_RS' and target 'tow' is -0.02700212349186383
# correlation between 'country_code_adep_SE' and target 'tow' is -0.1252235461935794
# correlation between 'country_code_adep_SK' and target 'tow' is -0.018362315126714955
# correlation between 'country_code_adep_TH' and target 'tow' is 0.014506922244640527
# correlation between 'country_code_adep_TR' and target 'tow' is 0.13072790834595502
# correlation between 'country_code_adep_US' and target 'tow' is 0.5382186285729103
# correlation between 'country_code_adep_XK' and target 'tow' is -0.01095578246238765
# correlation between 'country_code_adep_ZA' and target 'tow' is 0.012184683753823004
# correlation between 'ades_EBAW' and target 'tow' is -0.02447141913443211
# correlation between 'ades_EBBR' and target 'tow' is -0.0779645284656892
# correlation between 'ades_EBOS' and target 'tow' is -0.013522833899471533
# correlation between 'ades_EDDB' and target 'tow' is -0.017722030702606535
# correlation between 'ades_EDDH' and target 'tow' is -0.03329413958058294
# correlation between 'ades_EDDK' and target 'tow' is -0.020226647940122574
# correlation between 'ades_EDDL' and target 'tow' is -0.026825282553232747
# correlation between 'ades_EDDM' and target 'tow' is -0.012884640228824323
# correlation between 'ades_EDDN' and target 'tow' is -0.013229843926298676
# correlation between 'ades_EDDP' and target 'tow' is -0.019565886073214182
# correlation between 'ades_EDDS' and target 'tow' is -0.02299139132212752
# correlation between 'ades_EDDV' and target 'tow' is -0.027048574834877912
# correlation between 'ades_EETN' and target 'tow' is -0.030892397846292143
# correlation between 'ades_EFHK' and target 'tow' is -0.03378945163104236
# correlation between 'ades_EFTU' and target 'tow' is -0.011003023439200453
# correlation between 'ades_EGAC' and target 'tow' is -0.01734603637001475
# correlation between 'ades_EGKK' and target 'tow' is -0.014605302546276669
# correlation between 'ades_EGLC' and target 'tow' is -0.018502800117610664
# correlation between 'ades_EGLL' and target 'tow' is 0.09843218004245897
# correlation between 'ades_EGPD' and target 'tow' is -0.017759974561410936
# correlation between 'ades_EGPH' and target 'tow' is -0.012827635532823154
# correlation between 'ades_EICK' and target 'tow' is -0.01867625106250616
# correlation between 'ades_EIDW' and target 'tow' is 0.01700538353208507
# correlation between 'ades_EKAH' and target 'tow' is -0.04980008801894646
# correlation between 'ades_EKBI' and target 'tow' is -0.02807018553554665
# correlation between 'ades_EKCH' and target 'tow' is -0.10744047160253757
# correlation between 'ades_EKYT' and target 'tow' is -0.053321317222760595
# correlation between 'ades_ENAL' and target 'tow' is -0.014031701511109133
# correlation between 'ades_ENBO' and target 'tow' is -0.017404231805690795
# correlation between 'ades_ENBR' and target 'tow' is -0.0635537306685858
# correlation between 'ades_ENCN' and target 'tow' is -0.027572948577888865
# correlation between 'ades_ENGM' and target 'tow' is -0.07176358523949829
# correlation between 'ades_ENHD' and target 'tow' is -0.01811490477219861
# correlation between 'ades_ENVA' and target 'tow' is -0.02879778608574984
# correlation between 'ades_ENZV' and target 'tow' is -0.05120723271821295
# correlation between 'ades_EPGD' and target 'tow' is -0.02556791252089231
# correlation between 'ades_EPKK' and target 'tow' is -0.021881343203980615
# correlation between 'ades_EPPO' and target 'tow' is -0.012304121362384486
# correlation between 'ades_EPWA' and target 'tow' is -0.0319266422124855
# correlation between 'ades_ESDF' and target 'tow' is -0.020334294366441796
# correlation between 'ades_ESGG' and target 'tow' is -0.043401408789783415
# correlation between 'ades_ESMQ' and target 'tow' is -0.019709739385059696
# correlation between 'ades_ESMS' and target 'tow' is -0.025436973848483847
# correlation between 'ades_ESNN' and target 'tow' is -0.012937430404105332
# correlation between 'ades_ESNS' and target 'tow' is -0.01915412666943294
# correlation between 'ades_ESNZ' and target 'tow' is -0.03126281719702019
# correlation between 'ades_ESPA' and target 'tow' is -0.010566100641485205
# correlation between 'ades_ESSA' and target 'tow' is -0.09980052776516167
# correlation between 'ades_ESSB' and target 'tow' is -0.012659239956120522
# correlation between 'ades_ESSV' and target 'tow' is -0.011035631788306037
# correlation between 'ades_ESTA' and target 'tow' is -0.04068398712504325
# correlation between 'ades_EYPA' and target 'tow' is -0.016085971196516544
# correlation between 'ades_EYVI' and target 'tow' is -0.02721450243990155
# correlation between 'ades_KATL' and target 'tow' is 0.05762508384704069
# correlation between 'ades_KBOS' and target 'tow' is 0.10763636704571397
# correlation between 'ades_KCLT' and target 'tow' is 0.09007830585510905
# correlation between 'ades_KDFW' and target 'tow' is 0.14410755978572984
# correlation between 'ades_KEWR' and target 'tow' is 0.13157902409981043
# correlation between 'ades_KIAD' and target 'tow' is 0.07458130121729428
# correlation between 'ades_KIAH' and target 'tow' is 0.07083833451050862
# correlation between 'ades_KJFK' and target 'tow' is 0.2384631209985262
# correlation between 'ades_KLAX' and target 'tow' is 0.20703971688150258
# correlation between 'ades_KMCO' and target 'tow' is 0.07037711153875041
# correlation between 'ades_KMIA' and target 'tow' is 0.17565592669922855
# correlation between 'ades_KMLB' and target 'tow' is 0.057042279397954754
# correlation between 'ades_KORD' and target 'tow' is 0.19864230926874266
# correlation between 'ades_KPHL' and target 'tow' is 0.10091312282166173
# correlation between 'ades_KPHX' and target 'tow' is 0.04161793190095223
# correlation between 'ades_KRDU' and target 'tow' is 0.03290034835041101
# correlation between 'ades_KSEA' and target 'tow' is 0.05143551703892383
# correlation between 'ades_KSFO' and target 'tow' is 0.16524373379698185
# correlation between 'ades_LBSF' and target 'tow' is -0.018925265231004296
# correlation between 'ades_LBWN' and target 'tow' is -0.010711303419341378
# correlation between 'ades_LDZA' and target 'tow' is -0.015025614906285135
# correlation between 'ades_LEAL' and target 'tow' is -0.023558978791123272
# correlation between 'ades_LEBL' and target 'tow' is 0.027638725379428495
# correlation between 'ades_LEIB' and target 'tow' is -0.012594933611681338
# correlation between 'ades_LEMD' and target 'tow' is 0.06897873677772459
# correlation between 'ades_LEMG' and target 'tow' is -0.01621224420192016
# correlation between 'ades_LEMH' and target 'tow' is -0.01044315372342218
# correlation between 'ades_LEMI' and target 'tow' is -0.012003141697746923
# correlation between 'ades_LEPA' and target 'tow' is -0.022940243219029082
# correlation between 'ades_LFBO' and target 'tow' is -0.015784592463410473
# correlation between 'ades_LFLL' and target 'tow' is -0.01822812488039956
# correlation between 'ades_LFML' and target 'tow' is -0.013535557768677316
# correlation between 'ades_LFMN' and target 'tow' is -0.02365784400807423
# correlation between 'ades_LFPG' and target 'tow' is 0.024039730032446176
# correlation between 'ades_LFSB' and target 'tow' is -0.017044374340586404
# correlation between 'ades_LGKO' and target 'tow' is -0.010260863942213138
# correlation between 'ades_LGRP' and target 'tow' is -0.010435474148462498
# correlation between 'ades_LGTS' and target 'tow' is -0.011068853949937153
# correlation between 'ades_LHBP' and target 'tow' is -0.024159390533589613
# correlation between 'ades_LIML' and target 'tow' is -0.019071249090932763
# correlation between 'ades_LIPE' and target 'tow' is -0.022495341816913348
# correlation between 'ades_LIPZ' and target 'tow' is -0.02736114307455
# correlation between 'ades_LIRF' and target 'tow' is 0.011593564186068368
# correlation between 'ades_LIRQ' and target 'tow' is -0.021881307940778437
# correlation between 'ades_LKPR' and target 'tow' is -0.025616206694640497
# correlation between 'ades_LLBG' and target 'tow' is 0.04979370564981736
# correlation between 'ades_LOWG' and target 'tow' is -0.024375909413750153
# correlation between 'ades_LOWI' and target 'tow' is -0.026527808986185456
# correlation between 'ades_LOWK' and target 'tow' is -0.020111562988389686
# correlation between 'ades_LOWW' and target 'tow' is -0.10174837042135189
# correlation between 'ades_LPPR' and target 'tow' is -0.014773927549116913
# correlation between 'ades_LRIA' and target 'tow' is -0.011947410650866427
# correlation between 'ades_LROP' and target 'tow' is 0.013505779831428312
# correlation between 'ades_LSGG' and target 'tow' is -0.046526920174875315
# correlation between 'ades_LTAC' and target 'tow' is -0.011737537506274601
# correlation between 'ades_LTFJ' and target 'tow' is -0.03140059774854169
# correlation between 'ades_LTFM' and target 'tow' is 0.19978594171000616
# correlation between 'ades_LYBE' and target 'tow' is -0.024684762463701316
# correlation between 'ades_LZKZ' and target 'tow' is -0.021589487244633932
# correlation between 'ades_MPTO' and target 'tow' is 0.011367316188047689
# correlation between 'country_code_ades_AT' and target 'tow' is -0.10935304262699812
# correlation between 'country_code_ades_BE' and target 'tow' is -0.08293435092743325
# correlation between 'country_code_ades_BG' and target 'tow' is -0.021660484764975986
# correlation between 'country_code_ades_CH' and target 'tow' is -0.024622731334065
# correlation between 'country_code_ades_CZ' and target 'tow' is -0.025616206694640497
# correlation between 'country_code_ades_DE' and target 'tow' is -0.05968031678902307
# correlation between 'country_code_ades_DK' and target 'tow' is -0.12868959797574256
# correlation between 'country_code_ades_EE' and target 'tow' is -0.030943549528367937
# correlation between 'country_code_ades_FI' and target 'tow' is -0.03520297560941283
# correlation between 'country_code_ades_FR' and target 'tow' is -0.01421755239833103
# correlation between 'country_code_ades_GB' and target 'tow' is 0.05062966926355585
# correlation between 'country_code_ades_GR' and target 'tow' is -0.0175151933902055
# correlation between 'country_code_ades_HR' and target 'tow' is -0.01936366655582887
# correlation between 'country_code_ades_HU' and target 'tow' is -0.024159390533589613
# correlation between 'country_code_ades_IL' and target 'tow' is 0.04979370564981736
# correlation between 'country_code_ades_IT' and target 'tow' is -0.0289447448959689
# correlation between 'country_code_ades_LT' and target 'tow' is -0.031178327553146763
# correlation between 'country_code_ades_NO' and target 'tow' is -0.11783131733911156
# correlation between 'country_code_ades_PA' and target 'tow' is 0.011367316188047689
# correlation between 'country_code_ades_PL' and target 'tow' is -0.047783713227119315
# correlation between 'country_code_ades_PT' and target 'tow' is -0.01448437981273262
# correlation between 'country_code_ades_RS' and target 'tow' is -0.024684762463701316
# correlation between 'country_code_ades_SE' and target 'tow' is -0.1284967894389318
# correlation between 'country_code_ades_SK' and target 'tow' is -0.02186311393673629
# correlation between 'country_code_ades_TR' and target 'tow' is 0.1555596778739353
# correlation between 'country_code_ades_US' and target 'tow' is 0.5369723935826332
# correlation between 'aircraft_type_A20N' and target 'tow' is -0.11191808943031832
# correlation between 'aircraft_type_A319' and target 'tow' is -0.09190768549661615
# correlation between 'aircraft_type_A320' and target 'tow' is -0.17271807896592922
# correlation between 'aircraft_type_A321' and target 'tow' is -0.02524597395162234
# correlation between 'aircraft_type_A332' and target 'tow' is 0.1371762171246449
# correlation between 'aircraft_type_A333' and target 'tow' is 0.4813723740828755
# correlation between 'aircraft_type_A343' and target 'tow' is 0.09966549607619497
# correlation between 'aircraft_type_A359' and target 'tow' is 0.17494918144977484
# correlation between 'aircraft_type_AT76' and target 'tow' is -0.15387339301001607
# correlation between 'aircraft_type_B38M' and target 'tow' is -0.041300375147849865
# correlation between 'aircraft_type_B737' and target 'tow' is -0.0461410359409732
# correlation between 'aircraft_type_B738' and target 'tow' is -0.086563408860339
# correlation between 'aircraft_type_B739' and target 'tow' is -0.015074219393154504
# correlation between 'aircraft_type_B763' and target 'tow' is 0.08073716026118181
# correlation between 'aircraft_type_B772' and target 'tow' is 0.3225749160262913
# correlation between 'aircraft_type_B77W' and target 'tow' is 0.5516466707487663
# correlation between 'aircraft_type_B788' and target 'tow' is 0.1855038171846232
# correlation between 'aircraft_type_B789' and target 'tow' is 0.2608017144025354
# correlation between 'aircraft_type_BCS1' and target 'tow' is -0.06413251599555844
# correlation between 'aircraft_type_BCS3' and target 'tow' is -0.08908124716352267
# correlation between 'aircraft_type_CRJ9' and target 'tow' is -0.22729038749786426
# correlation between 'aircraft_type_E190' and target 'tow' is -0.04989141593166189
# correlation between 'aircraft_type_E195' and target 'tow' is -0.18764658175372784
# correlation between 'wtc_H' and target 'tow' is 0.9240978782010965
# correlation between 'wtc_M' and target 'tow' is -0.924097878201097
# correlation between 'airline_12838ccf020bc42e0e45c59a5fdf7e82' and target 'tow' is 0.024532312212478414
# correlation between 'airline_1332254e11e92b4ac6410613b2e86787' and target 'tow' is -0.11492020555688476
# correlation between 'airline_3a6435cd8884f0dd51b886b3e57267f3' and target 'tow' is 0.049919223324703756
# correlation between 'airline_5543e4dc327359ffaf5b9c0e6faaf0e1' and target 'tow' is 0.4495207201059372
# correlation between 'airline_5d407cb11cc29578cc3e292e743f5393' and target 'tow' is -0.147879741354893
# correlation between 'airline_6351ec1b849adacc0cbb3b1313d8d39b' and target 'tow' is 0.23279193362538075
# correlation between 'airline_8be5c854fd664bcb97fb543339f74770' and target 'tow' is -0.21674164136690233
# correlation between 'airline_bdeeef3a675587d530de70a25d7118d2' and target 'tow' is -0.09513328568257395
# correlation between 'airline_e36f387a48050121d2415f3935000bdc' and target 'tow' is -0.020221790799431708
# correlation between 'airline_f502877cab405652cf0dd70c2213e730' and target 'tow' is -0.012565157144008096
# correlation between 'airline_f53c55b5cf0cbb3be755bf50df6fa52d' and target 'tow' is -0.04928863160610432
# correlation between 'airline_f5c2e765e074db66052862ab3d1c4529' and target 'tow' is -0.0319133230866978
# correlation between 'month-day_04-30' and target 'tow' is 0.018138040435641337
# correlation between 'month-day_05-30' and target 'tow' is 0.010382108669409619
# correlation between 'month-day_06-30' and target 'tow' is 0.0121318376897245
# correlation between 'month-day_07-10' and target 'tow' is -0.010841075417939716
# correlation between 'month-day_07-11' and target 'tow' is -0.010845180631968713
# correlation between 'month-day_08-30' and target 'tow' is 0.010781316604077811
# correlation between 'month-day_09-30' and target 'tow' is 0.013248686028703372
# correlation between 'month-day_12-28' and target 'tow' is 0.01038032895783575
# correlation between 'month-day_12-30' and target 'tow' is 0.011033544894472504
# 374
# ['flight_duration', 'taxiout_time', 'flown_distance', 'day_in_month', 'adep_BKPR', 'adep_CYUL', 'adep_CYVR', 'adep_CYYZ', 'adep_EBAW', 'adep_EBBR', 'adep_EBOS', 'adep_EDDB', 'adep_EDDH', 'adep_EDDK', 'adep_EDDL', 'adep_EDDM', 'adep_EDDN', 'adep_EDDP', 'adep_EDDS', 'adep_EDDV', 'adep_EETN', 'adep_EFHK', 'adep_EFTU', 'adep_EGAC', 'adep_EGBB', 'adep_EGKK', 'adep_EGLC', 'adep_EGLL', 'adep_EGPD', 'adep_EGPH', 'adep_EICK', 'adep_EIDW', 'adep_EKAH', 'adep_EKBI', 'adep_EKCH', 'adep_EKYT', 'adep_ENAL', 'adep_ENBO', 'adep_ENBR', 'adep_ENCN', 'adep_ENGM', 'adep_ENHD', 'adep_ENVA', 'adep_ENZV', 'adep_EPGD', 'adep_EPKK', 'adep_EPPO', 'adep_EPWA', 'adep_ESDF', 'adep_ESGG', 'adep_ESMQ', 'adep_ESMS', 'adep_ESNN', 'adep_ESNS', 'adep_ESNU', 'adep_ESNZ', 'adep_ESPA', 'adep_ESSA', 'adep_ESSB', 'adep_ESSV', 'adep_ESTA', 'adep_EYPA', 'adep_EYVI', 'adep_FACT', 'adep_GLRB', 'adep_KATL', 'adep_KBOS', 'adep_KCLT', 'adep_KDFW', 'adep_KEWR', 'adep_KIAD', 'adep_KIAH', 'adep_KJFK', 'adep_KLAX', 'adep_KMCO', 'adep_KMIA', 'adep_KMLB', 'adep_KORD', 'adep_KPHL', 'adep_KPHX', 'adep_KRDU', 'adep_KSEA', 'adep_KSFO', 'adep_LBSF', 'adep_LDZA', 'adep_LDZD', 'adep_LEAL', 'adep_LEBL', 'adep_LEIB', 'adep_LEMD', 'adep_LEMG', 'adep_LEMI', 'adep_LEPA', 'adep_LFBO', 'adep_LFLL', 'adep_LFML', 'adep_LFMN', 'adep_LFPG', 'adep_LFSB', 'adep_LGAV', 'adep_LGTS', 'adep_LHBP', 'adep_LIML', 'adep_LIPE', 'adep_LIPZ', 'adep_LIRF', 'adep_LIRN', 'adep_LIRQ', 'adep_LKPR', 'adep_LLBG', 'adep_LOWG', 'adep_LOWI', 'adep_LOWK', 'adep_LOWW', 'adep_LPPR', 'adep_LQSA', 'adep_LROP', 'adep_LSGG', 'adep_LTAC', 'adep_LTFJ', 'adep_LTFM', 'adep_LUKK', 'adep_LWSK', 'adep_LYBE', 'adep_LZKZ', 'adep_MDPC', 'adep_MKJS', 'adep_MMUN', 'adep_MPTO', 'adep_MUVR', 'adep_OMDB', 'adep_OPLA', 'adep_RKSI', 'adep_TLPL', 'adep_TNCB', 'adep_TNCC', 'adep_VABB', 'adep_VIDP', 'adep_VTSP', 'adep_WIII', 'adep_ZMCK', 'country_code_adep_AE', 'country_code_adep_AN', 'country_code_adep_AT', 'country_code_adep_BA', 'country_code_adep_BE', 'country_code_adep_BG', 'country_code_adep_CA', 'country_code_adep_CH', 'country_code_adep_CU', 'country_code_adep_CZ', 'country_code_adep_DE', 'country_code_adep_DK', 'country_code_adep_DO', 'country_code_adep_EE', 'country_code_adep_ES', 'country_code_adep_FI', 'country_code_adep_FR', 'country_code_adep_GB', 'country_code_adep_HR', 'country_code_adep_HU', 'country_code_adep_ID', 'country_code_adep_IE', 'country_code_adep_IL', 'country_code_adep_IN', 'country_code_adep_IT', 'country_code_adep_JM', 'country_code_adep_KR', 'country_code_adep_LC', 'country_code_adep_LR', 'country_code_adep_LT', 'country_code_adep_MD', 'country_code_adep_ME', 'country_code_adep_MK', 'country_code_adep_MN', 'country_code_adep_MX', 'country_code_adep_NO', 'country_code_adep_PA', 'country_code_adep_PK', 'country_code_adep_PL', 'country_code_adep_PT', 'country_code_adep_RS', 'country_code_adep_SE', 'country_code_adep_SK', 'country_code_adep_TH', 'country_code_adep_TR', 'country_code_adep_US', 'country_code_adep_XK', 'country_code_adep_ZA', 'ades_EBAW', 'ades_EBBR', 'ades_EBOS', 'ades_EDDB', 'ades_EDDH', 'ades_EDDK', 'ades_EDDL', 'ades_EDDM', 'ades_EDDN', 'ades_EDDP', 'ades_EDDS', 'ades_EDDV', 'ades_EETN', 'ades_EFHK', 'ades_EFTU', 'ades_EGAC', 'ades_EGKK', 'ades_EGLC', 'ades_EGLL', 'ades_EGPD', 'ades_EGPH', 'ades_EICK', 'ades_EIDW', 'ades_EKAH', 'ades_EKBI', 'ades_EKCH', 'ades_EKYT', 'ades_ENAL', 'ades_ENBO', 'ades_ENBR', 'ades_ENCN', 'ades_ENGM', 'ades_ENHD', 'ades_ENVA', 'ades_ENZV', 'ades_EPGD', 'ades_EPKK', 'ades_EPPO', 'ades_EPWA', 'ades_ESDF', 'ades_ESGG', 'ades_ESMQ', 'ades_ESMS', 'ades_ESNN', 'ades_ESNS', 'ades_ESNZ', 'ades_ESPA', 'ades_ESSA', 'ades_ESSB', 'ades_ESSV', 'ades_ESTA', 'ades_EYPA', 'ades_EYVI', 'ades_KATL', 'ades_KBOS', 'ades_KCLT', 'ades_KDFW', 'ades_KEWR', 'ades_KIAD', 'ades_KIAH', 'ades_KJFK', 'ades_KLAX', 'ades_KMCO', 'ades_KMIA', 'ades_KMLB', 'ades_KORD', 'ades_KPHL', 'ades_KPHX', 'ades_KRDU', 'ades_KSEA', 'ades_KSFO', 'ades_LBSF', 'ades_LBWN', 'ades_LDZA', 'ades_LEAL', 'ades_LEBL', 'ades_LEI ...

# %%
# Pick up features from dataset
features = one_hot_encoded_challenge_set_df[correlated_features]

# Pick up target from dataset
target = one_hot_encoded_challenge_set_df['tow']

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=123, shuffle=True)

model = RandomForestRegressor(
    bootstrap=True,
    ccp_alpha=0.001,
    criterion='squared_error',
    max_depth=30,
    max_features=None,
    min_samples_leaf=2,
    min_samples_split=8,
    n_estimators=100,
    random_state=123
)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %% [markdown]
# <h3>B - Function to plot an example prediction with the tunned parameters</h3>

# %%
def plot_rmse(observed, predicted, show_error=False):
    # Calculate errors
    errors = observed - predicted
    squared_errors = errors**2
    mse = np.mean(squared_errors)
    rmse = np.sqrt(mse)
    
    # Create a plot
    plt.figure(figsize=(10, 6))
    
    # Plot the observed and predicted values
    plt.plot(observed, 'o', label='Observed Values')
    plt.plot(predicted, 'o', label='Predicted Values')
    
    # Plot the errors
    for i in range(len(observed)):
        plt.plot([i, i], [observed[i], predicted[i]], 'r--')
        if show_error:
            plt.text(i, (observed[i] + predicted[i]) / 2, f'{errors[i]:.1f}', ha='right', color='red')
    
    # Adding labels and title
    plt.xlabel('Data Points')
    plt.ylabel('Values')
    plt.title('Visualizing RMSE Calculation')
    plt.legend()
    plt.grid(True)
    
    # Show RMSE in the plot
    plt.text(1.5, max(observed) - 1, f'RMSE = {rmse:.3f}', fontsize=12, color='blue')

    plt.xticks([])
    plt.show()

# %% [markdown]
# <h3>C - Plotting random 100 points without showing individual datapoints errors</h3>

# %%
random_indices = np.random.choice(X_test.index, size=1000, replace=False)
X_test_sampled = X_test.loc[random_indices]
y_test_sampled = y_test.loc[random_indices]

y_pred_sampled = model.predict(X_test_sampled)

plot_rmse(observed=np.array(y_test_sampled), predicted=np.array(y_pred_sampled), show_error=False)

# %% [markdown]
# <h3>D - Plotting random 10 points and showing individual datapoints errors</h3>

# %%
random_indices = np.random.choice(X_test.index, size=10, replace=False)

X_test_sampled = X_test.loc[random_indices]
y_test_sampled = y_test.loc[random_indices]

y_pred_sampled = model.predict(X_test_sampled)

plot_rmse(observed=np.array(y_test_sampled), predicted=np.array(y_pred_sampled), show_error=True)

# %%
def rmse(y_true, y_pred):
    return np.sqrt(((y_true - y_pred) ** 2).mean())

y_pred = model.predict(X_test)

print(f"RMSE: {rmse(y_test, y_pred)}")
# Out:
# RMSE: 4187.209441229277
