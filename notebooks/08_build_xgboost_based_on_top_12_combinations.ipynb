# %%
from sklearn.model_selection import GridSearchCV, KFold, train_test_split
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.preprocessing import StandardScaler
from xgboost import plot_importance
import matplotlib.pyplot as plt
import xgboost as xgb
import pandas as pd
import numpy as np
import itertools

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
identifier_name = 'flight_id'

most_important_features_names = [
    'wtc', 
    'aircraft_type', 
    'flown_distance', 
    'groundspeed_max', 
    'latitude_min', 
    'altitude_25percentile', 
    'airline', 
    'flight_duration', 
    'longitude_max', 
    'vertical_rate_75percentile', 
    'altitude_median', 
    'ades'
]

target_name = 'tow'

global_random_state = 123

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def evaluate_model(model, data_df, features_columns, target_column):
    features = data_df[features_columns]
    target = data_df[target_column]
    X_array = features.values
    y_array = target.values
    rmse_scores = []
    kf = KFold(n_splits=3, shuffle=True, random_state=global_random_state)
    for train_index, test_index in kf.split(X_array):
        X_train, X_test = features.iloc[train_index], features.iloc[test_index]
        y_train, y_test = target.iloc[train_index], target.iloc[test_index]
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        rmse_scores.append(rmse(y_test, y_pred))
    return np.mean(rmse_scores)

# %%
encoded_challenge_set = pd.read_csv('data/encoded_challenge_set.csv')
encoded_challenge_set = encoded_challenge_set.fillna(0)

# %%
num_top_important_features = len(most_important_features_names)
print(f"We need to build {2**num_top_important_features} Trying all combinations of the top {num_top_important_features} important features")

all_combinations = list(itertools.chain.from_iterable(
    itertools.combinations(most_important_features_names, r) for r in range(len(most_important_features_names) + 1)
))
print(f"Total number of generated combinations: {len(all_combinations)}")

tried_combination = []
combinations_rmse_scores = []
for index, combination in enumerate(all_combinations[1:]):
    current_features = list(combination)
    
    print(f"Trying the combination number {index+1}...")
    print(current_features)
    
    xgb_model = xgb.XGBRegressor(
        n_estimators=91,
        max_depth=10,
        learning_rate=0.1,
        subsample=1.0,
        colsample_bytree=1.0,
        objective='reg:squarederror', 
        eval_metric='rmse',
        random_state=global_random_state
    )
    
    rmse_score = evaluate_model(
        model=xgb_model, 
        data_df=encoded_challenge_set, 
        features_columns=current_features, 
        target_column=target_name
    )
    print("Evaluation RMSE:", rmse_score)

    tried_combination.append(current_features)
    combinations_rmse_scores.append(rmse_score)
# Out:
# We need to build 4096 Trying all combinations of the top 12 important features
# Total number of generated combinations: 4096
# Trying the combination number 1...
# ['wtc']
# Evaluation RMSE: 20350.17311080975
# Trying the combination number 2...
# ['aircraft_type']
# Evaluation RMSE: 10827.753782628288
# Trying the combination number 3...
# ['flown_distance']
# Evaluation RMSE: 27477.065008386544
# Trying the combination number 4...
# ['groundspeed_max']
# Evaluation RMSE: 45284.66483403879
# Trying the combination number 5...
# ['latitude_min']
# Evaluation RMSE: 36605.25314532768
# Trying the combination number 6...
# ['altitude_25percentile']
# Evaluation RMSE: 44163.29536818614
# Trying the combination number 7...
# ['airline']
# Evaluation RMSE: 43931.55855543888
# Trying the combination number 8...
# ['flight_duration']
# Evaluation RMSE: 28424.577113701594
# Trying the combination number 9...
# ['longitude_max']
# Evaluation RMSE: 45191.24966573509
# Trying the combination number 10...
# ['vertical_rate_75percentile']
# Evaluation RMSE: 46814.85838059961
# Trying the combination number 11...
# ['altitude_median']
# Evaluation RMSE: 46530.07155410671
# Trying the combination number 12...
# ['ades']
# Evaluation RMSE: 40828.276413857
# Trying the combination number 13...
# ['wtc', 'aircraft_type']
# Evaluation RMSE: 10830.147034063946
# Trying the combination number 14...
# ['wtc', 'flown_distance']
# Evaluation RMSE: 15521.667890609824
# Trying the combination number 15...
# ['wtc', 'groundspeed_max']
# Evaluation RMSE: 19346.597698869442
# Trying the combination number 16...
# ['wtc', 'latitude_min']
# Evaluation RMSE: 15834.380362235644
# Trying the combination number 17...
# ['wtc', 'altitude_25percentile']
# Evaluation RMSE: 17624.537274702263
# Trying the combination number 18...
# ['wtc', 'airline']
# Evaluation RMSE: 17348.920974564604
# Trying the combination number 19...
# ['wtc', 'flight_duration']
# Evaluation RMSE: 15939.55890628444
# Trying the combination number 20...
# ['wtc', 'longitude_max']
# Evaluation RMSE: 16842.253970229413
# Trying the combination number 21...
# ['wtc', 'vertical_rate_75percentile']
# Evaluation RMSE: 19373.391616848996
# Trying the combination number 22...
# ['wtc', 'altitude_median']
# Evaluation RMSE: 17186.324995889652
# Trying the combination number 23...
# ['wtc', 'ades']
# Evaluation RMSE: 17184.227893568004
# Trying the combination number 24...
# ['aircraft_type', 'flown_distance']
# Evaluation RMSE: 6502.973917234445
# Trying the combination number 25...
# ['aircraft_type', 'groundspeed_max']
# Evaluation RMSE: 10405.641152858982
# Trying the combination number 26...
# ['aircraft_type', 'latitude_min']
# Evaluation RMSE: 8082.680562009195
# Trying the combination number 27...
# ['aircraft_type', 'altitude_25percentile']
# Evaluation RMSE: 9398.400163323187
# Trying the combination number 28...
# ['aircraft_type', 'airline']
# Evaluation RMSE: 8117.089391402267
# Trying the combination number 29...
# ['aircraft_type', 'flight_duration']
# Evaluation RMSE: 7185.765089283096
# Trying the combination number 30...
# ['aircraft_type', 'longitude_max']
# Evaluation RMSE: 7577.912928256922
# Trying the combination number 31...
# ['aircraft_type', 'vertical_rate_75percentile']
# Evaluation RMSE: 10567.84010979174
# Trying the combination number 32...
# ['aircraft_type', 'altitude_median']
# Evaluation RMSE: 9426.903870694108
# Trying the combination number 33...
# ['aircraft_type', 'ades']
# Evaluation RMSE: 7848.791316126623
# Trying the combination number 34...
# ['flown_distance', 'groundspeed_max']
# Evaluation RMSE: 27118.216414211838
# Trying the combination number 35...
# ['flown_distance', 'latitude_min']
# Evaluation RMSE: 22209.628239609872
# Trying the combination number 36...
# ['flown_distance', 'altitude_25percentile']
# Evaluation RMSE: 26335.844439774064
# Trying the combination number 37...
# ['flown_distance', 'airline']
# Evaluation RMSE: 23162.04230152392
# Trying the combination number 38...
# ['flown_distance', 'flight_duration']
# Evaluation RMSE: 26971.12916550147
# Trying the combination number 39...
# ['flown_distance', 'longitude_max']
# Evaluation RMSE: 21655.545176090378
# Trying the combination number 40...
# ['flown_distance', 'vertical_rate_75percentile']
# Evaluation RMSE: 26911.997596324814
# Trying the combination number 41...
# ['flown_distance', 'altitude_median']
# Evaluation RMSE: 24687.52436817187
# Trying the combination number 42...
# ['flown_distance', 'ades']
# Evaluation RMSE: 21444.074346837966
# Trying the combination number 43...
# ['groundspeed_max', 'latitude_min']
# Evaluation RMSE: 33780.49609685245
# Trying the combination number 44...
# ['groundspeed_max', 'altitude_25percentile']
# Evaluation RMSE: 39368.86437014991
# Trying the combination number 45...
# ['groundspeed_max', 'airline']
# Evaluation RMSE: 38815.987776569826
# Trying the combination number 46...
# ['groundspeed_max', 'flight_duration']
# Evaluation RMSE: 27762.786401317502
# Trying the combination number 47...
# ['groundspeed_max', 'longitude_max']
# Evaluation RMSE: 37371.544188091364
# Trying the combination number 48...
# ['groundspeed_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 39403.13657030417
# Trying the combination number 49...
# ['groundspeed_max', 'altitude_median']
# Evaluation RMSE: 39938.81611220325
# Trying the combination number 50...
# ['groundspeed_max', 'ades']
# Evaluation RMSE: 32727.204457075684
# Trying the combination number 51...
# ['latitude_min', 'altitude_25percentile']
# Evaluation RMSE: 32731.977992355405
# Trying the combination number 52...
# ['latitude_min', 'airline']
# Evaluation RMSE: 30471.04892208832
# Trying the combination number 53...
# ['latitude_min', 'flight_duration']
# Evaluation RMSE: 24208.521371474562
# Trying the combination number 54...
# ['latitude_min', 'longitude_max']
# Evaluation RMSE: 29209.95995710201
# Trying the combination number 55...
# ['latitude_min', 'vertical_rate_75percentile']
# Evaluation RMSE: 34248.71618851256
# Trying the combination number 56...
# ['latitude_min', 'altitude_median']
# Evaluation RMSE: 31448.047607782162
# Trying the combination number 57...
# ['latitude_min', 'ades']
# Evaluation RMSE: 26747.97350068483
# Trying the combination number 58...
# ['altitude_25percentile', 'airline']
# Evaluation RMSE: 36579.161502889416
# Trying the combination number 59...
# ['altitude_25percentile', 'flight_duration']
# Evaluation RMSE: 27671.905253364515
# Trying the combination number 60...
# ['altitude_25percentile', 'longitude_max']
# Evaluation RMSE: 34592.594083213226
# Trying the combination number 61...
# ['altitude_25percentile', 'vertical_rate_75percentile']
# Evaluation RMSE: 42384.292788857914
# Trying the combination number 62...
# ['altitude_25percentile', 'altitude_median']
# Evaluation RMSE: 42012.81426504287
# Trying the combination number 63...
# ['altitude_25percentile', 'ades']
# Evaluation RMSE: 31204.92136795587
# Trying the combination number 64...
# ['airline', 'flight_duration']
# Evaluation RMSE: 24762.79108442046
# Trying the combination number 65...
# ['airline', 'longitude_max']
# Evaluation RMSE: 39517.58689269603
# Trying the combination number 66...
# ['airline', 'vertical_rate_75percentile']
# Evaluation RMSE: 40711.461840477416
# Trying the combination number 67...
# ['airline', 'altitude_median']
# Evaluation RMSE: 37687.76902663145
# Trying the combination number 68...
# ['airline', 'ades']
# Evaluation RMSE: 33858.559876569976
# Trying the combination number 69...
# ['flight_duration', 'longitude_max']
# Evaluation RMSE: 23417.883281252667
# Trying the combination number 70...
# ['flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 27977.66793551995
# Trying the combination number 71...
# ['flight_duration', 'altitude_median']
# Evaluation RMSE: 26103.15624885917
# Trying the combination number 72...
# ['flight_duration', 'ades']
# Evaluation RMSE: 22996.07285236396
# Trying the combination number 73...
# ['longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 39521.38505034209
# Trying the combination number 74...
# ['longitude_max', 'altitude_median']
# Evaluation RMSE: 35626.53590960605
# Trying the combination number 75...
# ['longitude_max', 'ades']
# Evaluation RMSE: 34230.80529850602
# Trying the combination number 76...
# ['vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 43704.61816205713
# Trying the combination number 77...
# ['vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 36649.93781486952
# Trying the combination number 78...
# ['altitude_median', 'ades']
# Evaluation RMSE: 30658.687172555085
# Trying the combination number 79...
# ['wtc', 'aircraft_type', 'flown_distance']
# Evaluation RMSE: 6507.453055885133
# Trying the combination number 80...
# ['wtc', 'aircraft_type', 'groundspeed_max']
# Evaluation RMSE: 10406.100826657765
# Trying the combination number 81...
# ['wtc', 'aircraft_type', 'latitude_min']
# Evaluation RMSE: 8093.808066859891
# Trying the combination number 82...
# ['wtc', 'aircraft_type', 'altitude_25percentile']
# Evaluation RMSE: 9399.532486397307
# Trying the combination number 83...
# ['wtc', 'aircraft_type', 'airline']
# Evaluation RMSE: 8120.340386264888
# Trying the combination number 84...
# ['wtc', 'aircraft_type', 'flight_duration']
# Evaluation RMSE: 7187.33528557969
# Trying the combination number 85...
# ['wtc', 'aircraft_type', 'longitude_max']
# Evaluation RMSE: 7583.5972623700045
# Trying the combination number 86...
# ['wtc', 'aircraft_type', 'vertical_rate_75percentile']
# Evaluation RMSE: 10570.652813671959
# Trying the combination number 87...
# ['wtc', 'aircraft_type', 'altitude_median']
# Evaluation RMSE: 9439.287397595603
# Trying the combination number 88...
# ['wtc', 'aircraft_type', 'ades']
# Evaluation RMSE: 7852.715961095229
# Trying the combination number 89...
# ['wtc', 'flown_distance', 'groundspeed_max']
# Evaluation RMSE: 15186.265572238577
# Trying the combination number 90...
# ['wtc', 'flown_distance', 'latitude_min']
# Evaluation RMSE: 10959.586523599586
# Trying the combination number 91...
# ['wtc', 'flown_distance', 'altitude_25percentile']
# Evaluation RMSE: 14202.389083648117
# Trying the combination number 92...
# ['wtc', 'flown_distance', 'airline']
# Evaluation RMSE: 11371.612418379276
# Trying the combination number 93...
# ['wtc', 'flown_distance', 'flight_duration']
# Evaluation RMSE: 14951.391403984126
# Trying the combination number 94...
# ['wtc', 'flown_distance', 'longitude_max']
# Evaluation RMSE: 10757.49517526848
# Trying the combination number 95...
# ['wtc', 'flown_distance', 'vertical_rate_75percentile']
# Evaluation RMSE: 15212.165402790619
# Trying the combination number 96...
# ['wtc', 'flown_distance', 'altitude_median']
# Evaluation RMSE: 13643.19555889589
# Trying the combination number 97...
# ['wtc', 'flown_distance', 'ades']
# Evaluation RMSE: 10740.978445256618
# Trying the combination number 98...
# ['wtc', 'groundspeed_max', 'latitude_min']
# Evaluation RMSE: 15220.193565211579
# Trying the combination number 99...
# ['wtc', 'groundspeed_max', 'altitude_25percentile']
# Evaluation RMSE: 17068.333764175553
# Trying the combination number 100...
# ['wtc', 'groundspeed_max', 'airline']
# Evaluation RMSE: 15670.461223296908
# Trying the combination number 101...
# ['wtc', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 15445.308353148197
# Trying the combination number 102...
# ['wtc', 'groundspeed_max', 'longitude_max']
# Evaluation RMSE: 15171.305141252147
# Trying the combination number 103...
# ['wtc', 'groundspeed_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 18304.96280626894
# Trying the combination number 104...
# ['wtc', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 16668.349965098856
# Trying the combination number 105...
# ['wtc', 'groundspeed_max', 'ades']
# Evaluation RMSE: 15582.121700528267
# Trying the combination number 106...
# ['wtc', 'latitude_min', 'altitude_25percentile']
# Evaluation RMSE: 13997.399560726097
# Trying the combination number 107...
# ['wtc', 'latitude_min', 'airline']
# Evaluation RMSE: 12495.936104563267
# Trying the combination number 108...
# ['wtc', 'latitude_min', 'flight_duration']
# Evaluation RMSE: 12258.840914133878
# Trying the combination number 109...
# ['wtc', 'latitude_min', 'longitude_max']
# Evaluation RMSE: 12223.235478233662
# Trying the combination number 110...
# ['wtc', 'latitude_min', 'vertical_rate_75percentile']
# Evaluation RMSE: 15223.143315375215
# Trying the combination number 111...
# ['wtc', 'latitude_min', 'altitude_median']
# Evaluation RMSE: 13595.259340883355
# Trying the combination number 112...
# ['wtc', 'latitude_min', 'ades']
# Evaluation RMSE: 12842.818866476873
# Trying the combination number 113...
# ['wtc', 'altitude_25percentile', 'airline']
# Evaluation RMSE: 13664.850809902462
# Trying the combination number 114...
# ['wtc', 'altitude_25percentile', 'flight_duration']
# Evaluation RMSE: 14912.0595325743
# Trying the combination number 115...
# ['wtc', 'altitude_25percentile', 'longitude_max']
# Evaluation RMSE: 13471.167542641086
# Trying the combination number 116...
# ['wtc', 'altitude_25percentile', 'vertical_rate_75percentile']
# Evaluation RMSE: 17327.322542798825
# Trying the combination number 117...
# ['wtc', 'altitude_25percentile', 'altitude_median']
# Evaluation RMSE: 15976.714187132937
# Trying the combination number 118...
# ['wtc', 'altitude_25percentile', 'ades']
# Evaluation RMSE: 13523.192663508724
# Trying the combination number 119...
# ['wtc', 'airline', 'flight_duration']
# Evaluation RMSE: 12329.134855643637
# Trying the combination number 120...
# ['wtc', 'airline', 'longitude_max']
# Evaluation RMSE: 15324.867199825667
# Trying the combination number 121...
# ['wtc', 'airline', 'vertical_rate_75percentile']
# Evaluation RMSE: 16459.11218307811
# Trying the combination number 122...
# ['wtc', 'airline', 'altitude_median']
# Evaluation RMSE: 12935.38706734652
# Trying the combination number 123...
# ['wtc', 'airline', 'ades']
# Evaluation RMSE: 13769.52595836916
# Trying the combination number 124...
# ['wtc', 'flight_duration', 'longitude_max']
# Evaluation RMSE: 11765.738831572293
# Trying the combination number 125...
# ['wtc', 'flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 15737.764615322463
# Trying the combination number 126...
# ['wtc', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 14277.552129172307
# Trying the combination number 127...
# ['wtc', 'flight_duration', 'ades']
# Evaluation RMSE: 11826.054280113678
# Trying the combination number 128...
# ['wtc', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 15981.763627979162
# Trying the combination number 129...
# ['wtc', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 12833.088243618862
# Trying the combination number 130...
# ['wtc', 'longitude_max', 'ades']
# Evaluation RMSE: 13548.11902498879
# Trying the combination number 131...
# ['wtc', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 16671.025572232717
# Trying the combination number 132...
# ['wtc', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 16135.214088887833
# Trying the combination number 133...
# ['wtc', 'altitude_median', 'ades']
# Evaluation RMSE: 13067.230407025154
# Trying the combination number 134...
# ['aircraft_type', 'flown_distance', 'groundspeed_max']
# Evaluation RMSE: 6462.860619058741
# Trying the combination number 135...
# ['aircraft_type', 'flown_distance', 'latitude_min']
# Evaluation RMSE: 4844.496118708506
# Trying the combination number 136...
# ['aircraft_type', 'flown_distance', 'altitude_25percentile']
# Evaluation RMSE: 6111.551993631409
# Trying the combination number 137...
# ['aircraft_type', 'flown_distance', 'airline']
# Evaluation RMSE: 4674.742511330983
# Trying the combination number 138...
# ['aircraft_type', 'flown_distance', 'flight_duration']
# Evaluation RMSE: 6246.795283715389
# Trying the combination number 139...
# ['aircraft_type', 'flown_distance', 'longitude_max']
# Evaluation RMSE: 4649.773618077098
# Trying the combination number 140...
# ['aircraft_type', 'flown_distance', 'vertical_rate_75percentile']
# Evaluation RMSE: 6430.146539779867
# Trying the combination number 141...
# ['aircraft_type', 'flown_distance', 'altitude_median']
# Evaluation RMSE: 5781.483759204461
# Trying the combination number 142...
# ['aircraft_type', 'flown_distance', 'ades']
# Evaluation RMSE: 4384.503981077749
# Trying the combination number 143...
# ['aircraft_type', 'groundspeed_max', 'latitude_min']
# Evaluation RMSE: 7879.8579368833025
# Trying the combination number 144...
# ['aircraft_type', 'groundspeed_max', 'altitude_25percentile']
# Evaluation RMSE: 9328.22327799727
# Trying the combination number 145...
# ['aircraft_type', 'groundspeed_max', 'airline']
# Evaluation RMSE: 7326.071755266551
# Trying the combination number 146...
# ['aircraft_type', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 7048.003258703367
# Trying the combination number 147...
# ['aircraft_type', 'groundspeed_max', 'longitude_max']
# Evaluation RMSE: 6898.359253595657
# Trying the combination number 148...
# ['aircraft_type', 'groundspeed_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 10176.764312017505
# Trying the combination number 149...
# ['aircraft_type', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 9326.816194795128
# Trying the combination number 150...
# ['aircraft_type', 'groundspeed_max', 'ades']
# Evaluation RMSE: 7022.84877486161
# Trying the combination number 151...
# ['aircraft_type', 'latitude_min', 'altitude_25percentile']
# Evaluation RMSE: 6987.183685576753
# Trying the combination number 152...
# ['aircraft_type', 'latitude_min', 'airline']
# Evaluation RMSE: 5646.775470048672
# Trying the combination number 153...
# ['aircraft_type', 'latitude_min', 'flight_duration']
# Evaluation RMSE: 5238.239384550012
# Trying the combination number 154...
# ['aircraft_type', 'latitude_min', 'longitude_max']
# Evaluation RMSE: 5905.642236282307
# Trying the combination number 155...
# ['aircraft_type', 'latitude_min', 'vertical_rate_75percentile']
# Evaluation RMSE: 7919.030286641796
# Trying the combination number 156...
# ['aircraft_type', 'latitude_min', 'altitude_median']
# Evaluation RMSE: 7169.744404961914
# Trying the combination number 157...
# ['aircraft_type', 'latitude_min', 'ades']
# Evaluation RMSE: 6167.338267895383
# Trying the combination number 158...
# ['aircraft_type', 'altitude_25percentile', 'airline']
# Evaluation RMSE: 5807.143043024847
# Trying the combination number 159...
# ['aircraft_type', 'altitude_25percentile', 'flight_duration']
# Evaluation RMSE: 6801.25698651889
# Trying the combination number 160...
# ['aircraft_type', 'altitude_25percentile', 'longitude_max']
# Evaluation RMSE: 6002.838216225008
# Trying the combination number 161...
# ['aircraft_type', 'altitude_25percentile', 'vertical_rate_75percentile']
# Evaluation RMSE: 9305.476279368153
# Trying the combination number 162...
# ['aircraft_type', 'altitude_25percentile', 'altitude_median']
# Evaluation RMSE: 8535.102145804065
# Trying the combination number 163...
# ['aircraft_type', 'altitude_25percentile', 'ades']
# Evaluation RMSE: 6114.777885191732
# Trying the combination number 164...
# ['aircraft_type', 'airline', 'flight_duration']
# Evaluation RMSE: 4618.974955407495
# Trying the combination number 165...
# ['aircraft_type', 'airline', 'longitude_max']
# Evaluation RMSE: 6883.1849101899215
# Trying the combination number 166...
# ['aircraft_type', 'airline', 'vertical_rate_75percentile']
# Evaluation RMSE: 7671.039853177364
# Trying the combination number 167...
# ['aircraft_type', 'airline', 'altitude_median']
# Evaluation RMSE: 5907.9711402095045
# Trying the combination number 168...
# ['aircraft_type', 'airline', 'ades']
# Evaluation RMSE: 6550.856763161595
# Trying the combination number 169...
# ['aircraft_type', 'flight_duration', 'longitude_max']
# Evaluation RMSE: 4770.945965778276
# Trying the combination number 170...
# ['aircraft_type', 'flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 7103.78029535533
# Trying the combination number 171...
# ['aircraft_type', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 6393.517363104598
# Trying the combination number 172...
# ['aircraft_type', 'flight_duration', 'ades']
# Evaluation RMSE: 4568.85471016093
# Trying the combination number 173...
# ['aircraft_type', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 7320.323882354031
# Trying the combination number 174...
# ['aircraft_type', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 6015.19524858288
# Trying the combination number 175...
# ['aircraft_type', 'longitude_max', 'ades']
# Evaluation RMSE: 6005.737735867777
# Trying the combination number 176...
# ['aircraft_type', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 9320.553275576749
# Trying the combination number 177...
# ['aircraft_type', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 7537.367695679243
# Trying the combination number 178...
# ['aircraft_type', 'altitude_median', 'ades']
# Evaluation RMSE: 6247.24010181784
# Trying the combination number 179...
# ['flown_distance', 'groundspeed_max', 'latitude_min']
# Evaluation RMSE: 21558.671382079974
# Trying the combination number 180...
# ['flown_distance', 'groundspeed_max', 'altitude_25percentile']
# Evaluation RMSE: 25735.926363307455
# Trying the combination number 181...
# ['flown_distance', 'groundspeed_max', 'airline']
# Evaluation RMSE: 22450.64070032306
# Trying the combination number 182...
# ['flown_distance', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 26746.980903870735
# Trying the combination number 183...
# ['flown_distance', 'groundspeed_max', 'longitude_max']
# Evaluation RMSE: 20986.39012400409
# Trying the combination number 184...
# ['flown_distance', 'groundspeed_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 26220.724184400384
# Trying the combination number 185...
# ['flown_distance', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 23937.908455452558
# Trying the combination number 186...
# ['flown_distance', 'groundspeed_max', 'ades']
# Evaluation RMSE: 20658.26270255364
# Trying the combination number 187...
# ['flown_distance', 'latitude_min', 'altitude_25percentile']
# Evaluation RMSE: 21172.985213454376
# Trying the combination number 188...
# ['flown_distance', 'latitude_min', 'airline']
# Evaluation RMSE: 20838.78845772421
# Trying the combination number 189...
# ['flown_distance', 'latitude_min', 'flight_duration']
# Evaluation RMSE: 21422.200599482258
# Trying the combination number 190...
# ['flown_distance', 'latitude_min', 'longitude_max']
# Evaluation RMSE: 20400.92167528514
# Trying the combination number 191...
# ['flown_distance', 'latitude_min', 'vertical_rate_75percentile']
# Evaluation RMSE: 21600.65644781486
# Trying the combination number 192...
# ['flown_distance', 'latitude_min', 'altitude_median']
# Evaluation RMSE: 18030.27374850199
# Trying the combination number 193...
# ['flown_distance', 'latitude_min', 'ades']
# Evaluation RMSE: 20037.712054158354
# Trying the combination number 194...
# ['flown_distance', 'altitude_25percentile', 'airline']
# Evaluation RMSE: 21808.80233985001
# Trying the combination number 195...
# ['flown_distance', 'altitude_25percentile', 'flight_duration']
# Evaluation RMSE: 25591.804785826112
# Trying the combination number 196...
# ['flown_distance', 'altitude_25percentile', 'longitude_max']
# Evaluation RMSE: 20621.884510917105
# Trying the combination number 197...
# ['flown_distance', 'altitude_25percentile', 'vertical_rate_75percentile']
# Evaluation RMSE: 25600.217905205063
# Trying the combination number 198...
# ['flown_distance', 'altitude_25percentile', 'altitude_median']
# Evaluation RMSE: 23116.307371703733
# Trying the combination number 199...
# ['flown_distance', 'altitude_25percentile', 'ades']
# Evaluation RMSE: 20353.80679042153
# Trying the combination number 200...
# ['flown_distance', 'airline', 'flight_duration']
# Evaluation RMSE: 22434.800283037508
# Trying the combination number 201...
# ['flown_distance', 'airline', 'longitude_max']
# Evaluation RMSE: 20873.43849369237
# Trying the combination number 202...
# ['flown_distance', 'airline', 'vertical_rate_75percentile']
# Evaluation RMSE: 22582.19566171439
# Trying the combination number 203...
# ['flown_distance', 'airline', 'altitude_median']
# Evaluation RMSE: 18532.62340667679
# Trying the combination number 204...
# ['flown_distance', 'airline', 'ades']
# Evaluation RMSE: 20474.441296722274
# Trying the combination number 205...
# ['flown_distance', 'flight_duration', 'longitude_max']
# Evaluation RMSE: 20906.878375419208
# Trying the combination number 206...
# ['flown_distance', 'flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 26224.735865022914
# Trying the combination number 207...
# ['flown_distance', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 23918.765969207383
# Trying the combination number 208...
# ['flown_distance', 'flight_duration', 'ades']
# Evaluation RMSE: 20601.898014736867
# Trying the combination number 209...
# ['flown_distance', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 21116.947582433724
# Trying the combination number 210...
# ['flown_distance', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 17408.843372968735
# Trying the combination number 211...
# ['flown_distance', 'longitude_max', 'ades']
# Evaluation RMSE: 19701.781385253085
# Trying the combination number 212...
# ['flown_distance', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 24098.461751949697
# Trying the combination number 213...
# ['flown_distance', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 20881.419442185426
# Trying the combination number 214...
# ['flown_distance', 'altitude_median', 'ades']
# Evaluation RMSE: 16858.742072790603
# Trying the combination number 215...
# ['groundspeed_max', 'latitude_min', 'altitude_25percentile']
# Evaluation RMSE: 30501.227679957596
# Trying the combination number 216...
# ['groundspeed_max', 'latitude_min', 'airline']
# Evaluation RMSE: 27969.615432998165
# Trying the combination number 217...
# ['groundspeed_max', 'latitude_min', 'flight_duration']
# Evaluation RMSE: 22912.85232565169
# Trying the combination number 218...
# ['groundspeed_max', 'latitude_min', 'longitude_max']
# Evaluation RMSE: 27217.941263144316
# Trying the combination number 219...
# ['groundspeed_max', 'latitude_min', 'vertical_rate_75percentile']
# Evaluation RMSE: 31431.042822402058
# Trying the combination number 220...
# ['groundspeed_max', 'latitude_min', 'altitude_median']
# Evaluation RMSE: 28912.204078995168
# Trying the combination number 221...
# ['groundspeed_max', 'latitude_min', 'ades']
# Evaluation RMSE: 24462.253773132612
# Trying the combination number 222...
# ['groundspeed_max', 'altitude_25percentile', 'airline']
# Evaluation RMSE: 32686.785055939865
# Trying the combination number 223...
# ['groundspeed_max', 'altitude_25percentile', 'flight_duration']
# Evaluation RMSE: 26692.18558829595
# Trying the combination number 224...
# ['groundspeed_max', 'altitude_25percentile', 'longitude_max']
# Evaluation RMSE: 30921.153052054146
# Trying the combination number 225...
# ['groundspeed_max', 'altitude_25percentile', 'vertical_rate_75percentile']
# Evaluation RMSE: 37218.73089897406
# Trying the combination number 226...
# ['groundspeed_max', 'altitude_25percentile', 'altitude_median']
# Evaluation RMSE: 37072.05790947924
# Trying the combination number 227...
# ['groundspeed_max', 'altitude_25percentile', 'ades']
# Evaluation RMSE: 26797.68042947016
# Trying the combination number 228...
# ['groundspeed_max', 'airline', 'flight_duration']
# Evaluation RMSE: 23675.280224320624
# Trying the combination number 229...
# ['groundspeed_max', 'airline', 'longitude_max']
# Evaluation RMSE: 33328.29857402111
# Trying the combination number 230...
# ['groundspeed_max', 'airline', 'vertical_rate_75percentile']
# Evaluation RMSE: 34255.44188415926
# Trying the combination number 231...
# ['groundspeed_max', 'airline', 'altitude_median']
# Evaluation RMSE: 32090.92212270248
# Trying the combination number 232...
# ['groundspeed_max', 'airline', 'ades']
# Evaluation RMSE: 27399.64923573899
# Trying the combination number 233...
# ['groundspeed_max', 'flight_duration', 'longitude_max']
# Evaluation RMSE: 22188.60161944953
# Trying the combination number 234...
# ['groundspeed_max', 'flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 26950.124890865805
# Trying the combination number 235...
# ['groundspeed_max', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 24860.907201545935
# Trying the combination number 236...
# ['groundspeed_max', 'flight_duration', 'ades']
# Evaluation RMSE: 21968.40430924662
# Trying the combination number 237...
# ['groundspeed_max', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 32362.889997902148
# Trying the combination number 238...
# ['groundspeed_max', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 30255.020478009348
# Trying the combination number 239...
# ['groundspeed_max', 'longitude_max', 'ades']
# Evaluation RMSE: 27308.951440338642
# Trying the combination number 240...
# ['groundspeed_max', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 36876.32435556015
# Trying the combination number 241...
# ['groundspeed_max', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 28585.871233035377
# Trying the combination number 242...
# ['groundspeed_max', 'altitude_median', 'ades']
# Evaluation RMSE: 25520.725387856754
# Trying the combination number 243...
# ['latitude_min', 'altitude_25percentile', 'airline']
# Evaluation RMSE: 26421.12272378711
# Trying the combination number 244...
# ['latitude_min', 'altitude_25percentile', 'flight_duration']
# Evaluation RMSE: 23026.930170020914
# Trying the combination number 245...
# ['latitude_min', 'altitude_25percentile', 'longitude_max']
# Evaluation RMSE: 26539.985878545962
# Trying the combination number 246...
# ['latitude_min', 'altitude_25percentile', 'vertical_rate_75percentile']
# Evaluation RMSE: 31420.62931289012
# Trying the combination number 247...
# ['latitude_min', 'altitude_25percentile', 'altitude_median']
# Evaluation RMSE: 29259.586590848678
# Trying the combination number 248...
# ['latitude_min', 'altitude_25percentile', 'ades']
# Evaluation RMSE: 23977.70785313461
# Trying the combination number 249...
# ['latitude_min', 'airline', 'flight_duration']
# Evaluation RMSE: 22001.297292907428
# Trying the combination number 250...
# ['latitude_min', 'airline', 'longitude_max']
# Evaluation RMSE: 27008.984255354084
# Trying the combination number 251...
# ['latitude_min', 'airline', 'vertical_rate_75percentile']
# Evaluation RMSE: 28541.29817449945
# Trying the combination number 252...
# ['latitude_min', 'airline', 'altitude_median']
# Evaluation RMSE: 25258.589205395197
# Trying the combination number 253...
# ['latitude_min', 'airline', 'ades']
# Evaluation RMSE: 23937.488155360916
# Trying the combination number 254...
# ['latitude_min', 'flight_duration', 'longitude_max']
# Evaluation RMSE: 21280.820756689165
# Trying the combination number 255...
# ['latitude_min', 'flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 23473.622844145633
# Trying the combination number 256...
# ['latitude_min', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 19937.479372013124
# Trying the combination number 257...
# ['latitude_min', 'flight_duration', 'ades']
# Evaluation RMSE: 20925.371148571652
# Trying the combination number 258...
# ['latitude_min', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 27775.13591241214
# Trying the combination number 259...
# ['latitude_min', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 25211.249189555896
# Trying the combination number 260...
# ['latitude_min', 'longitude_max', 'ades']
# Evaluation RMSE: 23765.00940265231
# Trying the combination number 261...
# ['latitude_min', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 30217.780003557258
# Trying the combination number 262...
# ['latitude_min', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 25514.652766388437
# Trying the combination number 263...
# ['latitude_min', 'altitude_median', 'ades']
# Evaluation RMSE: 21859.309493769833
# Trying the combination number 264...
# ['altitude_25percentile', 'airline', 'flight_duration']
# Evaluation RMSE: 23601.766073837207
# Trying the combination number 265...
# ['altitude_25percentile', 'airline', 'longitude_max']
# Evaluation RMSE: 31201.885269367714
# Trying the combination number 266...
# ['altitude_25percentile', 'airline', 'vertical_rate_75percentile']
# Evaluation RMSE: 35091.30320397353
# Trying the combination number 267...
# ['altitude_25percentile', 'airline', 'altitude_median']
# Evaluation RMSE: 32082.8023888696
# Trying the combination number 268...
# ['altitude_25percentile', 'airline', 'ades']
# Evaluation RMSE: 26794.41861031088
# Trying the combination number 269...
# ['altitude_25percentile', 'flight_duration', 'longitude_max']
# Evaluation RMSE: 22191.187834948545
# Trying the combination number 270...
# ['altitude_25percentile', 'flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 27080.99884103685
# Trying the combination number 271...
# ['altitude_25percentile', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 24831.458430443872
# Trying the combination number 272...
# ['altitude_25percentile', 'flight_duration', 'ades']
# Evaluation RMSE: 21878.56496725616
# Trying the combination number 273...
# ['altitude_25percentile', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 32992.015601955376
# Trying the combination number 274...
# ['altitude_25percentile', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 30489.956239691233
# Trying the combination number 275...
# ['altitude_25percentile', 'longitude_max', 'ades']
# Evaluation RMSE: 25633.678695057446
# Trying the combination number 276...
# ['altitude_25percentile', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 40366.636606503154
# Trying the combination number 277...
# ['altitude_25percentile', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 30128.573567193755
# Trying the combination number 278...
# ['altitude_25percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 25700.974299671627
# Trying the combination number 279...
# ['airline', 'flight_duration', 'longitude_max']
# Evaluation RMSE: 22626.626685168263
# Trying the combination number 280...
# ['airline', 'flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 24191.048864648154
# Trying the combination number 281...
# ['airline', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 20211.821181506097
# Trying the combination number 282...
# ['airline', 'flight_duration', 'ades']
# Evaluation RMSE: 21340.7073553112
# Trying the combination number 283...
# ['airline', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 35562.63085131096
# Trying the combination number 284...
# ['airline', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 31724.688843839012
# Trying the combination number 285...
# ['airline', 'longitude_max', 'ades']
# Evaluation RMSE: 30969.11897207207
# Trying the combination number 286...
# ['airline', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 35356.00220424936
# Trying the combination number 287...
# ['airline', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 31534.737377351776
# Trying the combination number 288...
# ['airline', 'altitude_median', 'ades']
# Evaluation RMSE: 25983.596687916983
# Trying the combination number 289...
# ['flight_duration', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 22773.292715434927
# Trying the combination number 290...
# ['flight_duration', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 18868.36227835268
# Trying the combination number 291...
# ['flight_duration', 'longitude_max', 'ades']
# Evaluation RMSE: 20385.180258209988
# Trying the combination number 292...
# ['flight_duration', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 25514.153331606536
# Trying the combination number 293...
# ['flight_duration', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 22432.315849201677
# Trying the combination number 294...
# ['flight_duration', 'altitude_median', 'ades']
# Evaluation RMSE: 18544.90743819063
# Trying the combination number 295...
# ['longitude_max', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 33174.7538340772
# Trying the combination number 296...
# ['longitude_max', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 30385.029875957625
# Trying the combination number 297...
# ['longitude_max', 'altitude_median', 'ades']
# Evaluation RMSE: 25480.506707871726
# Trying the combination number 298...
# ['vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 28759.82937211455
# Trying the combination number 299...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max']
# Evaluation RMSE: 6460.312140896219
# Trying the combination number 300...
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min']
# Evaluation RMSE: 4845.06110547566
# Trying the combination number 301...
# ['wtc', 'aircraft_type', 'flown_distance', 'altitude_25percentile']
# Evaluation RMSE: 6117.410916762896
# Trying the combination number 302...
# ['wtc', 'aircraft_type', 'flown_distance', 'airline']
# Evaluation RMSE: 4679.488517547065
# Trying the combination number 303...
# ['wtc', 'aircraft_type', 'flown_distance', 'flight_duration']
# Evaluation RMSE: 6254.004359468113
# Trying the combination number 304...
# ['wtc', 'aircraft_type', 'flown_distance', 'longitude_max']
# Evaluation RMSE: 4646.776184695264
# Trying the combination number 305...
# ['wtc', 'aircraft_type', 'flown_distance', 'vertical_rate_75percentile']
# Evaluation RMSE: 6433.402920038039
# Trying the combination number 306...
# ['wtc', 'aircraft_type', 'flown_distance', 'altitude_median']
# Evaluation RMSE: 5788.004058008355
# Trying the combination number 307...
# ['wtc', 'aircraft_type', 'flown_distance', 'ades']
# Evaluation RMSE: 4395.167052304853
# Trying the combination number 308...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_min']
# Evaluation RMSE: 7892.651109310704
# Trying the combination number 309...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'altitude_25percentile']
# Evaluation RMSE: 9336.3963726211
# Trying the combination number 310...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'airline']
# Evaluation RMSE: 7337.550020042817
# Trying the combination number 311...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 7064.469168941233
# Trying the combination number 312...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'longitude_max']
# Evaluation RMSE: 6908.165386181863
# Trying the combination number 313...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 10169.95211527188
# Trying the combination number 314...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 9345.974394415136
# Trying the combination number 315...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'ades']
# Evaluation RMSE: 7032.097127308906
# Trying the combination number 316...
# ['wtc', 'aircraft_type', 'latitude_min', 'altitude_25percentile']
# Evaluation RMSE: 6993.466055289514
# Trying the combination number 317...
# ['wtc', 'aircraft_type', 'latitude_min', 'airline']
# Evaluation RMSE: 5662.468568555713
# Trying the combination number 318...
# ['wtc', 'aircraft_type', 'latitude_min', 'flight_duration']
# Evaluation RMSE: 5235.96985534009
# Trying the combination number 319...
# ['wtc', 'aircraft_type', 'latitude_min', 'longitude_max']
# Evaluation RMSE: 5910.070427399941
# Trying the combination number 320...
# ['wtc', 'aircraft_type', 'latitude_min', 'vertical_rate_75percentile']
# Evaluation RMSE: 7926.357515532057
# Trying the combination number 321...
# ['wtc', 'aircraft_type', 'latitude_min', 'altitude_median']
# Evaluation RMSE: 7183.372941089109
# Trying the combination number 322...
# ['wtc', 'aircraft_type', 'latitude_min', 'ades']
# Evaluation RMSE: 6186.604664247704
# Trying the combination number 323...
# ['wtc', 'aircraft_type', 'altitude_25percentile', 'airline']
# Evaluation RMSE: 5813.097668545958
# Trying the combination number 324...
# ['wtc', 'aircraft_type', 'altitude_25percentile', 'flight_duration']
# Evaluation RMSE: 6812.713702794779
# Trying the combination number 325...
# ['wtc', 'aircraft_type', 'altitude_25percentile', 'longitude_max']
# Evaluation RMSE: 6011.946270689962
# Trying the combination number 326...
# ['wtc', 'aircraft_type', 'altitude_25percentile', 'vertical_rate_75percentile']
# Evaluation RMSE: 9303.530634677465
# Trying the combination number 327...
# ['wtc', 'aircraft_type', 'altitude_25percentile', 'altitude_median']
# Evaluation RMSE: 8547.581406442243
# Trying the combination number 328...
# ['wtc', 'aircraft_type', 'altitude_25percentile', 'ades']
# Evaluation RMSE: 6114.23120813894
# Trying the combination number 329...
# ['wtc', 'aircraft_type', 'airline', 'flight_duration']
# Evaluation RMSE: 4622.230947335075
# Trying the combination number 330...
# ['wtc', 'aircraft_type', 'airline', 'longitude_max']
# Evaluation RMSE: 6890.613948029736
# Trying the combination number 331...
# ['wtc', 'aircraft_type', 'airline', 'vertical_rate_75percentile']
# Evaluation RMSE: 7675.573628877911
# Trying the combination number 332...
# ['wtc', 'aircraft_type', 'airline', 'altitude_median']
# Evaluation RMSE: 5929.878362034523
# Trying the combination number 333...
# ['wtc', 'aircraft_type', 'airline', 'ades']
# Evaluation RMSE: 6558.716573475423
# Trying the combination number 334...
# ['wtc', 'aircraft_type', 'flight_duration', 'longitude_max']
# Evaluation RMSE: 4757.942690983063
# Trying the combination number 335...
# ['wtc', 'aircraft_type', 'flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 7106.100988046445
# Trying the combination number 336...
# ['wtc', 'aircraft_type', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 6393.493341390807
# Trying the combination number 337...
# ['wtc', 'aircraft_type', 'flight_duration', 'ades']
# Evaluation RMSE: 4567.082962302705
# Trying the combination number 338...
# ['wtc', 'aircraft_type', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 7316.548000392475
# Trying the combination number 339...
# ['wtc', 'aircraft_type', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 6019.742323222352
# Trying the combination number 340...
# ['wtc', 'aircraft_type', 'longitude_max', 'ades']
# Evaluation RMSE: 6016.7123864755495
# Trying the combination number 341...
# ['wtc', 'aircraft_type', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 9324.566576407275
# Trying the combination number 342...
# ['wtc', 'aircraft_type', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 7540.571076118772
# Trying the combination number 343...
# ['wtc', 'aircraft_type', 'altitude_median', 'ades']
# Evaluation RMSE: 6245.772656180897
# Trying the combination number 344...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_min']
# Evaluation RMSE: 10704.047311543116
# Trying the combination number 345...
# ['wtc', 'flown_distance', 'groundspeed_max', 'altitude_25percentile']
# Evaluation RMSE: 13687.245173945697
# Trying the combination number 346...
# ['wtc', 'flown_distance', 'groundspeed_max', 'airline']
# Evaluation RMSE: 10942.950702980806
# Trying the combination number 347...
# ['wtc', 'flown_distance', 'groundspeed_max', 'flight_duration']
# Evaluation RMSE: 14883.269521250966
# Trying the combination number 348...
# ['wtc', 'flown_distance', 'groundspeed_max', 'longitude_max']
# Evaluation RMSE: 10542.589821563526
# Trying the combination number 349...
# ['wtc', 'flown_distance', 'groundspeed_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 14841.567638022714
# Trying the combination number 350...
# ['wtc', 'flown_distance', 'groundspeed_max', 'altitude_median']
# Evaluation RMSE: 13169.180518955467
# Trying the combination number 351...
# ['wtc', 'flown_distance', 'groundspeed_max', 'ades']
# Evaluation RMSE: 10517.70944420356
# Trying the combination number 352...
# ['wtc', 'flown_distance', 'latitude_min', 'altitude_25percentile']
# Evaluation RMSE: 9983.221184561973
# Trying the combination number 353...
# ['wtc', 'flown_distance', 'latitude_min', 'airline']
# Evaluation RMSE: 9446.761226208833
# Trying the combination number 354...
# ['wtc', 'flown_distance', 'latitude_min', 'flight_duration']
# Evaluation RMSE: 10558.818119657773
# Trying the combination number 355...
# ['wtc', 'flown_distance', 'latitude_min', 'longitude_max']
# Evaluation RMSE: 9544.004461572711
# Trying the combination number 356...
# ['wtc', 'flown_distance', 'latitude_min', 'vertical_rate_75percentile']
# Evaluation RMSE: 10690.878615964355
# Trying the combination number 357...
# ['wtc', 'flown_distance', 'latitude_min', 'altitude_median']
# Evaluation RMSE: 9465.620404516561
# Trying the combination number 358...
# ['wtc', 'flown_distance', 'latitude_min', 'ades']
# Evaluation RMSE: 9520.864856705213
# Trying the combination number 359...
# ['wtc', 'flown_distance', 'altitude_25percentile', 'airline']
# Evaluation RMSE: 10096.715527868819
# Trying the combination number 360...
# ['wtc', 'flown_distance', 'altitude_25percentile', 'flight_duration']
# Evaluation RMSE: 13524.480290220405
# Trying the combination number 361...
# ['wtc', 'flown_distance', 'altitude_25percentile', 'longitude_max']
# Evaluation RMSE: 9855.62576372551
# Trying the combination number 362...
# ['wtc', 'flown_distance', 'altitude_25percentile', 'vertical_rate_75percentile']
# Evaluation RMSE: 13856.347829221448
# Trying the combination number 363...
# ['wtc', 'flown_distance', 'altitude_25percentile', 'altitude_median']
# Evaluation RMSE: 12852.645960946458
# Trying the combination number 364...
# ['wtc', 'flown_distance', 'altitude_25percentile', 'ades']
# Evaluation RMSE: 9627.782854444516
# Trying the combination number 365...
# ['wtc', 'flown_distance', 'airline', 'flight_duration']
# Evaluation RMSE: 10808.058497523169
# Trying the combination number 366...
# ['wtc', 'flown_distance', 'airline', 'longitude_max']
# Evaluation RMSE: 9696.162990547791
# Trying the combination number 367...
# ['wtc', 'flown_distance', 'airline', 'vertical_rate_75percentile']
# Evaluation RMSE: 10919.789956537601
# Trying the combination number 368...
# ['wtc', 'flown_distance', 'airline', 'altitude_median']
# Evaluation RMSE: 9433.696489814916
# Trying the combination number 369...
# ['wtc', 'flown_distance', 'airline', 'ades']
# Evaluation RMSE: 9580.195989599124
# Trying the combination number 370...
# ['wtc', 'flown_distance', 'flight_duration', 'longitude_max']
# Evaluation RMSE: 10407.793396150098
# Trying the combination number 371...
# ['wtc', 'flown_distance', 'flight_duration', 'vertical_rate_75percentile']
# Evaluation RMSE: 14665.900155866706
# Trying the combination number 372...
# ['wtc', 'flown_distance', 'flight_duration', 'altitude_median']
# Evaluation RMSE: 13036.829080539357
# Trying the combination number 373...
# ['wtc', 'flown_distance', 'flight_duration', 'ades']
# Evaluation RMSE: 10399.30396354521
# Trying the combination number 374...
# ['wtc', 'flown_distance', 'longitude_max', 'vertical_rate_75percentile']
# Evaluation RMSE: 10496.659056054961
# Trying the combination number 375...
# ['wtc', 'flown_distance', 'longitude_max', 'altitude_median']
# Evaluation RMSE: 9331.21492171628
# Trying the combination number 376...
# ['wtc', 'flown_distance', 'longitude_max', 'ades']
# Evaluation RMSE: 9397.515744492053
# Trying the combination number 377...
# ['wtc', 'flown_distance', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 13271.359703001215
# Trying the combination number 378...
# ['wtc', 'flown_distance', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 10479.248516010057
# Trying the combination number 379...
# ['wtc', 'flown_distance', 'altitude_median', 'ades']
# Evaluation RMSE: 8998.37723312521
# Trying the combination number 380...
# ['wtc', 'groundspeed_max', 'latitude_min', 'altitude_25percentile']
# Evaluation RMSE: 13444.624236798278
# Trying the combination number 381...
# ['wtc', 'groundspeed_max', 'latitude_min', 'airline']
# Evaluation RMSE: 11644.639598707303
# Trying the combination number 382...
# ['wtc', 'groundspeed_max', 'latitude_min', 'flight_duration']
# Evaluation RMSE: 11581.352021500375
# Trying the combination number 383...
# ['wtc', 'groundspeed_max', 'latitude_min', 'longitude_max']
# Evaluation RMSE: 11522.45122667266
# Trying the combination number 384...
# ['wtc', 'groundspeed_max', 'latitude_min', 'vertical_rate_75percentile']
# Evaluation RMSE: 14613.175629130004
# Trying the combination number 385...
# ['wtc', 'groundspeed_max', 'latitude_min', 'altitude_median']
# Evaluation RMSE: 13171.390692377585
# Trying the combination number 386...
# ['wtc', 'groundspeed_max', 'latitude_min', 'ades']
# Evaluation RMSE: 12277.142993646039
# Trying the combination number 387...
# ['wtc', 'groundspeed_max', 'altitude_25percentile', 'airline']
# Evaluation RMSE: 12707.451392790545
# Trying the combination number 388...
# ['wtc', 'groundspeed_max', 'altitude_25percentile', 'flight_duration']
# Evaluation RMSE: 14203.719597717392
# Trying the combination number 389...
# ['wtc', 'groundspeed_max', 'altitude_25percentile', 'longitude_max']
# Evaluation RMSE: 12750.653179349987
# Trying the combination number 390...
# ...
# Trying the combination number 4032...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 3647.3340120587345
# Trying the combination number 4033...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 4047.418264169965
# Trying the combination number 4034...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'airline', 'flight_duration', 'longitude_max', 'altitude_median', 'ades']
# Evaluation RMSE: 3659.024466156217
# Trying the combination number 4035...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'airline', 'flight_duration', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3627.5514946199874
# Trying the combination number 4036...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'airline', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3599.0565926182885
# Trying the combination number 4037...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3678.4142596420147
# Trying the combination number 4038...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 3653.196460777855
# Trying the combination number 4039...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 3880.7065994000372
# Trying the combination number 4040...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'altitude_median', 'ades']
# Evaluation RMSE: 3633.7620817822003
# Trying the combination number 4041...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'altitude_25percentile', 'airline', 'flight_duration', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3629.0155872556657
# Trying the combination number 4042...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'altitude_25percentile', 'airline', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3571.506343308809
# Trying the combination number 4043...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'altitude_25percentile', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3675.0113443351634
# Trying the combination number 4044...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3616.4477575136916
# Trying the combination number 4045...
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 3576.843508220414
# Trying the combination number 4046...
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 3834.427089892933
# Trying the combination number 4047...
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'altitude_median', 'ades']
# Evaluation RMSE: 3582.676797223897
# Trying the combination number 4048...
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3554.8136779930896
# Trying the combination number 4049...
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'airline', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3530.1531114405425
# Trying the combination number 4050...
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3609.397304690969
# Trying the combination number 4051...
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3577.96411007247
# Trying the combination number 4052...
# ['wtc', 'aircraft_type', 'flown_distance', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3547.306832207451
# Trying the combination number 4053...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 3615.776883002003
# Trying the combination number 4054...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 3878.4965880429736
# Trying the combination number 4055...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'altitude_median', 'ades']
# Evaluation RMSE: 3627.2559023329813
# Trying the combination number 4056...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3595.006551619326
# Trying the combination number 4057...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3966.7553538022316
# Trying the combination number 4058...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3651.532555762939
# Trying the combination number 4059...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_min', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3622.576471998787
# Trying the combination number 4060...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3619.6917942408822
# Trying the combination number 4061...
# ['wtc', 'aircraft_type', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3551.0669039968693
# Trying the combination number 4062...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 7187.368881274408
# Trying the combination number 4063...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 7389.108789134414
# Trying the combination number 4064...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'altitude_median', 'ades']
# Evaluation RMSE: 7063.956353383103
# Trying the combination number 4065...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 7039.578541023938
# Trying the combination number 4066...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 6930.240570557014
# Trying the combination number 4067...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 7331.11248527472
# Trying the combination number 4068...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_min', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 7039.109321271345
# Trying the combination number 4069...
# ['wtc', 'flown_distance', 'groundspeed_max', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 7153.04805001451
# Trying the combination number 4070...
# ['wtc', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 6903.022806004131
# Trying the combination number 4071...
# ['wtc', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 7099.115959801202
# Trying the combination number 4072...
# ['aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 3618.045851405063
# Trying the combination number 4073...
# ['aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 3868.3800111115156
# Trying the combination number 4074...
# ['aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'altitude_median', 'ades']
# Evaluation RMSE: 3623.8493692885154
# Trying the combination number 4075...
# ['aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3562.582636334852
# Trying the combination number 4076...
# ['aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3568.636801757624
# Trying the combination number 4077...
# ['aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3649.430605587377
# Trying the combination number 4078...
# ['aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3623.7946544328647
# Trying the combination number 4079...
# ['aircraft_type', 'flown_distance', 'groundspeed_max', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3595.733835413332
# Trying the combination number 4080...
# ['aircraft_type', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3544.3061837298465
# Trying the combination number 4081...
# ['aircraft_type', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3645.299141231461
# Trying the combination number 4082...
# ['flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 13566.318802499687
# Trying the combination number 4083...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median']
# Evaluation RMSE: 3589.2240219982264
# Trying the combination number 4084...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'ades']
# Evaluation RMSE: 3849.7360061641643
# Trying the combination number 4085...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'altitude_median', 'ades']
# Evaluation RMSE: 3599.0968980355706
# Trying the combination number 4086...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3565.4512035145567
# Trying the combination number 4087...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3542.982595473661
# Trying the combination number 4088...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3624.4642304790573
# Trying the combination number 4089...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3595.3885229900666
# Trying the combination number 4090...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3567.0723488657145
# Trying the combination number 4091...
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3521.641592899745
# Trying the combination number 4092...
# ['wtc', 'aircraft_type', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3566.1745300796833
# Trying the combination number 4093...
# ['wtc', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 6889.199853689053
# Trying the combination number 4094...
# ['aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3570.1714140302697
# Trying the combination number 4095...
# ['wtc', 'aircraft_type', 'flown_distance', 'groundspeed_max', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']
# Evaluation RMSE: 3535.3328363843807

# %%
print(f"Minimum RMSE: ", combinations_rmse_scores[np.argmin(combinations_rmse_scores)])
# Out:
# Minimum RMSE:  3521.641592899745

# %%
print(f"Top features: ")
top_features_with_lowest_rmse = tried_combination[np.argmin(combinations_rmse_scores)]
print(top_features_with_lowest_rmse)
# Out:
# Top features:
# ['wtc', 'aircraft_type', 'flown_distance', 'latitude_min', 'altitude_25percentile', 'airline', 'flight_duration', 'longitude_max', 'vertical_rate_75percentile', 'altitude_median', 'ades']

# %%
print(f"Number of top features giving minimum RMSE: ", len(top_features_with_lowest_rmse))
# Out:
# Number of top features giving minimum RMSE:  11
