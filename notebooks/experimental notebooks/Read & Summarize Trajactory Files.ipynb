# %% [markdown]
# <h1>Read & Summarize Trajactory Files.ipynb</h1>

# %%
import dask.dataframe as dd
import pandas as pd
import os

# %%
challenge_set = pd.read_csv('../challenge_set.csv')
flight_ids = list(challenge_set['flight_id'].astype(int).unique())

submission_set = pd.read_csv('../submission_set.csv')
flight_ids += list(submission_set['flight_id'].astype(int).unique())

print(f"{len(flight_ids) = } flights")
# Out:
# len(flight_ids) = 474972 flights

# %%
file_names = os.listdir("../data/trajectory_files")

trajectory_df = pd.DataFrame({})

for trajectory_file_name in file_names:
    if ".parquet" in trajectory_file_name:
        print(f"Reading {trajectory_file_name}")
        current_trajectory_df = dd.read_parquet(f'../data/trajectory_files/{trajectory_file_name}', engine='auto')  # 'auto' lets Dask choose between 'fastparquet' or 'pyarrow'
        filtered_trajactory_df = current_trajectory_df[current_trajectory_df['flight_id'].astype(int).isin(flight_ids)]
        trajectory_df = dd.concat([trajectory_df, filtered_trajactory_df])

# Display the filtered DataFrame
print(f"{len(trajectory_df) = }")
display(trajectory_df)
# Out:
# Reading 2022-01-01.parquet
# Reading 2022-01-02.parquet
# Reading 2022-01-03.parquet
# Reading 2022-01-04.parquet
# Reading 2022-01-05.parquet
# Reading 2022-01-06.parquet
# Reading 2022-01-07.parquet
# Reading 2022-01-08.parquet
# Reading 2022-01-09.parquet
# Reading 2022-01-10.parquet
# Reading 2022-01-11.parquet
# Reading 2022-01-12.parquet
# Reading 2022-01-13.parquet
# Reading 2022-01-14.parquet
# Reading 2022-01-15.parquet
# Reading 2022-01-16.parquet
# Reading 2022-01-17.parquet
# Reading 2022-01-18.parquet
# Reading 2022-01-19.parquet
# Reading 2022-01-20.parquet
# Reading 2022-01-21.parquet
# Reading 2022-01-22.parquet
# Reading 2022-01-23.parquet
# Reading 2022-01-24.parquet
# Reading 2022-01-25.parquet
# Reading 2022-01-26.parquet
# Reading 2022-01-27.parquet
# Reading 2022-01-28.parquet
# Reading 2022-01-29.parquet
# Reading 2022-01-30.parquet
# Reading 2022-01-31.parquet
# Reading 2022-02-01.parquet
# Reading 2022-02-02.parquet
# Reading 2022-02-03.parquet
# Reading 2022-02-04.parquet
# Reading 2022-02-05.parquet
# Reading 2022-02-06.parquet
# Reading 2022-02-07.parquet
# Reading 2022-02-08.parquet
# Reading 2022-02-09.parquet
# Reading 2022-02-10.parquet
# Reading 2022-02-11.parquet
# Reading 2022-02-12.parquet
# Reading 2022-02-13.parquet
# Reading 2022-02-14.parquet
# Reading 2022-02-15.parquet
# Reading 2022-02-16.parquet
# Reading 2022-02-17.parquet
# Reading 2022-02-18.parquet
# Reading 2022-02-19.parquet
# Reading 2022-02-20.parquet
# Reading 2022-02-21.parquet
# Reading 2022-02-22.parquet
# Reading 2022-02-23.parquet
# Reading 2022-02-24.parquet
# Reading 2022-02-25.parquet
# Reading 2022-02-26.parquet
# Reading 2022-02-27.parquet
# Reading 2022-02-28.parquet
# Reading 2022-03-01.parquet
# Reading 2022-12-07.parquet
# Reading 2022-12-08.parquet
# Reading 2022-12-09.parquet
# Reading 2022-12-10.parquet
# Reading 2022-12-11.parquet
# Reading 2022-12-12.parquet
# Reading 2022-12-13.parquet
# Reading 2022-12-14.parquet
# Reading 2022-12-15.parquet
# Reading 2022-12-16.parquet
# Reading 2022-12-17.parquet
# Reading 2022-12-18.parquet
# Reading 2022-12-19.parquet
# Reading 2022-12-20.parquet
# Reading 2022-12-21.parquet
# Reading 2022-12-22.parquet
# Reading 2022-12-23.parquet
# Reading 2022-12-24.parquet
# Reading 2022-12-25.parquet
# Reading 2022-12-26.parquet
# Reading 2022-12-27.parquet
# Reading 2022-12-28.parquet
# Reading 2022-12-29.parquet
# Reading 2022-12-30.parquet
# Reading 2022-12-31.parquet
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[3], line 13
#      10         trajectory_df = dd.concat([trajectory_df, filtered_trajactory_df])
#      12 # Display the filtered DataFrame
# ---> 13 print(f"{len(trajectory_df) = }")
#      14 display(trajectory_df)
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_collection.py:383, in FrameBase.__len__(self)
#     382 def __len__(self):
# --> 383     return new_collection(Len(self)).compute()
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_collection.py:476, in FrameBase.compute(self, fuse, **kwargs)
#     474 if not isinstance(out, Scalar):
#     475     out = out.repartition(npartitions=1)
# --> 476 out = out.optimize(fuse=fuse)
#     477 return DaskMethodsMixin.compute(out, **kwargs)
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_collection.py:591, in FrameBase.optimize(self, fuse)
#     573 def optimize(self, fuse: bool = True):
#     574     """Optimizes the DataFrame.
#     575
#     576     Runs the optimizer with all steps over the DataFrame and wraps the result in a
#    (...)
#     589         The optimized Dask Dataframe
#     590     """
# --> 591     return new_collection(self.expr.optimize(fuse=fuse))
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:94, in Expr.optimize(self, **kwargs)
#      93 def optimize(self, **kwargs):
# ---> 94     return optimize(self, **kwargs)
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:3070, in optimize(expr, fuse)
#    3049 """High level query optimization
#    3050
#    3051 This leverages three optimization passes:
#    (...)
#    3066 optimize_blockwise_fusion
#    3067 """
#    3068 stage: core.OptimizerStage = "fused" if fuse else "simplified-physical"
# -> 3070 return optimize_until(expr, stage)
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:3041, in optimize_until(expr, stage)
#    3038     return expr
#    3040 # Final graph-specific optimizations
# -> 3041 expr = optimize_blockwise_fusion(expr)
#    3042 if stage == "fused":
#    3043     return expr
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:3239, in optimize_blockwise_fusion(expr)
#    3237 while True:
#    3238     original_name = expr._name
# -> 3239     expr, done = _fusion_pass(expr)
#    3240     if done or expr._name == original_name:
#    3241         break
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:3204, in optimize_blockwise_fusion.<locals>._fusion_pass(expr)
#    3201 stack_names = {s._name for s in stack}
#    3202 group_names = {g._name for g in group}
#    3203 if (
# -> 3204     dep.npartitions == root.npartitions or next._broadcast_dep(dep)
#    3205 ) and not (dependents[dep._name] - stack_names - group_names):
#    3206     # All of deps dependents are contained
#    3207     # in the local group (or the local stack
#    3208     # of expr nodes that we know we will be
#    3209     # adding to the local group).
#    3210     # All nodes must also have the same number
#    3211     # of partitions, since broadcasting within
#    3212     # a group is not allowed.
#    3213     stack.append(dep)
#    3214 elif dependencies[dep._name] and dep._name not in [
#    3215     r._name for r in roots
#    3216 ]:
#    3217     # Couldn't fuse dep, but we may be able to
#    3218     # use it as a new root on the next pass
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:398, in Expr.npartitions(self)
#     396     return self.operands[idx]
#     397 else:
# --> 398     return len(self.divisions) - 1
#
# File ~\miniconda3\envs\prc\Lib\functools.py:1001, in cached_property.__get__(self, instance, owner)
#     999 val = cache.get(self.attrname, _NOT_FOUND)
#    1000 if val is _NOT_FOUND:
# -> 1001     val = self.func(instance)
#    1002     try:
#    1003         cache[self.attrname] = val
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:382, in Expr.divisions(self)
#     380 @functools.cached_property
#     381 def divisions(self):
# --> 382     return tuple(self._divisions())
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:2633, in Binop._divisions(self)
#    2631     return tuple(self.operation(left_divisions, right_divisions))
#    2632 else:
# -> 2633     return super()._divisions()
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:529, in Blockwise._divisions(self)
#     527 dependencies = self.dependencies()
#     528 for arg in dependencies:
# --> 529     if not self._broadcast_dep(arg):
#     530         assert arg.divisions == dependencies[0].divisions
#     531 return dependencies[0].divisions
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:520, in Blockwise._broadcast_dep(self, dep)
#     517 def _broadcast_dep(self, dep: Expr):
#     518     # Checks if a dependency should be broadcasted to
#     519     # all partitions of this `Blockwise` operation
# --> 520     return dep.npartitions == 1 and dep.ndim < self.ndim
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:398, in Expr.npartitions(self)
#     396     return self.operands[idx]
#     397 else:
# --> 398     return len(self.divisions) - 1
#
# File ~\miniconda3\envs\prc\Lib\functools.py:1001, in cached_property.__get__(self, instance, owner)
#     999 val = cache.get(self.attrname, _NOT_FOUND)
#    1000 if val is _NOT_FOUND:
# -> 1001     val = self.func(instance)
#    1002     try:
#    1003         cache[self.attrname] = val
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:382, in Expr.divisions(self)
#     380 @functools.cached_property
#     381 def divisions(self):
# --> 382     return tuple(self._divisions())
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:2633, in Binop._divisions(self)
#    2631     return tuple(self.operation(left_divisions, right_divisions))
#    2632 else:
# -> 2633     return super()._divisions()
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:529, in Blockwise._divisions(self)
#     527 dependencies = self.dependencies()
#     528 for arg in dependencies:
# --> 529     if not self._broadcast_dep(arg):
#     530         assert arg.divisions == dependencies[0].divisions
#     531 return dependencies[0].divisions
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:520, in Blockwise._broadcast_dep(self, dep)
#     517 def _broadcast_dep(self, dep: Expr):
#     518     # Checks if a dependency should be broadcasted to
#     519     # all partitions of this `Blockwise` operation
# --> 520     return dep.npartitions == 1 and dep.ndim < self.ndim
#
#     [... skipping similar frames: cached_property.__get__ at line 1001 (491 times), Expr.divisions at line 382 (491 times), Expr.npartitions at line 398 (491 times), Blockwise._broadcast_dep at line 520 (490 times), Binop._divisions at line 2633 (490 times), Blockwise._divisions at line 529 (490 times)]
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:2633, in Binop._divisions(self)
#    2631     return tuple(self.operation(left_divisions, right_divisions))
#    2632 else:
# -> 2633     return super()._divisions()
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:529, in Blockwise._divisions(self)
#     527 dependencies = self.dependencies()
#     528 for arg in dependencies:
# --> 529     if not self._broadcast_dep(arg):
#     530         assert arg.divisions == dependencies[0].divisions
#     531 return dependencies[0].divisions
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:520, in Blockwise._broadcast_dep(self, dep)
#     517 def _broadcast_dep(self, dep: Expr):
#     518     # Checks if a dependency should be broadcasted to
#     519     # all partitions of this `Blockwise` operation
# --> 520     return dep.npartitions == 1 and dep.ndim < self.ndim
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:398, in Expr.npartitions(self)
#     396     return self.operands[idx]
#     397 else:
# --> 398     return len(self.divisions) - 1
#
# File ~\miniconda3\envs\prc\Lib\functools.py:1001, in cached_property.__get__(self, instance, owner)
#     999 val = cache.get(self.attrname, _NOT_FOUND)
#    1000 if val is _NOT_FOUND:
# -> 1001     val = self.func(instance)
#    1002     try:
#    1003         cache[self.attrname] = val
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:382, in Expr.divisions(self)
#     380 @functools.cached_property
#     381 def divisions(self):
# --> 382     return tuple(self._divisions())
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask_expr\_expr.py:2619, in Binop._divisions(self)
#    2618 def _divisions(self):
# -> 2619     if is_index_like(self._meta):
#    2620         left_divisions = (
#    2621             pd.Series(self.left.divisions)
#    2622             if isinstance(self.left, Expr)
#    2623             else self.left
#    2624         )
#    2625         right_divisions = (
#    2626             pd.Series(self.right.divisions)
#    2627             if isinstance(self.right, Expr)
#    2628             else self.right
#    2629         )
#
# File ~\miniconda3\envs\prc\Lib\site-packages\dask\utils.py:1552, in is_index_like(s)
#    1549 """Looks like a Pandas Index"""
#    1550 typ = s.__class__
#    1551 return (
# -> 1552     all(hasattr(s, name) for name in ("name", "dtype"))
#    1553     and "index" in typ.__name__.lower()
#    1554 )
#
# RecursionError: maximum recursion depth exceeded

# %%
import sys

# Increase recursion limit
sys.setrecursionlimit(10000)  # Adjust the limit as needed

# %%
def calculate_stat(
    dataframe: pd.DataFrame, 
    group_by_column: str, 
    target_column: str,
    stat_type: str,
    value_type: str = 'float64'
) -> pd.Series | None:
    result = None
    if stat_type == 'median':
        result = dataframe.groupby(group_by_column).apply(lambda group: group[target_column].median(), meta=('value', value_type)).compute()
    elif stat_type == 'mean':
        result = dataframe.groupby(group_by_column).apply(lambda group: group[target_column].mean(), meta=('value', value_type)).compute()
    return result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 def calculate_stat(
# ----> 2     dataframe: pd.DataFrame,
#       3     group_by_column: str,
#       4     target_column: str,
#       5     stat_type: str,
#       6     value_type: str = 'float64'
#       7 ) -> pd.Series | None:
#       8     result = None
#       9     if stat_type == 'median':
#
# NameError: name 'pd' is not defined

# %%
latitude_median = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='latitude', stat_type='median')
longitude_median = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='longitude', stat_type='median')
altitude_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='altitude', stat_type='mean', value_type='int64')
groundspeed_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='groundspeed', stat_type='mean', value_type='int64')
track_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='track', stat_type='mean')
vertical_rate_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='vertical_rate', stat_type='mean', value_type='int64')
track_unwrapped_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='track_unwrapped', stat_type='mean')
u_component_of_wind_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='u_component_of_wind', stat_type='mean')
v_component_of_wind_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='v_component_of_wind', stat_type='mean')
temperature_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='temperature', stat_type='mean')
specific_humidity_mean = calculate_stat(dataframe=trajectory_df, group_by_column='flight_id', target_column='specific_humidity', stat_type='mean')

trajactory_summary_df = pd.DataFrame({
    "latitude_median": latitude_median,
    "longitude_median": longitude_median,
    "altitude_mean": altitude_mean,
    "groundspeed_mean": groundspeed_mean,
    "track_mean": track_mean,
    "vertical_rate_mean": vertical_rate_mean,
    "track_unwrapped_mean": track_unwrapped_mean,
    "u_component_of_wind_mean": u_component_of_wind_mean,
    "v_component_of_wind_mean": v_component_of_wind_mean,
    "temperature": temperature_mean,
    "specific_humidity": specific_humidity_mean
})

display(trajactory_summary_df)

# %%
def save_dataframe(path: str, dataframe: pd.DataFrame) -> None:
    dataframe.to_csv(path, index=False)
    print(f"{path} is saved!")

# %%
save_dataframe(path="../data/trajactory_summary.csv", dataframe=trajactory_summary_df)
