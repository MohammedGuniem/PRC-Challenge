# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import xgboost as xgb
import pandas as pd
import numpy as np

# %%
identifier_name = 'flight_id'

top_features_names = [
    'wtc', 
    'aircraft_type', 
    'flown_distance', 
    'groundspeed_max', 
    'latitude_min', 
    'altitude_25percentile', 
    'airline', 
    'flight_duration', 
    'longitude_max', 
    'vertical_rate_75percentile', 
    'altitude_median', 
    'ades', 
    'longitude_mean', 
    'altitude_75percentile', 
    'latitude_75percentile', 
    'vertical_rate_std', 
    'adep', 
    'latitude_std', 
    'vertical_rate_max', 
    'latitude_max', 
    'longitude_std', 
    'vertical_rate_25percentile', 
    'longitude_min', 
    'longitude_75percentile', 
    'altitude_mean', 
    'groundspeed_75percentile', 
    'country_code_adep', 
    'latitude_median', 
    'longitude_25percentile', 
    'groundspeed_min', 
    'country_code_ades', 
    'latitude_25percentile', 
    'actual_offblock_time_hour', 
    'longitude_median', 
    'month', 
    'altitude_std', 
    'latitude_count', 
    'taxiout_time', 
    'vertical_rate_median', 
    'month_day'
]

target_name = 'tow'

global_random_state = 123

# %%
encoded_challenge_set = pd.read_csv('data/encoded_challenge_set.csv')
encoded_challenge_set = encoded_challenge_set.fillna(0)
df = encoded_challenge_set[top_features_names+[target_name]]

# %%
threshold_rmse = 3000
below_threshold_data = []
above_threshold_data = [df]

below_min_datapoints = []

remaining_datapoints = len(df)

while len(above_threshold_data) > 0:
    data_df = above_threshold_data.pop().copy()
    kmeans = KMeans(n_clusters=2, random_state=global_random_state)
    data_df['cluster'] = kmeans.fit_predict(data_df[top_features_names])
    
    for cluster_nr in range(0, 2, 1):
        cluster_df = data_df[data_df['cluster'] == cluster_nr]
        cluster_df = cluster_df.drop('cluster', axis=1)
        cluster_df_length = len(cluster_df)
        
        if len(cluster_df) < 90:
            below_min_datapoints.append(cluster_df)
            remaining_datapoints -= cluster_df_length
            print(f"Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: {remaining_datapoints}")
            continue

        X = cluster_df[top_features_names]
        y = cluster_df[target_name]
        
        model = xgb.XGBRegressor(
            colsample_bytree=1.0,
            learning_rate=0.1, 
            max_depth=10, 
            n_estimators=91, 
            subsample=1.0,
            objective='reg:squarederror', 
            eval_metric='rmse',
            random_state=global_random_state
        )
        kf = KFold(n_splits=3, shuffle=True, random_state=global_random_state)
        scores = cross_val_score(model, X, y, cv=kf, scoring='neg_mean_squared_error')
        mse_scores = -scores
        mean_mse = np.mean(mse_scores)
        rmse = np.sqrt(mean_mse)
        
        if rmse < threshold_rmse:
            below_threshold_cluster = {
                "cluster_data": cluster_df,
                "cluster_RMSE": rmse,
                "cluster_centroid": kmeans.cluster_centers_[cluster_nr].tolist()
            }
            below_threshold_data.append(below_threshold_cluster)
            remaining_datapoints -= cluster_df_length
            print(f"Below Threshold Cluster Found -> RMSE: {rmse:.2f}, Remaining Data Points: {remaining_datapoints}")
        else:
            above_threshold_data.append(cluster_df)

print("Finished searching for clusters.")
# Out:
# C:\Users\MOHAMMEDG\Anaconda3\envs\prc\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\MOHAMMEDG\Anaconda3\envs\prc\Lib\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")
# Below Threshold Cluster Found -> RMSE: 2611.73, Remaining Data Points: 232445
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 232442
# Below Threshold Cluster Found -> RMSE: 2866.65, Remaining Data Points: 231873
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points:
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 5399
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 5341
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 5311
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 5244
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 5196
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 5148
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 5113
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 5057
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 5015
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4999
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4959
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4893
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4808
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4721
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4717
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4686
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4649
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4563
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4559
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4539
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4472
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4448
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4371
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4313
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4265
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4211
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4142
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4077
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 4064
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3983
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3948
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3877
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3788
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3748
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3673
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3596
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3513
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3428
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3369
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3295
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3269
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3265
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3260
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3195
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3114
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 3070
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2989
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2940
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2854
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2840
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2754
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2687
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2649
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2631
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2554
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2469
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2416
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2336
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2256
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2253
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2245
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2202
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2180
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2105
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 2035
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1954
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1899
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1811
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1804
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1742
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1688
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1684
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1611
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1540
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1525
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1468
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1430
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1361
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1325
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1247
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1195
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1115
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 1039
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 969
# Below Threshold Cluster Found -> RMSE: 2670.87, Remaining Data Points: 844
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 815
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 760
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 675
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 618
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 577
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 501
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 412
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 341
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 293
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 231
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 200
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 134
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 99
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 34
# Cluster Reached Below Minimum Requirement of Datapoints, Remaining Data Points: 0
# Finished searching for clusters.

# %%
original_count_of_datapoints = len(df)
datapoint_count_in_clusters = 0

cluster_centroids_info = []

for cluster_number, cluster_dict in enumerate(below_threshold_data):
    cluster_num = cluster_number+1
    cluster_df = cluster_dict["cluster_data"]
    cluster_df_length = len(cluster_df)
    datapoint_count_in_clusters += cluster_df_length
    cluster_centroids_info.append(
        cluster_dict['cluster_centroid']+[cluster_dict['cluster_RMSE'], cluster_df_length]
    )
    cluster_df.to_csv(f"./data/clusters/clusters_threshold_{str(threshold_rmse)}/cluster_{str(cluster_num)}.csv", index=False)
    print(f"./data/clusters/cluster_{str(cluster_num)}.csv is saved!")
print()

print("Cluster centroid information")
cluster_centroids_info_df = pd.DataFrame(cluster_centroids_info, columns=top_features_names+['rmse', 'datapoint_count'])
display(cluster_centroids_info_df)
cluster_centroids_info_df.to_csv(f"./data/clusters/clusters_threshold_{str(threshold_rmse)}/ext/cluster_centroids_info.csv", index=False)
print(f"./data/clusters/clusters_threshold_{str(threshold_rmse)}/cluster_centroids_info.csv is saved!")

below_min_datapoints_df = pd.DataFrame([])
for part_df in below_min_datapoints:
    below_min_datapoints_df = pd.concat([below_min_datapoints_df, part_df], ignore_index=True)
below_min_datapoints_df.to_csv(f"./data/clusters/clusters_threshold_{str(threshold_rmse)}/ext/below_min_datapoints.csv", index=False)
print(f"./data/clusters/clusters_threshold_{str(threshold_rmse)}/below_min_datapoints.csv is saved!")
datapoint_count_not_in_clusters = len(below_min_datapoints_df)

print("Original count of datapoints: ", original_count_of_datapoints)
print("Datapoints in clusters: ", datapoint_count_in_clusters)
print("Datapoints not in clusters: ", datapoint_count_not_in_clusters)
print(f"Percentage of clustered datapoints: {(datapoint_count_in_clusters/original_count_of_datapoints)*100:.2f}", )
print(f"Percentage of non-clustered datapoints: {(datapoint_count_not_in_clusters/original_count_of_datapoints)*100:.2f}", )
print()
# Out:
# ./data/clusters/cluster_1.csv is saved!
# ./data/clusters/cluster_2.csv is saved!
# ./data/clusters/cluster_3.csv is saved!
# ./data/clusters/cluster_4.csv is saved!
# ./data/clusters/cluster_5.csv is saved!
# ./data/clusters/cluster_6.csv is saved!
# ./data/clusters/cluster_7.csv is saved!
# ./data/clusters/cluster_8.csv is saved!
# ./data/clusters/cluster_9.csv is saved!
# ./data/clusters/cluster_10.csv is saved!
# ./data/clusters/cluster_11.csv is saved!
# ./data/clusters/cluster_12.csv is saved!
# ./data/clusters/cluster_13.csv is saved!
# ./data/clusters/cluster_14.csv is saved!
# ./data/clusters/cluster_15.csv is saved!
# ./data/clusters/cluster_16.csv is saved!
# ./data/clusters/cluster_17.csv is saved!
# ./data/clusters/cluster_18.csv is saved!
# ./data/clusters/cluster_19.csv is saved!
# ./data/clusters/cluster_20.csv is saved!
# ./data/clusters/cluster_21.csv is saved!
# ./data/clusters/cluster_22.csv is saved!
# ./data/clusters/cluster_23.csv is saved!
# ./data/clusters/cluster_24.csv is saved!
# ./data/clusters/cluster_25.csv is saved!
# ./data/clusters/cluster_26.csv is saved!
# ./data/clusters/cluster_27.csv is saved!
# ./data/clusters/cluster_28.csv is saved!
# ./data/clusters/cluster_29.csv is saved!
# ./data/clusters/cluster_30.csv is saved!
# ./data/clusters/cluster_31.csv is saved!
# ./data/clusters/cluster_32.csv is saved!
# ./data/clusters/cluster_33.csv is saved!
# ./data/clusters/cluster_34.csv is saved!
# ./data/clusters/cluster_35.csv is saved!
#
# Cluster centroid information
#          wtc  aircraft_type  flown_distance  groundspeed_max  latitude_min  \
# 0   0.956569      11.829648      442.565542       397.954462     47.388700
# 1   0.978910      23.021090      632.699473       471.441125     48.263135
# 2   0.923519       9.166623      804.438642       474.154883     45.147658
# 3   0.972997      10.423942     1809.534653       497.956796     35.765966
# 4   0.963470       5.890411     1628.636986       487.764840     36.736309
# 5   0.928571       7.276786     1626.642857       479.348214     36.611201
# 6   0.968750      10.062500     1850.117188       508.351562     35.460236
# 7   0.974026       8.675325     1464.363636       483.402597     36.756106
# 8   0.885417       9.906250     1513.833333       471.520833     37.687869
# 9   0.981900       6.552036     1475.624434       491.927602     38.396275
# 10  0.970740       9.986231     1635.560241       511.976764     36.830271
# 11  0.990476       5.695238     1707.385714       609.828571     35.415576
# 12  1.000000       2.604278     1499.433155       457.219251     38.812752
# 13  0.991718       3.099379     1358.552795       460.751553     40.371676
# 14  0.967391      11.097826     1379.086957       498.858696     38.888537
# 15  0.978261      10.945652     1161.478261       484.076087     37.037719
# 16  1.000000       1.609907     1746.130031       469.696594     38.817204
# 17  1.000000       1.617512     1448.718894       461.525346     40.103787
# 18  0.991402       2.355159     1654.774471       488.959656     38.930017
# 19  1.000000       5.490706     1832.368030       540.565056     35.994073
# 20  0.959184      12.357143     1014.857143       466.142857     40.202524
# 21  0.982456      12.216374     1079.736842       485.491228     39.579588
# 22  0.960217      11.793852     1060.651899       483.305606     39.927401
# 23  0.965039      10.195676      933.323688       477.828851     41.703655
# 24  0.936508      10.738095     1095.337302       493.611111     40.115302
# 25  0.918182      11.209091      892.790909       468.218182     42.363137
# 26  0.954198       3.137405     1405.977099       519.969466     40.042265
# 27  0.985714       7.642857      929.442857       469.792857     41.328744
# 28  0.984456       2.860104     1381.336788       461.362694     40.444366
# 29  1.000000       4.265487     1051.814159       457.513274     41.013330
# 30  1.000000       3.582133     1198.804035       455.440922     40.537206
# 31  0.983740       4.512195     1230.056911       462.243902     41.041552
# 13          0.000000e+00  186.233954  2998.353794              483
# 14         -2.782609e+00  191.663043  2070.385234               92
# 15         -6.956522e-01  176.358696  2522.731948               92
# 16          4.163336e-17  206.359133  2158.356043              323
# 17          0.000000e+00  186.539171  2800.733657              217
# 18         -1.269841e-01  206.212963  2859.903794             1512
# 19         -4.884981e-15  207.308550  2254.168697              269
# 20          5.551115e-17  181.306122  2855.505598               98
# 21         -3.742690e-01  200.906433  2978.167332              171
# 22         -8.101266e-01  195.323689  2843.269285             1105
# 23         -1.418244e+00  192.132315  2827.817325             9296
# 24         -5.079365e-01  189.107143  2922.598615              252
# 25         -2.909091e-01  192.436364  2949.109762              220
# 26          2.775558e-16  201.755725  2529.271119              131
# 27          3.885781e-16  188.778571  2874.853276              140
# 28          0.000000e+00  197.818653  2930.372504              193
# 29          0.000000e+00  204.398230  2995.820990              113
# 30          0.000000e+00  208.337176  2932.882064              347
# 31          0.000000e+00  172.910569  2919.732396              123
# 32         -2.151261e-01  202.500840  2946.218080              595
# 33          0.000000e+00  203.992436  2644.445859              661
# 34          1.387779e-16  215.384000  2670.874339              125
#
# [35 rows x 42 columns]
# ./data/clusters/clusters_threshold_3000/cluster_centroids_info.csv is saved!
# ./data/clusters/clusters_threshold_3000/below_min_datapoints.csv is saved!
# Original count of datapoints:  369013
# Datapoints in clusters:  273190
# Datapoints not in clusters:  95823
# Percentage of clustered datapoints: 74.03
# Percentage of non-clustered datapoints: 25.97

# %%
display(cluster_centroids_info_df.describe()['rmse'])
# Out:
# count      35.000000
# mean     2705.233430
# std       264.621436
# min      2070.385234
# 25%      2570.500360
# 50%      2800.733657
# 75%      2921.165505
# max      2998.353794
# Name: rmse, dtype: float64

# %%
below_threshold_data_df = pd.DataFrame([])
for part_df in below_threshold_data:
    below_threshold_data_df = pd.concat([below_threshold_data_df, part_df["cluster_data"]], ignore_index=True)

X = below_threshold_data_df[top_features_names]
y = below_threshold_data_df[target_name]
        
model = xgb.XGBRegressor(
colsample_bytree=1.0,
    learning_rate=0.1, 
    max_depth=10, 
    n_estimators=91, 
    subsample=1.0,
    objective='reg:squarederror', 
    eval_metric='rmse',
    random_state=global_random_state
)
kf = KFold(n_splits=3, shuffle=True, random_state=global_random_state)
scores = cross_val_score(model, X, y, cv=kf, scoring='neg_mean_squared_error')
mse_scores = -scores
mean_mse = np.mean(mse_scores)
rmse = np.sqrt(mean_mse)

print("RMSE of clustered datapoints all together: ", rmse)
# Out:
# RMSE of clustered datapoints all together:  2572.6835380508105

# %%
X = below_min_datapoints_df[top_features_names]
y = below_min_datapoints_df[target_name]
        
model = xgb.XGBRegressor(
    colsample_bytree=1.0,
    learning_rate=0.1, 
    max_depth=10, 
    n_estimators=91, 
    subsample=1.0,
    objective='reg:squarederror', 
    eval_metric='rmse',
    random_state=global_random_state
)
kf = KFold(n_splits=3, shuffle=True, random_state=global_random_state)
scores = cross_val_score(model, X, y, cv=kf, scoring='neg_mean_squared_error')
mse_scores = -scores
mean_mse = np.mean(mse_scores)
rmse = np.sqrt(mean_mse)

print("RMSE of non-clustered datapoints: ", rmse)
# Out:
# RMSE of non-clustered datapoints:  4145.756114093148
